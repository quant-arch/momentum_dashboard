# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_excel("Trials\\Nifty_500_2025_Apr_20_stocks_results_GoldSilverDebt_buy&hold_returns.xlsx")
data
# Out:
#             Date      Open      High       Low     Close      volume   oi  \
# 0     2023-04-03    154.00    154.90    152.00    153.80   2347046.0  0.0
# 1     2023-04-03    407.00    410.95    403.05    405.15    112564.0  0.0
# 2     2023-04-03    169.10    170.25    168.10    169.20  16659059.0  0.0
# 3     2023-04-03     75.00     76.45     74.10     75.95   8102076.0  0.0
# 4     2023-04-03  19500.00  19500.85  19200.00  19434.25     29923.0  0.0
# ...          ...       ...       ...       ...       ...         ...  ...
# 15459 2026-03-10    113.08       NaN       NaN    113.06         NaN  NaN
# 15460 2026-03-11    133.43       NaN       NaN    132.71         NaN  NaN
# 15461 2026-03-11    113.08       NaN       NaN    113.08         NaN  NaN
# 15462 2026-03-12    131.90       NaN       NaN    131.95         NaN  NaN
# 15463 2026-03-12    113.11       NaN       NaN    113.10         NaN  NaN
#
#            Ticker   %change  Buy_Hold_Value  Total_Portfolio_Value
# 0       ABCAPITAL  0.001628        3.756106              75.779854
# 1      ANANDRATHI  0.003219        3.762071              75.779854
# 2      BANKBARODA  0.002073        3.757773              75.779854
# 3       BANKINDIA  0.017415        3.815305              75.779854
# 4        BOSCHLTD  0.003322        3.762458              75.779854
# ...           ...       ...             ...                    ...
# 15459  LIQUIDCASE  0.000088       38.952619                    NaN
# 15460    GOLDBEES  0.003858       27.125331                    NaN
# 15461  LIQUIDCASE  0.000177       38.959510                    NaN
# 15462    GOLDBEES -0.005727       26.969990                    NaN
# 15463  LIQUIDCASE  0.000177       38.966401                    NaN
#
# [15464 rows x 11 columns]

# %%
# max_date_tickers = data[(data['Date'] == '2025-12-31')]
# max_date_tickers
max_date_tickers = data[(data['Date'] == data['Date'].max())]
max_date_tickers
# Out:
#             Date     Open     High      Low    Close      volume   oi  \
# 15260 2026-03-12  2019.90  2019.90  1937.20  1969.00    293352.0  0.0
# 15261 2026-03-12   184.66   184.97   178.06   178.06  11288031.0  0.0
# 15262 2026-03-12   287.00   288.80   282.95   287.70   2332799.0  0.0
# 15263 2026-03-12   151.00   153.09   149.81   152.65   2027036.0  0.0
# 15264 2026-03-12  1789.90  1790.10  1720.00  1763.70    714536.0  0.0
# 15265 2026-03-12   138.60   139.74   136.26   139.44   6532216.0  0.0
# 15266 2026-03-12   265.75   271.65   264.85   270.80   2371246.0  0.0
# 15267 2026-03-12   968.00   968.00   934.45   939.35   1407413.0  0.0
# 15268 2026-03-12   540.80   540.80   519.40   524.70   3608070.0  0.0
# 15269 2026-03-12   910.00   912.80   890.00   909.95    366587.0  0.0
# 15270 2026-03-12   157.40   159.89   154.06   159.53   9726712.0  0.0
# 15271 2026-03-12   350.00   352.30   344.00   345.15    402691.0  0.0
# 15272 2026-03-12    65.56    66.83    65.45    66.57   5123139.0  0.0
# 15273 2026-03-12  2512.70  2529.70  2466.90  2488.80    846152.0  0.0
# 15274 2026-03-12   403.50   403.95   385.95   392.50   7695631.0  0.0
# 15275 2026-03-12   153.01   153.08   149.60   151.04   3684614.0  0.0
# 15276 2026-03-12  1075.10  1082.00  1070.50  1074.50   4241565.0  0.0
# 15277 2026-03-12  1021.10  1028.00  1006.10  1021.60   2604333.0  0.0
# 15278 2026-03-12   179.52   179.52   175.52   178.15   5205358.0  0.0
# 15279 2026-03-12   730.25   730.30   704.55   706.40   4277041.0  0.0
# 15462 2026-03-12   131.90      NaN      NaN   131.95         NaN  NaN
# 15463 2026-03-12   113.11      NaN      NaN   113.10         NaN  NaN
#
#            Ticker   %change  Buy_Hold_Value  Total_Portfolio_Value
# 15260   APLAPOLLO -0.023459        8.432730             200.504779
# 15261    ASHOKLEY -0.035741        9.278142             200.504779
# 15262  BANKBARODA -0.005531        8.552119             200.504779
# 15263   BANKINDIA -0.010693        9.533781             200.504779
# 15264  BHARATFORG -0.018585        8.831630             200.504779
# 15265       CANBK  0.000215        9.455758             200.504779
# 15266  FEDERALBNK  0.005010        9.645178             200.504779
# 15267    HINDALCO -0.020592       11.754075             200.504779
# 15268  HINDCOPPER -0.033524        7.840201             200.504779
# 15269     INDIANB -0.008553       10.229220             200.504779
# 15270         IOC -0.006848        8.143908             200.504779
# 15271      M&MFIN -0.022376        9.636434             200.504779
# 15272    MAHABANK -0.007011        8.521804             200.504779
# 15273         MCX -0.016906       10.089969             200.504779
# 15274  NATIONALUM -0.013199       15.673860             200.504779
# 15275        SAIL -0.018456       10.242789             200.504779
# 15276        SBIN -0.015214       11.491982             200.504779
# 15277  SHRIRAMFIN -0.009790       10.772656             200.504779
# 15278   UNIONBANK -0.015311       10.100908             200.504779
# 15279        VEDL -0.020996       12.277634             200.504779
# 15462    GOLDBEES -0.005727       26.969990                    NaN
# 15463  LIQUIDCASE  0.000177       38.966401                    NaN

# %%
total_value = max_date_tickers['Buy_Hold_Value'].sum()

# Calculate weights
max_date_tickers['Weight'] = max_date_tickers['Buy_Hold_Value'] / total_value

# Format as percentage (optional)
max_date_tickers['Weight_Percent'] = max_date_tickers['Weight']

max_date_tickers
# Out:
# C:\Users\anike\AppData\Local\Temp\ipykernel_21236\2488948854.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   max_date_tickers['Weight'] = max_date_tickers['Buy_Hold_Value'] / total_value
# C:\Users\anike\AppData\Local\Temp\ipykernel_21236\2488948854.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   max_date_tickers['Weight_Percent'] = max_date_tickers['Weight']
#             Date     Open     High      Low    Close      volume   oi  \
# 15260 2026-03-12  2019.90  2019.90  1937.20  1969.00    293352.0  0.0
# 15261 2026-03-12   184.66   184.97   178.06   178.06  11288031.0  0.0
# 15262 2026-03-12   287.00   288.80   282.95   287.70   2332799.0  0.0
# 15263 2026-03-12   151.00   153.09   149.81   152.65   2027036.0  0.0
# 15264 2026-03-12  1789.90  1790.10  1720.00  1763.70    714536.0  0.0
# 15265 2026-03-12   138.60   139.74   136.26   139.44   6532216.0  0.0
# 15266 2026-03-12   265.75   271.65   264.85   270.80   2371246.0  0.0
# 15267 2026-03-12   968.00   968.00   934.45   939.35   1407413.0  0.0
# 15268 2026-03-12   540.80   540.80   519.40   524.70   3608070.0  0.0
# 15269 2026-03-12   910.00   912.80   890.00   909.95    366587.0  0.0
# 15270 2026-03-12   157.40   159.89   154.06   159.53   9726712.0  0.0
# 15271 2026-03-12   350.00   352.30   344.00   345.15    402691.0  0.0
# 15272 2026-03-12    65.56    66.83    65.45    66.57   5123139.0  0.0
# 15273 2026-03-12  2512.70  2529.70  2466.90  2488.80    846152.0  0.0
# 15274 2026-03-12   403.50   403.95   385.95   392.50   7695631.0  0.0
# 15275 2026-03-12   153.01   153.08   149.60   151.04   3684614.0  0.0
# 15276 2026-03-12  1075.10  1082.00  1070.50  1074.50   4241565.0  0.0
# 15277 2026-03-12  1021.10  1028.00  1006.10  1021.60   2604333.0  0.0
# 15278 2026-03-12   179.52   179.52   175.52   178.15   5205358.0  0.0
# 15279 2026-03-12   730.25   730.30   704.55   706.40   4277041.0  0.0
# 15462 2026-03-12   131.90      NaN      NaN   131.95         NaN  NaN
# 15463 2026-03-12   113.11      NaN      NaN   113.10         NaN  NaN
#
#            Ticker   %change  Buy_Hold_Value  Total_Portfolio_Value    Weight  \
# 15260   APLAPOLLO -0.023459        8.432730             200.504779  0.031650
# 15261    ASHOKLEY -0.035741        9.278142             200.504779  0.034822
# 15262  BANKBARODA -0.005531        8.552119             200.504779  0.032098
# 15263   BANKINDIA -0.010693        9.533781             200.504779  0.035782
# 15264  BHARATFORG -0.018585        8.831630             200.504779  0.033147
# 15265       CANBK  0.000215        9.455758             200.504779  0.035489
# 15266  FEDERALBNK  0.005010        9.645178             200.504779  0.036200
# 15267    HINDALCO -0.020592       11.754075             200.504779  0.044115
# 15268  HINDCOPPER -0.033524        7.840201             200.504779  0.029426
# 15269     INDIANB -0.008553       10.229220             200.504779  0.038392
# 15270         IOC -0.006848        8.143908             200.504779  0.030566
# 15271      M&MFIN -0.022376        9.636434             200.504779  0.036167
# 15272    MAHABANK -0.007011        8.521804             200.504779  0.031984
# 15273         MCX -0.016906       10.089969             200.504779  0.037869
# 15274  NATIONALUM -0.013199       15.673860             200.504779  0.058827
# 15275        SAIL -0.018456       10.242789             200.504779  0.038443
# 15276        SBIN -0.015214       11.491982             200.504779  0.043131
# 15277  SHRIRAMFIN -0.009790       10.772656             200.504779  0.040432
# 15278   UNIONBANK -0.015311       10.100908             200.504779  0.037910
# 15279        VEDL -0.020996       12.277634             200.504779  0.046080
# 15462    GOLDBEES -0.005727       26.969990                    NaN  0.101223
# 15463  LIQUIDCASE  0.000177       38.966401                    NaN  0.146248
#
#        Weight_Percent
# 15260        0.031650
# 15261        0.034822
# 15262        0.032098
# 15263        0.035782
# 15264        0.033147
# 15265        0.035489
# 15266        0.036200
# 15267        0.044115
# 15268        0.029426
# 15269        0.038392
# 15270        0.030566
# 15271        0.036167
# 15272        0.031984
# 15273        0.037869
# 15274        0.058827
# 15275        0.038443
# 15276        0.043131
# 15277        0.040432
# 15278        0.037910
# 15279        0.046080
# 15462        0.101223
# 15463        0.146248

# %%
# Convert to dictionary
weights = dict(zip(max_date_tickers['Ticker'], max_date_tickers['Weight']))

weights
# Out:
# {'APLAPOLLO': 0.03164950218925274,
#  'ASHOKLEY': 0.034822478682284295,
#  'BANKBARODA': 0.03209758770375259,
#  'BANKINDIA': 0.03578193480279072,
#  'BHARATFORG': 0.03314664216642868,
#  'CANBK': 0.0354891041766107,
#  'FEDERALBNK': 0.036200029145294604,
#  'HINDALCO': 0.0441150861433418,
#  'HINDCOPPER': 0.029425635691471233,
#  'INDIANB': 0.03839203802013562,
#  'IOC': 0.030565503029036205,
#  'M&MFIN': 0.03616720978074659,
#  'MAHABANK': 0.03198381214541264,
#  'MCX': 0.03786940843420288,
#  'NATIONALUM': 0.058826720115667926,
#  'SAIL': 0.03844296596134328,
#  'SBIN': 0.04313140513324991,
#  'SHRIRAMFIN': 0.04043164986474954,
#  'UNIONBANK': 0.03791046282684913,
#  'VEDL': 0.046080093504612264,
#  'GOLDBEES': 0.10122305903302932,
#  'LIQUIDCASE': 0.14624767144973744}

# %%
tickers = list(max_date_tickers['Ticker'].unique()) + ['NIFTY 500']
# tickers = [
#     "ABCAPITAL",
#     "AIIL",
#     "BOSCHLTD",
#     "DATAPATTNS",
#     "DELHIVERY",
#     "ETERNAL",
#     "GOLDBEES",
#     "GVT&D",
#     "HBLENGINE",
#     "HEROMOTOCO",
#     "HINDCOPPER",
#     "HYUNDAI",
#     "IIFL",
#     "INTELLECT",
#     "LAURUSLABS",
#     "LTF",
#     "MFSL",
#     "NETWEB",
#     "POLYCAB",
#     "SYRMA",
#     "TATAINVEST",
#     "NIFTY 500"
# ]

# tickers

# %%
len(tickers)
# Out:
# 23

# %%
import time
import logging
import pandas as pd
from truedata import TD_hist

def fetch_truedata_history(
    ticker_list: list,
    duration: str = '1 Y',
    bar_size: str = 'EOD',
    sleep_time: float = 0.1
) -> tuple[pd.DataFrame, list]:
    """
    Fetches historical data from TrueData for a list of tickers.

    Parameters
    ----------
    username : str
        TrueData username.
    password : str
        TrueData password.
    ticker_list : list
        List of ticker symbols to fetch data for.
    duration : str, optional
        Duration of data (e.g., '1 Y', '25 Y', etc.). Default is '1 Y'.
    bar_size : str, optional
        Bar size for data ('EOD', 'WEEK', etc.). Default is 'EOD'.
    sleep_time : float, optional
        Delay between API calls to avoid throttling. Default is 0.2 seconds.

    Returns
    -------
    final_df : pd.DataFrame
        Combined DataFrame of all tickers' historical data.
    error_list : list
        List of tickers that failed to fetch.
    """
    logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
    username =  'tdwsf695'
    password = 'ocean@695'
    # username =  'td105'
    # password = 'sharma@105'
    # Initialize connection
    td_hist = TD_hist(username, password)
    df_list = []
    error_list = []
    for ticker in ticker_list:
        try:
            df = td_hist.get_historic_data([ticker], duration=duration, bar_size=bar_size)

            df['Ticker'] = ticker
            df = df.rename(columns={
                'timestamp': 'Date',
                'high': 'High',
                'low': 'Low',
                'close': 'Close',
                'open': 'Open'
            })

            df_list.append(df)
            logging.info(f"Fetched data for {ticker} ({len(df)} rows).")
            time.sleep(sleep_time)

        except Exception as e:
            logging.error(f"Failed to fetch data for {ticker}: {e}")
            error_list.append(ticker)

    final_df = pd.concat(df_list, ignore_index=True) if df_list else pd.DataFrame()
    return final_df, error_list

# %%
ticker_data = fetch_truedata_history(
        ticker_list = tickers,
        duration = '2 Y',
        bar_size = 'EOD',
        sleep_time= 0.1
    )[0][['Ticker','Date', 'Close']]
ticker_data
# Out:
# (2026-03-12 10:57:24,108) WARNING :: Connected successfully to TrueData Historical Data Service...  (PID:21236 Thread:2984)
# 2026-03-12 10:57:24,108 - WARNING - Connected successfully to TrueData Historical Data Service...
# 2026-03-12 10:57:24,640 - INFO - Fetched data for APLAPOLLO (497 rows).
# 2026-03-12 10:57:25,171 - INFO - Fetched data for ASHOKLEY (497 rows).
# 2026-03-12 10:57:25,667 - INFO - Fetched data for BANKBARODA (497 rows).
# 2026-03-12 10:57:26,224 - INFO - Fetched data for BANKINDIA (497 rows).
# 2026-03-12 10:57:26,739 - INFO - Fetched data for BHARATFORG (497 rows).
# 2026-03-12 10:57:27,258 - INFO - Fetched data for CANBK (497 rows).
# 2026-03-12 10:57:27,857 - INFO - Fetched data for FEDERALBNK (497 rows).
# 2026-03-12 10:57:28,349 - INFO - Fetched data for HINDALCO (497 rows).
# 2026-03-12 10:57:28,944 - INFO - Fetched data for HINDCOPPER (497 rows).
# 2026-03-12 10:57:29,556 - INFO - Fetched data for INDIANB (497 rows).
# 2026-03-12 10:57:30,108 - INFO - Fetched data for IOC (497 rows).
# 2026-03-12 10:57:30,668 - INFO - Fetched data for M&MFIN (497 rows).
# 2026-03-12 10:57:31,282 - INFO - Fetched data for MAHABANK (497 rows).
# 2026-03-12 10:57:31,845 - INFO - Fetched data for MCX (497 rows).
# 2026-03-12 10:57:32,378 - INFO - Fetched data for NATIONALUM (497 rows).
# 2026-03-12 10:57:32,890 - INFO - Fetched data for SAIL (497 rows).
# 2026-03-12 10:57:33,505 - INFO - Fetched data for SBIN (497 rows).
# 2026-03-12 10:57:34,177 - INFO - Fetched data for SHRIRAMFIN (497 rows).
# 2026-03-12 10:57:34,793 - INFO - Fetched data for UNIONBANK (497 rows).
# 2026-03-12 10:57:35,342 - INFO - Fetched data for VEDL (497 rows).
# 2026-03-12 10:57:35,944 - INFO - Fetched data for GOLDBEES (497 rows).
# 2026-03-12 10:57:36,466 - INFO - Fetched data for LIQUIDCASE (497 rows).
# 2026-03-12 10:57:36,959 - INFO - Fetched data for NIFTY 500 (497 rows).
#           Ticker       Date     Close
# 0      APLAPOLLO 2024-03-12   1592.60
# 1      APLAPOLLO 2024-03-13   1492.45
# 2      APLAPOLLO 2024-03-14   1495.60
# 3      APLAPOLLO 2024-03-15   1474.70
# 4      APLAPOLLO 2024-03-18   1547.35
# ...          ...        ...       ...
# 11426  NIFTY 500 2026-03-06  22481.30
# 11427  NIFTY 500 2026-03-09  22056.55
# 11428  NIFTY 500 2026-03-10  22342.95
# 11429  NIFTY 500 2026-03-11  22042.30
# 11430  NIFTY 500 2026-03-12  21861.25
#
# [11431 rows x 3 columns]

# %%
ticker_data[ticker_data.duplicated(subset=['Ticker', 'Date'])]
# Out:
# Empty DataFrame
# Columns: [Ticker, Date, Close]
# Index: []

# %%
ticker_data = ticker_data.drop_duplicates(subset=['Ticker', 'Date'])

# %%
# ticker_data[ticker_data['Ticker'] == 'MOGSEC'].to_excel('MOGSEC.xlsx', index=False)

# %%
ticker_data.pivot(index="Date", columns="Ticker", values="Close").sort_index()
# Out:
# Ticker      APLAPOLLO  ASHOKLEY  BANKBARODA  BANKINDIA  BHARATFORG   CANBK  \
# Date
# 2024-03-12    1592.60     83.65      271.60     140.20     1155.85  113.40
# 2024-03-13    1492.45     79.90      260.90     128.45     1127.00  107.30
# 2024-03-14    1495.60     82.05      259.20     130.40     1113.05  109.40
# 2024-03-15    1474.70     80.95      254.00     134.30     1119.50  109.85
# 2024-03-18    1547.35     81.30      254.50     133.10     1114.40  110.60
# ...               ...       ...         ...        ...         ...     ...
# 2026-03-06    2152.80    194.67      295.35     159.58     1923.90  145.97
# 2026-03-09    2097.90    186.94      288.05     151.29     1862.30  139.91
# 2026-03-10    2100.60    193.56      294.40     156.17     1842.20  142.27
# 2026-03-11    2016.30    184.66      289.30     154.30     1797.10  139.41
# 2026-03-12    1969.10    178.23      287.80     152.79     1765.10  139.63
#
# Ticker      FEDERALBNK  GOLDBEES  HINDALCO  HINDCOPPER  ...  M&MFIN  MAHABANK  \
# Date                                                    ...
# 2024-03-12      151.75     55.94    528.95      256.10  ...  273.25     58.70
# 2024-03-13      148.50     55.47    507.00      235.05  ...  256.70     54.20
# 2024-03-14      146.05     55.84    525.25      262.70  ...  259.15     58.30
# 2024-03-15      150.45     55.73    532.55      271.15  ...  254.05     59.40
# 2024-03-18      147.35     55.50    531.15      269.25  ...  253.15     58.80
# ...                ...       ...       ...         ...  ...     ...       ...
# 2026-03-06      286.50    130.82    958.90      558.60  ...  363.50     70.13
# 2026-03-09      273.30    131.35    945.35      540.55  ...  347.85     65.69
# 2026-03-10      276.00    132.20    956.60      548.95  ...  360.70     68.77
# 2026-03-11      269.45    132.71    959.10      542.90  ...  353.05     67.04
# 2026-03-12      271.25    131.83    939.80      526.20  ...  345.75     66.60
#
# Ticker          MCX  NATIONALUM  NIFTY 500    SAIL     SBIN  SHRIRAMFIN  \
# Date
# 2024-03-12   689.25      151.65   20171.40  129.75   759.70      484.35
# 2024-03-13   642.10      136.15   19646.30  118.70   747.25      464.30
# 2024-03-14   643.25      141.45   19916.35  121.50   741.05      458.30
# 2024-03-15   651.70      136.40   19825.20  121.70   731.90      453.35
# 2024-03-18   639.00      139.10   19843.10  125.95   730.95      461.80
# ...             ...         ...        ...     ...      ...         ...
# 2026-03-06  2533.90      396.15   22481.30  154.94  1143.00     1007.50
# 2026-03-09  2577.10      388.10   22056.55  149.52  1098.50      987.20
# 2026-03-10  2578.20      388.75   22342.95  149.84  1112.20     1062.90
# 2026-03-11  2531.60      397.75   22042.30  153.88  1091.10     1031.70
# 2026-03-12  2483.30      393.20   21861.25  151.25  1076.30     1023.70
#
# Ticker      UNIONBANK    VEDL
# Date
# 2024-03-12     150.40  270.30
# 2024-03-13     141.55  251.90
# 2024-03-14     143.65  260.15
# 2024-03-15     148.00  265.10
# 2024-03-18     153.25  271.05
# ...               ...     ...
# 2026-03-06     188.65  721.00
# 2026-03-09     179.06  709.40
# 2026-03-10     186.30  722.00
# 2026-03-11     180.92  721.55
# 2026-03-12     178.52  706.05
#
# [497 rows x 23 columns]

# %%
ticker_data['Ticker'].nunique()
# Out:
# 23

# %%
weights
# Out:
# {'APLAPOLLO': 0.03164950218925274,
#  'ASHOKLEY': 0.034822478682284295,
#  'BANKBARODA': 0.03209758770375259,
#  'BANKINDIA': 0.03578193480279072,
#  'BHARATFORG': 0.03314664216642868,
#  'CANBK': 0.0354891041766107,
#  'FEDERALBNK': 0.036200029145294604,
#  'HINDALCO': 0.0441150861433418,
#  'HINDCOPPER': 0.029425635691471233,
#  'INDIANB': 0.03839203802013562,
#  'IOC': 0.030565503029036205,
#  'M&MFIN': 0.03616720978074659,
#  'MAHABANK': 0.03198381214541264,
#  'MCX': 0.03786940843420288,
#  'NATIONALUM': 0.058826720115667926,
#  'SAIL': 0.03844296596134328,
#  'SBIN': 0.04313140513324991,
#  'SHRIRAMFIN': 0.04043164986474954,
#  'UNIONBANK': 0.03791046282684913,
#  'VEDL': 0.046080093504612264,
#  'GOLDBEES': 0.10122305903302932,
#  'LIQUIDCASE': 0.14624767144973744}

# %%
import pandas as pd
import numpy as np

def calculate_portfolio_beta_from_df(df, benchmark_name, weights_dict=None):
    """
    df: DataFrame with columns ['Ticker','Date','Close']
    benchmark_name: name used in the 'Ticker' column for your benchmark
    weights_dict: {'ABCAPITAL':0.1, 'BOSCHLTD':0.05, ...}
    """

    df['Date'] = pd.to_datetime(df['Date'])


    # Pivot → Date index, ticker columns
    price_df = df.pivot(index="Date", columns="Ticker", values="Close").sort_index()

    # keep only last 1 year
    price_df = price_df.last("252D")
    # print(price_df)

    # print(price_df)

    # Extract benchmark + stocks separately
    benchmark = price_df[benchmark_name]
    stock_prices = price_df.drop(columns=[benchmark_name])

    # daily returns
    returns = price_df.pct_change().dropna()
    stock_returns = returns.drop(columns=[benchmark_name])
    bench_ret = returns[benchmark_name]

    # weights: equal-weight if not given
    if weights_dict is None:
        n = stock_returns.shape[1]
        weights_dict = {col: 1/n for col in stock_returns.columns}

    weights = pd.Series(weights_dict).reindex(stock_returns.columns).fillna(0)

    # portfolio daily return
    portfolio_ret = (stock_returns * weights).sum(axis=1)

    # beta = Cov(portfolio, benchmark) / Var(benchmark)
    covariance = np.cov(portfolio_ret, bench_ret)[0][1]
    variance = np.var(bench_ret)

    beta = covariance / variance

    return beta, portfolio_ret, bench_ret

# %%
calculate_portfolio_beta_from_df(ticker_data, 'NIFTY 500', weights)[0]
# Out:
# C:\Users\anike\AppData\Local\Temp\ipykernel_21236\2096940647.py:18: FutureWarning: last is deprecated and will be removed in a future version. Please create a mask and filter using `.loc` instead
#   price_df = price_df.last("252D")
# np.float64(1.09618078134501)

# %%
current_beta = pd.DataFrame({'Beta': [calculate_portfolio_beta_from_df(ticker_data, 'NIFTY 500', weights)[0]]})
current_beta.to_excel('momentum_ratios.xlsx', index=False)
current_beta
# Out:
# C:\Users\anike\AppData\Local\Temp\ipykernel_21236\2096940647.py:18: FutureWarning: last is deprecated and will be removed in a future version. Please create a mask and filter using `.loc` instead
#   price_df = price_df.last("252D")
#        Beta
# 0  1.096181
