# %%
import time
import logging
import pandas as pd
from truedata import TD_hist

def fetch_truedata_history(
    username: str,
    password: str,
    ticker_list: list,
    duration: str = '1 Y',
    bar_size: str = 'EOD',
    sleep_time: float = 0.1
) -> tuple[pd.DataFrame, list]:
    """
    Fetches historical data from TrueData for a list of tickers.

    Parameters
    ----------
    username : str
        TrueData username.
    password : str
        TrueData password.
    ticker_list : list
        List of ticker symbols to fetch data for.
    duration : str, optional
        Duration of data (e.g., '1 Y', '25 Y', etc.). Default is '1 Y'.
    bar_size : str, optional
        Bar size for data ('EOD', 'WEEK', etc.). Default is 'EOD'.
    sleep_time : float, optional
        Delay between API calls to avoid throttling. Default is 0.2 seconds.

    Returns
    -------
    final_df : pd.DataFrame
        Combined DataFrame of all tickers' historical data.
    error_list : list
        List of tickers that failed to fetch.
    """
    logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

    # Initialize connection
    td_hist = TD_hist(username, password)

    df_list = []
    error_list = []

    for ticker in ticker_list:
        try:
            df = td_hist.get_historic_data([ticker], duration=duration, bar_size=bar_size)

            df['Ticker'] = ticker
            df = df.rename(columns={
                'timestamp': 'Date',
                'high': 'High',
                'low': 'Low',
                'close': 'Close',
                'open': 'Open'
            })

            df_list.append(df)
            logging.info(f"Fetched data for {ticker} ({len(df)} rows).")
            time.sleep(sleep_time)

        except Exception as e:
            logging.error(f"Failed to fetch data for {ticker}: {e}")
            error_list.append(ticker)

    final_df = pd.concat(df_list, ignore_index=True) if df_list else pd.DataFrame()
    return final_df, error_list

# %%
import numpy as np
import pandas as pd
from datetime import datetime
from dateutil.relativedelta import relativedelta
import yfinance as yf
from pathlib import Path

import os

def run_momentum_strategy(universe_file: str,
                          start_date: str,
                          end_date: str,
                          top_n: int,
                          output_root: str = "Momentum_Results") -> str:
    """
    Run rolling-window momentum strategy on given stock universe.

    Parameters
    ----------
    universe_file : str
        Path to universe file (.csv or .xlsx) with columns ["Symbol", "ISIN Code"].
    start_date : str
        Start date for backtest (YYYY-MM-DD).
    end_date : str
        End date for backtest (YYYY-MM-DD).
    top_n : int
        Number of top ranked stocks to select each window.
    output_root : str
        Root folder where results will be saved.

    Returns
    -------
    str
        Path to master summary file.
    """


    # ==== 1. Load Universe ====
    if universe_file.endswith(".csv"):
        stock_list = pd.read_csv(universe_file)[["Symbol", "ISIN Code"]]
    else:
        stock_list = pd.read_excel(universe_file)[["Symbol", "ISIN Code"]]
    # username = 'tdwsf695'
    # password = 'ocean@695'
    
    username = 'td105'
    password = 'sharma@105'
    # stock_list["Ticker"] = stock_list["Symbol"] + ".NS"
    stock_list["Ticker"] = stock_list["Symbol"] 
    symbol_list = stock_list["Symbol"].tolist()
    universe_name = Path(universe_file).stem
    output_dir = os.path.join(output_root, f"{universe_name}_{top_n}_stocks_results")
    os.makedirs(output_dir, exist_ok=True)

    # ==== 2. Download Data ====
    total_start = pd.to_datetime(start_date)
    total_end = pd.to_datetime(end_date)

    print(f"\n📥 Downloading price data for {len(symbol_list)} symbols...")
    # data = yf.download(symbol_list, start=total_start.strftime('%Y-%m-%d'),
    #                    end=total_end.strftime('%Y-%m-%d'), progress=True)
    # prices_all = data["Close"]
    # prices_all.index = pd.to_datetime(prices_all.index)
    # print("✅ Download complete.")

    data, errors = fetch_truedata_history(username, password, symbol_list, duration='10 Y', bar_size='EOD')
    data = data[['Date', 'Close', 'Ticker']]
    data.drop_duplicates(subset=['Date', 'Ticker'], inplace=True)
    print(data)
    print("Failed tickers:", errors)
    prices = data.pivot(index="Date", columns="Ticker", values="Close")  
    # optional: sort by date
    prices_all = prices.sort_index()



    # ==== 3. Create Rolling Windows ====
    windows = []
    current_start = total_start
    while True:
        current_end = current_start + relativedelta(months=6)
        if current_end > total_end:
            break
        window_prices = prices_all.loc[(prices_all.index >= current_start) & (prices_all.index < current_end)].copy()
        if not window_prices.empty:
            windows.append((current_start, current_end, window_prices))
        current_start += relativedelta(months=1)

    print(f"📊 Created {len(windows)} rolling windows.")

    # ==== 4. Process Each Window ====
    for start, end, prices in windows:
        file_suffix = f"{start.strftime('%Y%m%d')}_{end.strftime('%Y%m%d')}"
        print(f"\n🔍 Processing window: {start.date()} → {end.date()}")

        prices.dropna(axis=1, how='all', inplace=True)
        if prices.empty:
            print("⚠️ All price data missing. Skipping window.")
            continue

        # Monthly momentum
        monthclose = prices.groupby(prices.index.strftime('%Y-%m')).tail(1)
        monthstart = prices.groupby(prices.index.strftime('%Y-%m')).head(1)
        monthstart.index = monthclose.index
        monchange = (monthclose - monthstart) / monthstart
        MOM = (monchange + 1).product() - 1
        mom = MOM * 100

        # Daily returns
        daily_ret = prices.pct_change(fill_method=None)
        positivechange = (daily_ret[daily_ret > 0].count() / daily_ret.count()) * 100
        negativechange = (daily_ret[daily_ret < 0].count() / daily_ret.count()) * 100

        result = pd.concat([positivechange, negativechange, mom], axis=1, join='inner')
        result.columns = ["Positive", "Negative", "Momentum"]
        result = result.reset_index().rename(columns={'index': 'Ticker'})

        # Merge ISIN
        result = pd.merge(result, stock_list[["Ticker", "ISIN Code"]], on="Ticker", how="left")

        # Ranking
        df = result.copy()
        df["Rank_Mom"] = df["Momentum"].rank(method='min', ascending=False)
        print('rank df:', df)
        df['FIP'] = df.apply(lambda row: row['Negative'] - row['Positive'] if row['Momentum'] > 0 else np.nan, axis=1)
        # df['FIP'] = df.apply(lambda row: row['Negative'] - row['Positive'])

        df.dropna(inplace=True)
        df["FIP_rank"] = df["FIP"].rank(method="first", ascending=True)
        df["Combined_Rank"] = df["Rank_Mom"] + df["FIP_rank"]
        if end.strftime('%Y-%m-%d') == '2026-01-01':
            df = df[~(df['Ticker'].isin(['MARUTI', 'PTCIL']))]

        df = df.sort_values(by="Combined_Rank", ascending=True).head(top_n)
        df["Real_Rank"] = range(1, len(df) + 1)
        df["End_Date"] = end.strftime('%Y-%m-%d')


        # Save each window
        output_file = os.path.join(output_dir, f"momentum_{file_suffix}.xlsx")
        df.to_excel(output_file, index=False)
        print(f"✅ Saved results to: {output_file}")

    # ==== 5. Master File ====
    print("\n📂 Creating master summary file...")
    master_data = []
    for file in os.listdir(output_dir):
        if file.startswith("momentum_") and file.endswith(".xlsx"):
            df = pd.read_excel(os.path.join(output_dir, file))
            selected_df = df[["End_Date", "ISIN Code", "Ticker", 'Real_Rank']].copy()
            master_data.append(selected_df)

    if master_data:
        master_df = pd.concat(master_data, ignore_index=True)
        master_file_path = os.path.join(output_dir, "master_momentum_summary.xlsx")
        master_df.to_excel(master_file_path, index=False)
        print(f"✅ Master file saved to: {master_file_path}")
        return master_file_path
    else:
        print("⚠️ No window files found, master not created.")
        return None

# %%
# Momentum/Automating Momentum/Universe/Nifty_500_2025_Apr.csv
# "C:\Users\Admin\Momentum\Automating Momentum\Universe\Nifty_500_2025_Apr.csv"
master_file = run_momentum_strategy(
    universe_file=r"Universe/Nifty_500_2025_Apr.csv",
    start_date="2022-06-01",
    end_date="2026-01-01",
    top_n=20,
    output_root="Stocks"
)
print("Master summary located at:", master_file)
# Out:
# 📥 Downloading price data for 503 symbols...
# (2026-01-12 14:38:05,997) WARNING :: Connected successfully to TrueData Historical Data Service...  (PID:4220 Thread:26632)
# 2026-01-12 14:38:05,997 - WARNING - Connected successfully to TrueData Historical Data Service...
# 2026-01-12 14:38:06,723 - INFO - Fetched data for 360ONE (1569 rows).
# 2026-01-12 14:38:08,034 - INFO - Fetched data for 3MINDIA (2476 rows).
# 2026-01-12 14:38:08,919 - INFO - Fetched data for ABB (2476 rows).
# 2026-01-12 14:38:10,222 - INFO - Fetched data for ACC (2476 rows).
# 2026-01-12 14:38:10,818 - INFO - Fetched data for ACMESOLAR (289 rows).
# 2026-01-12 14:38:11,494 - INFO - Fetched data for AIAENG (2476 rows).
# 2026-01-12 14:38:12,235 - INFO - Fetched data for APLAPOLLO (2476 rows).
# 2026-01-12 14:38:13,892 - INFO - Fetched data for AUBANK (2111 rows).
# 2026-01-12 14:38:14,584 - INFO - Fetched data for AWL (975 rows).
# 2026-01-12 14:38:15,184 - INFO - Fetched data for AADHARHFC (414 rows).
# 2026-01-12 14:38:16,044 - INFO - Fetched data for AARTIIND (2476 rows).
# 2026-01-12 14:38:17,475 - INFO - Fetched data for AAVAS (1802 rows).
# 2026-01-12 14:38:18,157 - INFO - Fetched data for ABBOTINDIA (2476 rows).
# 2026-01-12 14:38:18,947 - INFO - Fetched data for ACE (2476 rows).
# 2026-01-12 14:38:19,596 - INFO - Fetched data for ADANIENSOL (593 rows).
# 2026-01-12 14:38:20,309 - INFO - Fetched data for ADANIENT (2476 rows).
# 2026-01-12 14:38:20,986 - INFO - Fetched data for ADANIGREEN (1877 rows).
# 2026-01-12 14:38:21,681 - INFO - Fetched data for ADANIPORTS (2476 rows).
# 2026-01-12 14:38:22,399 - INFO - Fetched data for ADANIPOWER (2476 rows).
# 2026-01-12 14:38:23,205 - INFO - Fetched data for ATGL (1782 rows).
# 2026-01-12 14:38:23,887 - INFO - Fetched data for ABCAPITAL (2074 rows).
# 2026-01-12 14:38:24,640 - INFO - Fetched data for ABFRL (2476 rows).
# 2026-01-12 14:38:25,315 - INFO - Fetched data for ABREL (2476 rows).
# 2026-01-12 14:38:25,964 - INFO - Fetched data for ABSLAMC (1057 rows).
# 2026-01-12 14:38:26,668 - INFO - Fetched data for AEGISLOG (2476 rows).
# 2026-01-12 14:38:27,254 - INFO - Fetched data for AFCONS (296 rows).
# 2026-01-12 14:38:27,925 - INFO - Fetched data for AFFLE (1595 rows).
# 2026-01-12 14:38:28,620 - INFO - Fetched data for AJANTPHARM (2476 rows).
# 2026-01-12 14:38:29,216 - INFO - Fetched data for AKUMS (358 rows).
# 2026-01-12 14:38:29,893 - INFO - Fetched data for APLLTD (2476 rows).
# 2026-01-12 14:38:30,526 - INFO - Fetched data for ALIVUS (1101 rows).
# 2026-01-12 14:38:31,281 - INFO - Fetched data for ALKEM (2476 rows).
# 2026-01-12 14:38:32,011 - INFO - Fetched data for ALKYLAMINE (2476 rows).
# 2026-01-12 14:38:32,775 - INFO - Fetched data for ALOKINDS (1464 rows).
# 2026-01-12 14:38:33,468 - INFO - Fetched data for ARE&M (550 rows).
# 2026-01-12 14:38:34,190 - INFO - Fetched data for AMBER (1971 rows).
# 2026-01-12 14:38:34,932 - INFO - Fetched data for AMBUJACEM (2476 rows).
# 2026-01-12 14:38:35,587 - INFO - Fetched data for ANANDRATHI (1014 rows).
# 2026-01-12 14:38:36,270 - INFO - Fetched data for ANANTRAJ (2476 rows).
# 2026-01-12 14:38:36,932 - INFO - Fetched data for ANGELONE (1309 rows).
# 2026-01-12 14:38:37,684 - INFO - Fetched data for APARINDS (2476 rows).
# 2026-01-12 14:38:38,389 - INFO - Fetched data for APOLLOHOSP (2476 rows).
# 2026-01-12 14:38:39,060 - INFO - Fetched data for APOLLOTYRE (2476 rows).
# 2026-01-12 14:38:39,835 - INFO - Fetched data for APTUS (1090 rows).
# 2026-01-12 14:38:40,554 - INFO - Fetched data for ASAHIINDIA (2476 rows).
# 2026-01-12 14:38:41,279 - INFO - Fetched data for ASHOKLEY (2476 rows).
# 2026-01-12 14:38:41,954 - INFO - Fetched data for ASIANPAINT (2476 rows).
# 2026-01-12 14:38:42,579 - INFO - Fetched data for ASTERDM (1953 rows).
# 2026-01-12 14:38:43,273 - INFO - Fetched data for ASTRAZEN (2476 rows).
# 2026-01-12 14:38:43,963 - INFO - Fetched data for ASTRAL (2476 rows).
# 2026-01-12 14:38:44,676 - INFO - Fetched data for ATUL (2476 rows).
# 2026-01-12 14:38:45,421 - INFO - Fetched data for AUROPHARMA (2476 rows).
# 2026-01-12 14:38:46,018 - INFO - Fetched data for AIIL (430 rows).
# 2026-01-12 14:38:46,814 - INFO - Fetched data for DMART (2186 rows).
# 2026-01-12 14:38:47,508 - INFO - Fetched data for AXISBANK (2476 rows).
# 2026-01-12 14:38:48,226 - INFO - Fetched data for BASF (2476 rows).
# 2026-01-12 14:38:48,907 - INFO - Fetched data for BEML (2476 rows).
# 2026-01-12 14:38:49,596 - INFO - Fetched data for BLS (2375 rows).
# 2026-01-12 14:38:50,261 - INFO - Fetched data for BSE (2216 rows).
# 2026-01-12 14:38:50,946 - INFO - Fetched data for BAJAJ-AUTO (2476 rows).
# 2026-01-12 14:38:51,603 - INFO - Fetched data for BAJFINANCE (2476 rows).
# 2026-01-12 14:38:52,309 - INFO - Fetched data for BAJAJFINSV (2476 rows).
# 2026-01-12 14:38:52,971 - INFO - Fetched data for BAJAJHLDNG (2476 rows).
# 2026-01-12 14:38:53,548 - INFO - Fetched data for BAJAJHFL (330 rows).
# 2026-01-12 14:38:54,199 - INFO - Fetched data for BALKRISIND (2476 rows).
# 2026-01-12 14:38:54,876 - INFO - Fetched data for BALRAMCHIN (2476 rows).
# 2026-01-12 14:38:55,619 - INFO - Fetched data for BANDHANBNK (1933 rows).
# 2026-01-12 14:38:56,313 - INFO - Fetched data for BANKBARODA (2476 rows).
# 2026-01-12 14:38:56,992 - INFO - Fetched data for BANKINDIA (2476 rows).
# 2026-01-12 14:38:57,677 - INFO - Fetched data for MAHABANK (2476 rows).
# 2026-01-12 14:38:58,538 - INFO - Fetched data for BATAINDIA (2476 rows).
# 2026-01-12 14:38:59,269 - INFO - Fetched data for BAYERCROP (2476 rows).
# 2026-01-12 14:39:00,118 - INFO - Fetched data for BERGEPAINT (2476 rows).
# 2026-01-12 14:39:00,737 - INFO - Fetched data for BDL (1935 rows).
# 2026-01-12 14:39:01,388 - INFO - Fetched data for BEL (2476 rows).
# 2026-01-12 14:39:02,093 - INFO - Fetched data for BHARATFORG (2476 rows).
# 2026-01-12 14:39:02,771 - INFO - Fetched data for BHEL (2476 rows).
# 2026-01-12 14:39:03,439 - INFO - Fetched data for BPCL (2476 rows).
# 2026-01-12 14:39:04,096 - INFO - Fetched data for BHARTIARTL (2476 rows).
# 2026-01-12 14:39:04,687 - INFO - Fetched data for BHARTIHEXA (436 rows).
# 2026-01-12 14:39:05,331 - INFO - Fetched data for BIKAJI (785 rows).
# 2026-01-12 14:39:06,142 - INFO - Fetched data for BIOCON (2476 rows).
# 2026-01-12 14:39:08,404 - INFO - Fetched data for BSOFT (2476 rows).
# 2026-01-12 14:39:09,061 - INFO - Fetched data for BLUEDART (2476 rows).
# 2026-01-12 14:39:09,762 - INFO - Fetched data for BLUESTARCO (2476 rows).
# 2026-01-12 14:39:10,989 - INFO - Fetched data for BBTC (2476 rows).
# 2026-01-12 14:39:11,661 - INFO - Fetched data for BOSCHLTD (2476 rows).
# 2026-01-12 14:39:12,250 - INFO - Fetched data for FIRSTCRY (353 rows).
# 2026-01-12 14:39:12,974 - INFO - Fetched data for BRIGADE (2476 rows).
# 2026-01-12 14:39:13,817 - INFO - Fetched data for BRITANNIA (2476 rows).
# 2026-01-12 14:39:14,678 - INFO - Fetched data for MAPMYINDIA (1009 rows).
# 2026-01-12 14:39:15,331 - INFO - Fetched data for CCL (2476 rows).
# 2026-01-12 14:39:16,040 - INFO - Fetched data for CESC (2476 rows).
# 2026-01-12 14:39:16,687 - INFO - Fetched data for CGPOWER (2476 rows).
# 2026-01-12 14:39:17,500 - INFO - Fetched data for CRISIL (2476 rows).
# 2026-01-12 14:39:18,165 - INFO - Fetched data for CAMPUS (916 rows).
# 2026-01-12 14:39:18,827 - INFO - Fetched data for CANFINHOME (2476 rows).
# 2026-01-12 14:39:19,688 - INFO - Fetched data for CANBK (2476 rows).
# 2026-01-12 14:39:20,405 - INFO - Fetched data for CAPLIPOINT (2476 rows).
# 2026-01-12 14:39:21,127 - INFO - Fetched data for CGCL (2476 rows).
# 2026-01-12 14:39:21,865 - INFO - Fetched data for CARBORUNIV (2476 rows).
# 2026-01-12 14:39:22,718 - INFO - Fetched data for CASTROLIND (2476 rows).
# 2026-01-12 14:39:23,438 - INFO - Fetched data for CEATLTD (2476 rows).
# 2026-01-12 14:39:24,176 - INFO - Fetched data for CENTRALBK (2476 rows).
# 2026-01-12 14:39:26,337 - INFO - Fetched data for CDSL (2117 rows).
# 2026-01-12 14:39:27,049 - INFO - Fetched data for CENTURYPLY (2476 rows).
# 2026-01-12 14:39:27,772 - INFO - Fetched data for CERA (2476 rows).
# 2026-01-12 14:39:28,459 - INFO - Fetched data for CHALET (1718 rows).
# 2026-01-12 14:39:29,159 - INFO - Fetched data for CHAMBLFERT (2476 rows).
# 2026-01-12 14:39:29,829 - INFO - Fetched data for CHENNPETRO (2476 rows).
# 2026-01-12 14:39:30,507 - INFO - Fetched data for CHOLAHLDNG (2058 rows).
# 2026-01-12 14:39:31,152 - INFO - Fetched data for CHOLAFIN (2476 rows).
# 2026-01-12 14:39:31,870 - INFO - Fetched data for CIPLA (2476 rows).
# 2026-01-12 14:39:32,533 - INFO - Fetched data for CUB (2476 rows).
# 2026-01-12 14:39:33,303 - INFO - Fetched data for CLEAN (1113 rows).
# 2026-01-12 14:39:34,089 - INFO - Fetched data for COALINDIA (2476 rows).
# 2026-01-12 14:39:34,819 - INFO - Fetched data for COCHINSHIP (2087 rows).
# 2026-01-12 14:39:36,270 - INFO - Fetched data for COFORGE (2476 rows).
# 2026-01-12 14:39:36,927 - INFO - Fetched data for COHANCE (1452 rows).
# 2026-01-12 14:39:38,253 - INFO - Fetched data for COLPAL (2476 rows).
# 2026-01-12 14:39:38,923 - INFO - Fetched data for CAMS (1310 rows).
# 2026-01-12 14:39:39,563 - INFO - Fetched data for CONCORDBIO (597 rows).
# 2026-01-12 14:39:40,294 - INFO - Fetched data for CONCOR (2476 rows).
# 2026-01-12 14:39:40,943 - INFO - Fetched data for COROMANDEL (2476 rows).
# 2026-01-12 14:39:41,640 - INFO - Fetched data for CRAFTSMAN (1190 rows).
# 2026-01-12 14:39:42,274 - INFO - Fetched data for CREDITACC (1831 rows).
# 2026-01-12 14:39:42,976 - INFO - Fetched data for CROMPTON (2398 rows).
# 2026-01-12 14:39:43,687 - INFO - Fetched data for CUMMINSIND (2476 rows).
# 2026-01-12 14:39:44,368 - INFO - Fetched data for CYIENT (2476 rows).
# 2026-01-12 14:39:45,051 - INFO - Fetched data for DCMSHRIRAM (2476 rows).
# 2026-01-12 14:39:46,943 - INFO - Fetched data for DLF (2476 rows).
# 2026-01-12 14:39:48,501 - INFO - Fetched data for DOMS (513 rows).
# 2026-01-12 14:39:50,203 - INFO - Fetched data for DABUR (2476 rows).
# 2026-01-12 14:39:50,890 - INFO - Fetched data for DALBHARAT (1730 rows).
# 2026-01-12 14:39:51,680 - INFO - Fetched data for DATAPATTNS (1006 rows).
# 2026-01-12 14:39:52,388 - INFO - Fetched data for DEEPAKFERT (2476 rows).
# 2026-01-12 14:39:54,209 - INFO - Fetched data for DEEPAKNTR (2476 rows).
# 2026-01-12 14:39:55,910 - INFO - Fetched data for DELHIVERY (905 rows).
# 2026-01-12 14:39:57,006 - INFO - Fetched data for DEVYANI (1095 rows).
# 2026-01-12 14:39:57,677 - INFO - Fetched data for DIVISLAB (2476 rows).
# 2026-01-12 14:39:58,337 - INFO - Fetched data for DIXON (2063 rows).
# 2026-01-12 14:39:59,024 - INFO - Fetched data for LALPATHLAB (2476 rows).
# 2026-01-12 14:40:00,993 - INFO - Fetched data for DRREDDY (2476 rows).
# (2026-01-12 14:40:01,587) ERROR :: <class 'AttributeError'> -> 'DataFrame' object has no attribute 'timestamp' (PID:4220 Thread:26632)
# 2026-01-12 14:40:01,587 - ERROR - <class 'AttributeError'> -> 'DataFrame' object has no attribute 'timestamp'
# 2026-01-12 14:40:01,589 - ERROR - Failed to fetch data for DUMMYABFRL: 'NoneType' object does not support item assignment
# (2026-01-12 14:40:02,157) ERROR :: <class 'AttributeError'> -> 'DataFrame' object has no attribute 'timestamp' (PID:4220 Thread:26632)
# 2026-01-12 14:40:02,157 - ERROR - <class 'AttributeError'> -> 'DataFrame' object has no attribute 'timestamp'
# 2026-01-12 14:40:02,161 - ERROR - Failed to fetch data for DUMMYSIEMS: 'NoneType' object does not support item assignment
# (2026-01-12 14:40:02,655) ERROR :: <class 'AttributeError'> -> 'DataFrame' object has no attribute 'timestamp' (PID:4220 Thread:26632)
# 2026-01-12 14:40:02,655 - ERROR - <class 'AttributeError'> -> 'DataFrame' object has no attribute 'timestamp'
# 2026-01-12 14:40:02,659 - ERROR - Failed to fetch data for DUMMYRAYMN: 'NoneType' object does not support item assignment
# 2026-01-12 14:40:03,237 - INFO - Fetched data for EIDPARRY (2476 rows).
# 2026-01-12 14:40:03,930 - INFO - Fetched data for EIHOTEL (2476 rows).
# 2026-01-12 14:40:04,588 - INFO - Fetched data for EICHERMOT (2476 rows).
# 2026-01-12 14:40:05,249 - INFO - Fetched data for ELECON (2476 rows).
# 2026-01-12 14:40:05,904 - INFO - Fetched data for ELGIEQUIP (2476 rows).
# 2026-01-12 14:40:06,604 - INFO - Fetched data for EMAMILTD (2476 rows).
# 2026-01-12 14:40:07,184 - INFO - Fetched data for EMCURE (376 rows).
# 2026-01-12 14:40:07,856 - INFO - Fetched data for ENDURANCE (2291 rows).
# 2026-01-12 14:40:08,522 - INFO - Fetched data for ENGINERSIN (2476 rows).
# 2026-01-12 14:40:09,187 - INFO - Fetched data for ERIS (2118 rows).
# 2026-01-12 14:40:09,876 - INFO - Fetched data for ESCORTS (2476 rows).
# 2026-01-12 14:40:10,506 - INFO - Fetched data for ETERNAL (1110 rows).
# 2026-01-12 14:40:11,186 - INFO - Fetched data for EXIDEIND (2476 rows).
# 2026-01-12 14:40:11,831 - INFO - Fetched data for NYKAA (1037 rows).
# 2026-01-12 14:40:12,524 - INFO - Fetched data for FEDERALBNK (2476 rows).
# 2026-01-12 14:40:13,214 - INFO - Fetched data for FACT (2476 rows).
# 2026-01-12 14:40:14,512 - INFO - Fetched data for FINCABLES (2476 rows).
# 2026-01-12 14:40:15,681 - INFO - Fetched data for FINPIPE (2476 rows).
# 2026-01-12 14:40:16,358 - INFO - Fetched data for FSL (2476 rows).
# 2026-01-12 14:40:17,555 - INFO - Fetched data for FIVESTAR (782 rows).
# 2026-01-12 14:40:18,306 - INFO - Fetched data for FORTIS (2476 rows).
# 2026-01-12 14:40:19,048 - INFO - Fetched data for GAIL (2476 rows).
# 2026-01-12 14:40:19,900 - INFO - Fetched data for GVT&D (2476 rows).
# 2026-01-12 14:40:20,653 - INFO - Fetched data for GMRAIRPORT (2476 rows).
# 2026-01-12 14:40:21,327 - INFO - Fetched data for GRSE (1800 rows).
# 2026-01-12 14:40:22,029 - INFO - Fetched data for GICRE (2038 rows).
# 2026-01-12 14:40:22,767 - INFO - Fetched data for GILLETTE (2476 rows).
# 2026-01-12 14:40:23,424 - INFO - Fetched data for GLAND (1275 rows).
# 2026-01-12 14:40:26,286 - INFO - Fetched data for GLAXO (2476 rows).
# 2026-01-12 14:40:27,024 - INFO - Fetched data for GLENMARK (2476 rows).
# 2026-01-12 14:40:28,396 - INFO - Fetched data for MEDANTA (785 rows).
# 2026-01-12 14:40:29,014 - INFO - Fetched data for GODIGIT (409 rows).
# 2026-01-12 14:40:29,692 - INFO - Fetched data for GPIL (2476 rows).
# 2026-01-12 14:40:31,850 - INFO - Fetched data for GODFRYPHLP (2476 rows).
# 2026-01-12 14:40:32,548 - INFO - Fetched data for GODREJAGRO (2044 rows).
# 2026-01-12 14:40:33,255 - INFO - Fetched data for GODREJCP (2476 rows).
# 2026-01-12 14:40:34,071 - INFO - Fetched data for GODREJIND (2476 rows).
# 2026-01-12 14:40:34,786 - INFO - Fetched data for GODREJPROP (2476 rows).
# 2026-01-12 14:40:35,643 - INFO - Fetched data for GRANULES (2476 rows).
# 2026-01-12 14:40:36,307 - INFO - Fetched data for GRAPHITE (2476 rows).
# 2026-01-12 14:40:37,019 - INFO - Fetched data for GRASIM (2476 rows).
# 2026-01-12 14:40:37,683 - INFO - Fetched data for GRAVITA (2476 rows).
# 2026-01-12 14:40:38,364 - INFO - Fetched data for GESHIP (2476 rows).
# 2026-01-12 14:40:39,029 - INFO - Fetched data for FLUOROCHEM (1552 rows).
# 2026-01-12 14:40:39,687 - INFO - Fetched data for GUJGASLTD (2476 rows).
# 2026-01-12 14:40:40,394 - INFO - Fetched data for GMDCLTD (2476 rows).
# 2026-01-12 14:40:41,086 - INFO - Fetched data for GNFC (2476 rows).
# 2026-01-12 14:40:41,754 - INFO - Fetched data for GPPL (2476 rows).
# 2026-01-12 14:40:42,438 - INFO - Fetched data for GSPL (2476 rows).
# 2026-01-12 14:40:43,126 - INFO - Fetched data for HEG (2476 rows).
# 2026-01-12 14:40:43,811 - INFO - Fetched data for HBLENGINE (2476 rows).
# 2026-01-12 14:40:44,624 - INFO - Fetched data for HCLTECH (2476 rows).
# 2026-01-12 14:40:45,244 - INFO - Fetched data for HDFCAMC (1842 rows).
# 2026-01-12 14:40:45,953 - INFO - Fetched data for HDFCBANK (2476 rows).
# 2026-01-12 14:40:46,637 - INFO - Fetched data for HDFCLIFE (2021 rows).
# 2026-01-12 14:40:47,326 - INFO - Fetched data for HFCL (2476 rows).
# 2026-01-12 14:40:47,996 - INFO - Fetched data for HAPPSTMNDS (1320 rows).
# 2026-01-12 14:40:49,673 - INFO - Fetched data for HAVELLS (2476 rows).
# 2026-01-12 14:40:50,517 - INFO - Fetched data for HEROMOTOCO (2476 rows).
# 2026-01-12 14:40:51,221 - INFO - Fetched data for HSCL (2476 rows).
# 2026-01-12 14:40:51,895 - INFO - Fetched data for HINDALCO (2476 rows).
# 2026-01-12 14:40:52,827 - INFO - Fetched data for HAL (1932 rows).
# 2026-01-12 14:40:53,530 - INFO - Fetched data for HINDCOPPER (2476 rows).
# 2026-01-12 14:40:54,750 - INFO - Fetched data for HINDPETRO (2476 rows).
# 2026-01-12 14:40:55,477 - INFO - Fetched data for HINDUNILVR (2476 rows).
# 2026-01-12 14:40:56,326 - INFO - Fetched data for HINDZINC (2476 rows).
# 2026-01-12 14:40:56,961 - INFO - Fetched data for POWERINDIA (1438 rows).
# 2026-01-12 14:40:57,616 - INFO - Fetched data for HOMEFIRST (1225 rows).
# 2026-01-12 14:40:58,326 - INFO - Fetched data for HONASA (543 rows).
# 2026-01-12 14:40:59,012 - INFO - Fetched data for HONAUT (2476 rows).
# 2026-01-12 14:40:59,646 - INFO - Fetched data for HUDCO (2146 rows).
# 2026-01-12 14:41:00,233 - INFO - Fetched data for HYUNDAI (305 rows).
# 2026-01-12 14:41:00,913 - INFO - Fetched data for ICICIBANK (2476 rows).
# 2026-01-12 14:41:01,572 - INFO - Fetched data for ICICIGI (2056 rows).
# 2026-01-12 14:41:02,229 - INFO - Fetched data for ICICIPRULI (2303 rows).
# 2026-01-12 14:41:02,905 - INFO - Fetched data for IDBI (2476 rows).
# 2026-01-12 14:41:03,570 - INFO - Fetched data for IDFCFIRSTB (2475 rows).
# 2026-01-12 14:41:04,283 - INFO - Fetched data for IFCI (2476 rows).
# 2026-01-12 14:41:04,945 - INFO - Fetched data for IIFL (2476 rows).
# 2026-01-12 14:41:05,542 - INFO - Fetched data for INOXINDIA (512 rows).
# 2026-01-12 14:41:06,378 - INFO - Fetched data for IRB (2476 rows).
# 2026-01-12 14:41:07,051 - INFO - Fetched data for IRCON (1807 rows).
# 2026-01-12 14:41:08,050 - INFO - Fetched data for ITC (2476 rows).
# 2026-01-12 14:41:08,790 - INFO - Fetched data for ITI (2476 rows).
# 2026-01-12 14:41:09,394 - INFO - Fetched data for INDGN (417 rows).
# 2026-01-12 14:41:10,116 - INFO - Fetched data for INDIACEM (2476 rows).
# 2026-01-12 14:41:10,773 - INFO - Fetched data for INDIAMART (1620 rows).
# 2026-01-12 14:41:13,195 - INFO - Fetched data for INDIANB (2476 rows).
# 2026-01-12 14:41:13,881 - INFO - Fetched data for IEX (2040 rows).
# 2026-01-12 14:41:14,542 - INFO - Fetched data for INDHOTEL (2476 rows).
# 2026-01-12 14:41:15,273 - INFO - Fetched data for IOC (2476 rows).
# 2026-01-12 14:41:15,978 - INFO - Fetched data for IOB (2476 rows).
# 2026-01-12 14:41:16,574 - INFO - Fetched data for IRCTC (1554 rows).
# 2026-01-12 14:41:17,211 - INFO - Fetched data for IRFC (1228 rows).
# 2026-01-12 14:41:17,768 - INFO - Fetched data for IREDA (528 rows).
# 2026-01-12 14:41:19,947 - INFO - Fetched data for IGL (2476 rows).
# 2026-01-12 14:41:20,624 - INFO - Fetched data for INDUSTOWER (2476 rows).
# 2026-01-12 14:41:21,498 - INFO - Fetched data for INDUSINDBK (2476 rows).
# 2026-01-12 14:41:22,264 - INFO - Fetched data for NAUKRI (2476 rows).
# 2026-01-12 14:41:22,979 - INFO - Fetched data for INFY (2476 rows).
# 2026-01-12 14:41:23,679 - INFO - Fetched data for INOXWIND (2476 rows).
# 2026-01-12 14:41:25,733 - INFO - Fetched data for INTELLECT (2476 rows).
# 2026-01-12 14:41:26,587 - INFO - Fetched data for INDIGO (2476 rows).
# 2026-01-12 14:41:27,359 - INFO - Fetched data for IGIL (264 rows).
# 2026-01-12 14:41:28,259 - INFO - Fetched data for IKS (265 rows).
# 2026-01-12 14:41:29,001 - INFO - Fetched data for IPCALAB (2476 rows).
# 2026-01-12 14:41:30,359 - INFO - Fetched data for JBCHEPHARM (2476 rows).
# 2026-01-12 14:41:31,528 - INFO - Fetched data for JKCEMENT (2476 rows).
# 2026-01-12 14:41:32,206 - INFO - Fetched data for JBMA (2476 rows).
# 2026-01-12 14:41:32,880 - INFO - Fetched data for JKTYRE (2476 rows).
# 2026-01-12 14:41:33,718 - INFO - Fetched data for JMFINANCIL (2476 rows).
# 2026-01-12 14:41:34,419 - INFO - Fetched data for JSWENERGY (2476 rows).
# 2026-01-12 14:41:37,332 - INFO - Fetched data for JSWHL (2476 rows).
# 2026-01-12 14:41:37,948 - INFO - Fetched data for JSWINFRA (567 rows).
# 2026-01-12 14:41:38,713 - INFO - Fetched data for JSWSTEEL (2476 rows).
# 2026-01-12 14:41:39,401 - INFO - Fetched data for JPPOWER (2476 rows).
# 2026-01-12 14:41:40,096 - INFO - Fetched data for J&KBANK (2476 rows).
# 2026-01-12 14:41:40,951 - INFO - Fetched data for JINDALSAW (2476 rows).
# 2026-01-12 14:41:42,124 - INFO - Fetched data for JSL (2476 rows).
# 2026-01-12 14:41:43,304 - INFO - Fetched data for JINDALSTEL (2476 rows).
# 2026-01-12 14:41:44,013 - INFO - Fetched data for JIOFIN (596 rows).
# 2026-01-12 14:41:44,950 - INFO - Fetched data for JUBLFOOD (2476 rows).
# 2026-01-12 14:41:45,608 - INFO - Fetched data for JUBLINGREA (1194 rows).
# 2026-01-12 14:41:46,211 - INFO - Fetched data for JUBLPHARMA (1219 rows).
# 2026-01-12 14:41:47,035 - INFO - Fetched data for JWL (2476 rows).
# 2026-01-12 14:41:50,934 - INFO - Fetched data for JUSTDIAL (2476 rows).
# 2026-01-12 14:41:51,788 - INFO - Fetched data for JYOTHYLAB (2476 rows).
# 2026-01-12 14:41:52,457 - INFO - Fetched data for JYOTICNC (495 rows).
# 2026-01-12 14:41:53,141 - INFO - Fetched data for KPRMILL (2476 rows).
# 2026-01-12 14:41:53,824 - INFO - Fetched data for KEI (2476 rows).
# 2026-01-12 14:41:55,960 - INFO - Fetched data for KNRCON (2476 rows).
# 2026-01-12 14:41:56,642 - INFO - Fetched data for KPITTECH (1670 rows).
# 2026-01-12 14:41:57,740 - INFO - Fetched data for KAJARIACER (2476 rows).
# 2026-01-12 14:41:58,393 - INFO - Fetched data for KPIL (2476 rows).
# 2026-01-12 14:41:59,058 - INFO - Fetched data for KALYANKJIL (1189 rows).
# 2026-01-12 14:41:59,767 - INFO - Fetched data for KANSAINER (2476 rows).
# 2026-01-12 14:42:00,457 - INFO - Fetched data for KARURVYSYA (2476 rows).
# 2026-01-12 14:42:01,081 - INFO - Fetched data for KAYNES (781 rows).
# 2026-01-12 14:42:01,755 - INFO - Fetched data for KEC (2476 rows).
# 2026-01-12 14:42:02,381 - INFO - Fetched data for KFINTECH (754 rows).
# 2026-01-12 14:42:03,046 - INFO - Fetched data for KIRLOSBROS (2476 rows).
# 2026-01-12 14:42:03,727 - INFO - Fetched data for KIRLOSENG (2476 rows).
# 2026-01-12 14:42:04,400 - INFO - Fetched data for KOTAKBANK (2476 rows).
# 2026-01-12 14:42:05,343 - INFO - Fetched data for KIMS (1128 rows).
# 2026-01-12 14:42:08,073 - INFO - Fetched data for LTF (2476 rows).
# 2026-01-12 14:42:08,739 - INFO - Fetched data for LTTS (2307 rows).
# 2026-01-12 14:42:09,442 - INFO - Fetched data for LICHSGFIN (2476 rows).
# 2026-01-12 14:42:10,036 - INFO - Fetched data for LTFOODS (544 rows).
# 2026-01-12 14:42:10,879 - INFO - Fetched data for LTIM (2350 rows).
# 2026-01-12 14:42:12,031 - INFO - Fetched data for LT (2476 rows).
# 2026-01-12 14:42:12,816 - INFO - Fetched data for LATENTVIEW (1029 rows).
# 2026-01-12 14:42:14,242 - INFO - Fetched data for LAURUSLABS (2249 rows).
# 2026-01-12 14:42:15,042 - INFO - Fetched data for LEMONTREE (1926 rows).
# 2026-01-12 14:42:15,682 - INFO - Fetched data for LICI (910 rows).
# 2026-01-12 14:42:16,355 - INFO - Fetched data for LINDEINDIA (2476 rows).
# 2026-01-12 14:42:16,948 - INFO - Fetched data for LLOYDSME (620 rows).
# 2026-01-12 14:42:18,062 - INFO - Fetched data for LUPIN (2476 rows).
# 2026-01-12 14:42:18,783 - INFO - Fetched data for MMTC (2476 rows).
# 2026-01-12 14:42:20,451 - INFO - Fetched data for MRF (2476 rows).
# 2026-01-12 14:42:21,245 - INFO - Fetched data for LODHA (1176 rows).
# 2026-01-12 14:42:21,965 - INFO - Fetched data for MGL (2363 rows).
# 2026-01-12 14:42:22,662 - INFO - Fetched data for MAHSEAMLES (2476 rows).
# 2026-01-12 14:42:23,351 - INFO - Fetched data for M&MFIN (2476 rows).
# 2026-01-12 14:42:24,390 - INFO - Fetched data for M&M (2476 rows).
# 2026-01-12 14:42:25,105 - INFO - Fetched data for MANAPPURAM (2476 rows).
# 2026-01-12 14:42:25,848 - INFO - Fetched data for MRPL (2476 rows).
# 2026-01-12 14:42:26,491 - INFO - Fetched data for MANKIND (668 rows).
# 2026-01-12 14:42:27,201 - INFO - Fetched data for MARICO (2476 rows).
# 2026-01-12 14:42:28,107 - INFO - Fetched data for MARUTI (2476 rows).
# 2026-01-12 14:42:28,792 - INFO - Fetched data for MASTEK (2476 rows).
# 2026-01-12 14:42:29,453 - INFO - Fetched data for MFSL (2476 rows).
# 2026-01-12 14:42:30,066 - INFO - Fetched data for MAXHEALTH (1339 rows).
# 2026-01-12 14:42:31,123 - INFO - Fetched data for MAZDOCK (1305 rows).
# 2026-01-12 14:42:31,761 - INFO - Fetched data for METROPOLIS (1673 rows).
# 2026-01-12 14:42:32,612 - INFO - Fetched data for MINDACORP (2476 rows).
# 2026-01-12 14:42:33,244 - INFO - Fetched data for MSUMI (942 rows).
# 2026-01-12 14:42:33,944 - INFO - Fetched data for MOTILALOFS (2476 rows).
# 2026-01-12 14:42:35,172 - INFO - Fetched data for MPHASIS (2476 rows).
# 2026-01-12 14:42:35,870 - INFO - Fetched data for MCX (2476 rows).
# 2026-01-12 14:42:37,556 - INFO - Fetched data for MUTHOOTFIN (2476 rows).
# 2026-01-12 14:42:38,261 - INFO - Fetched data for NATCOPHARM (2476 rows).
# 2026-01-12 14:42:38,987 - INFO - Fetched data for NBCC (2476 rows).
# 2026-01-12 14:42:39,793 - INFO - Fetched data for NCC (2476 rows).
# 2026-01-12 14:42:40,488 - INFO - Fetched data for NHPC (2476 rows).
# 2026-01-12 14:42:41,162 - INFO - Fetched data for NLCINDIA (2476 rows).
# 2026-01-12 14:42:41,891 - INFO - Fetched data for NMDC (2476 rows).
# 2026-01-12 14:42:42,950 - INFO - Fetched data for NSLNISP (717 rows).
# 2026-01-12 14:42:43,628 - INFO - Fetched data for NTPCGREEN (281 rows).
# 2026-01-12 14:42:44,489 - INFO - Fetched data for NTPC (2476 rows).
# 2026-01-12 14:42:45,139 - INFO - Fetched data for NH (2476 rows).
# 2026-01-12 14:42:45,846 - INFO - Fetched data for NATIONALUM (2476 rows).
# 2026-01-12 14:42:46,571 - INFO - Fetched data for NAVA (2476 rows).
# 2026-01-12 14:42:47,352 - INFO - Fetched data for NAVINFLUOR (2476 rows).
# 2026-01-12 14:42:51,116 - INFO - Fetched data for NESTLEIND (2476 rows).
# 2026-01-12 14:42:51,727 - INFO - Fetched data for NETWEB (612 rows).
# 2026-01-12 14:42:52,581 - INFO - Fetched data for NETWORK18 (2476 rows).
# 2026-01-12 14:42:53,285 - INFO - Fetched data for NEULANDLAB (2476 rows).
# 2026-01-12 14:42:56,531 - INFO - Fetched data for NEWGEN (1972 rows).
# 2026-01-12 14:42:57,271 - INFO - Fetched data for NAM-INDIA (2029 rows).
# 2026-01-12 14:42:57,949 - INFO - Fetched data for NIVABUPA (288 rows).
# 2026-01-12 14:42:58,936 - INFO - Fetched data for NUVAMA (570 rows).
# 2026-01-12 14:42:59,708 - INFO - Fetched data for OBEROIRLTY (2476 rows).
# 2026-01-12 14:43:00,588 - INFO - Fetched data for ONGC (2476 rows).
# 2026-01-12 14:43:01,757 - INFO - Fetched data for OIL (2476 rows).
# 2026-01-12 14:43:02,355 - INFO - Fetched data for OLAELEC (355 rows).
# 2026-01-12 14:43:03,042 - INFO - Fetched data for OLECTRA (2476 rows).
# 2026-01-12 14:43:03,681 - INFO - Fetched data for PAYTM (1031 rows).
# 2026-01-12 14:43:04,391 - INFO - Fetched data for OFSS (2476 rows).
# 2026-01-12 14:43:05,259 - INFO - Fetched data for POLICYBZR (1034 rows).
# 2026-01-12 14:43:05,916 - INFO - Fetched data for PCBL (992 rows).
# 2026-01-12 14:43:06,607 - INFO - Fetched data for PGEL (2476 rows).
# 2026-01-12 14:43:07,420 - INFO - Fetched data for PIIND (2476 rows).
# 2026-01-12 14:43:08,114 - INFO - Fetched data for PNBHOUSING (2278 rows).
# 2026-01-12 14:43:08,837 - INFO - Fetched data for PNCINFRA (2476 rows).
# 2026-01-12 14:43:09,620 - INFO - Fetched data for PTCIL (645 rows).
# 2026-01-12 14:43:10,306 - INFO - Fetched data for PVRINOX (2476 rows).
# 2026-01-12 14:43:11,003 - INFO - Fetched data for PAGEIND (2476 rows).
# 2026-01-12 14:43:11,645 - INFO - Fetched data for PATANJALI (869 rows).
# 2026-01-12 14:43:13,697 - INFO - Fetched data for PERSISTENT (2476 rows).
# 2026-01-12 14:43:14,379 - INFO - Fetched data for PETRONET (2476 rows).
# 2026-01-12 14:43:15,077 - INFO - Fetched data for PFIZER (2476 rows).
# 2026-01-12 14:43:15,817 - INFO - Fetched data for PHOENIXLTD (2476 rows).
# 2026-01-12 14:43:16,667 - INFO - Fetched data for PIDILITIND (2476 rows).
# 2026-01-12 14:43:17,381 - INFO - Fetched data for PEL (2400 rows).
# 2026-01-12 14:43:18,582 - INFO - Fetched data for PPLPHARMA (802 rows).
# 2026-01-12 14:43:19,265 - INFO - Fetched data for POLYMED (2476 rows).
# 2026-01-12 14:43:19,919 - INFO - Fetched data for POLYCAB (1672 rows).
# 2026-01-12 14:43:20,677 - INFO - Fetched data for POONAWALLA (2476 rows).
# 2026-01-12 14:43:21,344 - INFO - Fetched data for PFC (2476 rows).
# 2026-01-12 14:43:22,182 - INFO - Fetched data for POWERGRID (2476 rows).
# 2026-01-12 14:43:22,909 - INFO - Fetched data for PRAJIND (2476 rows).
# 2026-01-12 14:43:23,560 - INFO - Fetched data for PREMIERENE (339 rows).
# 2026-01-12 14:43:25,069 - INFO - Fetched data for PRESTIGE (2476 rows).
# 2026-01-12 14:43:25,757 - INFO - Fetched data for PNB (2476 rows).
# 2026-01-12 14:43:26,348 - INFO - Fetched data for RRKABEL (574 rows).
# 2026-01-12 14:43:27,022 - INFO - Fetched data for RBLBANK (2322 rows).
# 2026-01-12 14:43:27,787 - INFO - Fetched data for RECLTD (2476 rows).
# 2026-01-12 14:43:28,429 - INFO - Fetched data for RHIM (1112 rows).
# 2026-01-12 14:43:29,128 - INFO - Fetched data for RITES (1867 rows).
# 2026-01-12 14:43:29,845 - INFO - Fetched data for RADICO (2476 rows).
# 2026-01-12 14:43:30,529 - INFO - Fetched data for RVNL (1675 rows).
# 2026-01-12 14:43:31,170 - INFO - Fetched data for RAILTEL (1208 rows).
# 2026-01-12 14:43:31,813 - INFO - Fetched data for RAINBOW (914 rows).
# 2026-01-12 14:43:32,499 - INFO - Fetched data for RKFORGE (2476 rows).
# 2026-01-12 14:43:33,177 - INFO - Fetched data for RCF (2476 rows).
# 2026-01-12 14:43:33,824 - INFO - Fetched data for RTNINDIA (1184 rows).
# 2026-01-12 14:43:34,531 - INFO - Fetched data for RAYMONDLSL (337 rows).
# 2026-01-12 14:43:35,224 - INFO - Fetched data for RAYMOND (2476 rows).
# 2026-01-12 14:43:35,920 - INFO - Fetched data for REDINGTON (2476 rows).
# 2026-01-12 14:43:36,635 - INFO - Fetched data for RELIANCE (2476 rows).
# 2026-01-12 14:43:37,349 - INFO - Fetched data for RPOWER (2476 rows).
# 2026-01-12 14:43:38,035 - INFO - Fetched data for ROUTE (1319 rows).
# 2026-01-12 14:43:38,735 - INFO - Fetched data for SBFC (599 rows).
# 2026-01-12 14:43:39,326 - INFO - Fetched data for SBICARD (1448 rows).
# 2026-01-12 14:43:40,017 - INFO - Fetched data for SBILIFE (2053 rows).
# 2026-01-12 14:43:40,672 - INFO - Fetched data for SJVN (2476 rows).
# 2026-01-12 14:43:41,385 - INFO - Fetched data for SKFINDIA (2476 rows).
# 2026-01-12 14:43:42,086 - INFO - Fetched data for SRF (2476 rows).
# 2026-01-12 14:43:42,753 - INFO - Fetched data for SAGILITY (290 rows).
# 2026-01-12 14:43:43,346 - INFO - Fetched data for SAILIFE (266 rows).
# 2026-01-12 14:43:44,037 - INFO - Fetched data for SAMMAANCAP (2476 rows).
# 2026-01-12 14:43:44,735 - INFO - Fetched data for MOTHERSON (2476 rows).
# 2026-01-12 14:43:45,461 - INFO - Fetched data for SAPPHIRE (1031 rows).
# 2026-01-12 14:43:46,297 - INFO - Fetched data for SARDAEN (2476 rows).
# 2026-01-12 14:43:46,970 - INFO - Fetched data for SAREGAMA (2476 rows).
# 2026-01-12 14:43:47,647 - INFO - Fetched data for SCHAEFFLER (2476 rows).
# 2026-01-12 14:43:48,307 - INFO - Fetched data for SCHNEIDER (2476 rows).
# 2026-01-12 14:43:49,159 - INFO - Fetched data for SCI (2476 rows).
# 2026-01-12 14:43:49,827 - INFO - Fetched data for SHREECEM (2476 rows).
# 2026-01-12 14:43:50,489 - INFO - Fetched data for RENUKA (2476 rows).
# 2026-01-12 14:43:51,149 - INFO - Fetched data for SHRIRAMFIN (2476 rows).
# 2026-01-12 14:43:51,796 - INFO - Fetched data for SHYAMMETL (1130 rows).
# 2026-01-12 14:43:52,569 - INFO - Fetched data for SIEMENS (2476 rows).
# 2026-01-12 14:43:53,142 - INFO - Fetched data for SIGNATURE (569 rows).
# 2026-01-12 14:43:53,958 - INFO - Fetched data for SOBHA (2476 rows).
# 2026-01-12 14:43:54,645 - INFO - Fetched data for SOLARINDS (2476 rows).
# 2026-01-12 14:43:55,395 - INFO - Fetched data for SONACOMS (1130 rows).
# 2026-01-12 14:43:56,230 - INFO - Fetched data for SONATSOFTW (2476 rows).
# 2026-01-12 14:43:56,875 - INFO - Fetched data for STARHEALTH (1015 rows).
# 2026-01-12 14:43:57,571 - INFO - Fetched data for SBIN (2476 rows).
# 2026-01-12 14:43:58,415 - INFO - Fetched data for SAIL (2476 rows).
# 2026-01-12 14:43:59,051 - INFO - Fetched data for SWSOLAR (1589 rows).
# 2026-01-12 14:43:59,697 - INFO - Fetched data for SUMICHEM (1481 rows).
# 2026-01-12 14:44:00,525 - INFO - Fetched data for SUNPHARMA (2476 rows).
# 2026-01-12 14:44:01,204 - INFO - Fetched data for SUNTV (2476 rows).
# 2026-01-12 14:44:01,878 - INFO - Fetched data for SUNDARMFIN (2476 rows).
# 2026-01-12 14:44:02,546 - INFO - Fetched data for SUNDRMFAST (2476 rows).
# 2026-01-12 14:44:03,296 - INFO - Fetched data for SUPREMEIND (2476 rows).
# 2026-01-12 14:44:04,418 - INFO - Fetched data for SUZLON (2476 rows).
# (2026-01-12 14:44:04,978) ERROR :: <class 'AttributeError'> -> 'DataFrame' object has no attribute 'timestamp' (PID:4220 Thread:26632)
# 2026-01-12 14:44:04,978 - ERROR - <class 'AttributeError'> -> 'DataFrame' object has no attribute 'timestamp'
# 2026-01-12 14:44:04,981 - ERROR - Failed to fetch data for SWANENERGY: 'NoneType' object does not support item assignment
# 2026-01-12 14:44:05,431 - INFO - Fetched data for SWIGGY (289 rows).
# 2026-01-12 14:44:06,105 - INFO - Fetched data for SYNGENE (2476 rows).
# 2026-01-12 14:44:06,769 - INFO - Fetched data for SYRMA (839 rows).
# 2026-01-12 14:44:07,400 - INFO - Fetched data for TBOTEK (415 rows).
# 2026-01-12 14:44:08,105 - INFO - Fetched data for TVSMOTOR (2476 rows).
# 2026-01-12 14:44:08,835 - INFO - Fetched data for TANLA (2476 rows).
# 2026-01-12 14:44:09,496 - INFO - Fetched data for TATACHEM (2476 rows).
# 2026-01-12 14:44:10,197 - INFO - Fetched data for TATACOMM (2476 rows).
# 2026-01-12 14:44:11,045 - INFO - Fetched data for TCS (2476 rows).
# 2026-01-12 14:44:11,763 - INFO - Fetched data for TATACONSUM (2475 rows).
# 2026-01-12 14:44:12,534 - INFO - Fetched data for TATAELXSI (2476 rows).
# 2026-01-12 14:44:13,250 - INFO - Fetched data for TATAINVEST (2476 rows).
# (2026-01-12 14:44:13,931) ERROR :: <class 'AttributeError'> -> 'DataFrame' object has no attribute 'timestamp' (PID:4220 Thread:26632)
# 2026-01-12 14:44:13,931 - ERROR - <class 'AttributeError'> -> 'DataFrame' object has no attribute 'timestamp'
# 2026-01-12 14:44:13,936 - ERROR - Failed to fetch data for TATAMOTORS: 'NoneType' object does not support item assignment
# 2026-01-12 14:44:14,708 - INFO - Fetched data for TATAPOWER (2476 rows).
# 2026-01-12 14:44:15,413 - INFO - Fetched data for TATASTEEL (2476 rows).
# 2026-01-12 14:44:15,976 - INFO - Fetched data for TATATECH (527 rows).
# 2026-01-12 14:44:16,621 - INFO - Fetched data for TTML (2476 rows).
# 2026-01-12 14:44:17,504 - INFO - Fetched data for TECHM (2476 rows).
# 2026-01-12 14:44:18,165 - INFO - Fetched data for TECHNOE (1764 rows).
# 2026-01-12 14:44:19,335 - INFO - Fetched data for TEJASNET (2120 rows).
# 2026-01-12 14:44:20,041 - INFO - Fetched data for NIACL (2025 rows).
# 2026-01-12 14:44:21,002 - INFO - Fetched data for RAMCOCEM (2476 rows).
# 2026-01-12 14:44:21,854 - INFO - Fetched data for THERMAX (2476 rows).
# 2026-01-12 14:44:22,655 - INFO - Fetched data for TIMKEN (2476 rows).
# 2026-01-12 14:44:23,335 - INFO - Fetched data for TITAGARH (2476 rows).
# 2026-01-12 14:44:24,030 - INFO - Fetched data for TITAN (2476 rows).
# 2026-01-12 14:44:24,766 - INFO - Fetched data for TORNTPHARM (2476 rows).
# 2026-01-12 14:44:25,455 - INFO - Fetched data for TORNTPOWER (2476 rows).
# 2026-01-12 14:44:26,204 - INFO - Fetched data for TARIL (2476 rows).
# 2026-01-12 14:44:26,861 - INFO - Fetched data for TRENT (2476 rows).
# 2026-01-12 14:44:27,557 - INFO - Fetched data for TRIDENT (2476 rows).
# 2026-01-12 14:44:28,278 - INFO - Fetched data for TRIVENI (2476 rows).
# 2026-01-12 14:44:28,939 - INFO - Fetched data for TRITURBINE (2476 rows).
# 2026-01-12 14:44:29,617 - INFO - Fetched data for TIINDIA (2032 rows).
# 2026-01-12 14:44:30,319 - INFO - Fetched data for UCOBANK (2476 rows).
# 2026-01-12 14:44:31,025 - INFO - Fetched data for UNOMINDA (2476 rows).
# 2026-01-12 14:44:31,729 - INFO - Fetched data for UPL (2476 rows).
# 2026-01-12 14:44:32,391 - INFO - Fetched data for UTIAMC (1305 rows).
# 2026-01-12 14:44:33,094 - INFO - Fetched data for ULTRACEMCO (2476 rows).
# 2026-01-12 14:44:33,768 - INFO - Fetched data for UNIONBANK (2476 rows).
# 2026-01-12 14:44:34,466 - INFO - Fetched data for UBL (2476 rows).
# 2026-01-12 14:44:35,128 - INFO - Fetched data for UNITDSPR (2476 rows).
# 2026-01-12 14:44:35,854 - INFO - Fetched data for USHAMART (2476 rows).
# 2026-01-12 14:44:36,911 - INFO - Fetched data for VGUARD (2476 rows).
# 2026-01-12 14:44:37,612 - INFO - Fetched data for DBREALTY (2476 rows).
# 2026-01-12 14:44:38,301 - INFO - Fetched data for VTL (2476 rows).
# 2026-01-12 14:44:39,117 - INFO - Fetched data for VBL (2277 rows).
# 2026-01-12 14:44:39,758 - INFO - Fetched data for MANYAVAR (969 rows).
# 2026-01-12 14:44:40,449 - INFO - Fetched data for VEDL (2476 rows).
# 2026-01-12 14:44:41,090 - INFO - Fetched data for VIJAYA (1076 rows).
# 2026-01-12 14:44:41,675 - INFO - Fetched data for VMM (266 rows).
# 2026-01-12 14:44:42,521 - INFO - Fetched data for IDEA (2475 rows).
# 2026-01-12 14:44:43,259 - INFO - Fetched data for VOLTAS (2476 rows).
# 2026-01-12 14:44:43,885 - INFO - Fetched data for WAAREEENER (301 rows).
# 2026-01-12 14:44:44,608 - INFO - Fetched data for WELCORP (2476 rows).
# 2026-01-12 14:44:45,207 - INFO - Fetched data for WELSPUNLIV (517 rows).
# 2026-01-12 14:44:45,867 - INFO - Fetched data for WESTLIFE (1589 rows).
# 2026-01-12 14:44:46,587 - INFO - Fetched data for WHIRLPOOL (2476 rows).
# 2026-01-12 14:44:47,435 - INFO - Fetched data for WIPRO (2476 rows).
# 2026-01-12 14:44:48,088 - INFO - Fetched data for WOCKPHARMA (2476 rows).
# 2026-01-12 14:44:48,766 - INFO - Fetched data for YESBANK (2476 rows).
# 2026-01-12 14:44:49,395 - INFO - Fetched data for ZFCVINDIA (939 rows).
# 2026-01-12 14:44:50,235 - INFO - Fetched data for ZEEL (2476 rows).
# 2026-01-12 14:44:50,912 - INFO - Fetched data for ZENTEC (2476 rows).
# 2026-01-12 14:44:51,638 - INFO - Fetched data for ZENSARTECH (2476 rows).
# 2026-01-12 14:44:52,337 - INFO - Fetched data for ZYDUSLIFE (2476 rows).
