# %%
import time
import logging
import pandas as pd
from truedata import TD_hist

def fetch_truedata_history(
    username: str,
    password: str,
    ticker_list: list,
    duration: str = '1 Y',
    bar_size: str = 'EOD',
    sleep_time: float = 0.1
) -> tuple[pd.DataFrame, list]:
    """
    Fetches historical data from TrueData for a list of tickers.

    Parameters
    ----------
    username : str
        TrueData username.
    password : str
        TrueData password.
    ticker_list : list
        List of ticker symbols to fetch data for.
    duration : str, optional
        Duration of data (e.g., '1 Y', '25 Y', etc.). Default is '1 Y'.
    bar_size : str, optional
        Bar size for data ('EOD', 'WEEK', etc.). Default is 'EOD'.
    sleep_time : float, optional
        Delay between API calls to avoid throttling. Default is 0.2 seconds.

    Returns
    -------
    final_df : pd.DataFrame
        Combined DataFrame of all tickers' historical data.
    error_list : list
        List of tickers that failed to fetch.
    """
    logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

    # Initialize connection
    td_hist = TD_hist(username, password)

    df_list = []
    error_list = []

    for ticker in ticker_list:
        try:
            df = td_hist.get_historic_data([ticker], duration=duration, bar_size=bar_size)

            df['Ticker'] = ticker
            df = df.rename(columns={
                'timestamp': 'Date',
                'high': 'High',
                'low': 'Low',
                'close': 'Close',
                'open': 'Open'
            })

            df_list.append(df)
            logging.info(f"Fetched data for {ticker} ({len(df)} rows).")
            time.sleep(sleep_time)

        except Exception as e:
            logging.error(f"Failed to fetch data for {ticker}: {e}")
            error_list.append(ticker)

    final_df = pd.concat(df_list, ignore_index=True) if df_list else pd.DataFrame()
    return final_df, error_list

# %%
import numpy as np
from datetime import datetime
from dateutil.relativedelta import relativedelta
import yfinance as yf
from pathlib import Path

import os

def run_momentum_strategy(universe_file: str,
                          start_date: str,
                          end_date: str,
                          top_n: int,
                          output_root: str = "Momentum_Results") -> str:
    """
    Run rolling-window momentum strategy on given stock universe.

    Parameters
    ----------
    universe_file : str
        Path to universe file (.csv or .xlsx) with columns ["Symbol", "ISIN Code"].
    start_date : str
        Start date for backtest (YYYY-MM-DD).
    end_date : str
        End date for backtest (YYYY-MM-DD).
    top_n : int
        Number of top ranked stocks to select each window.
    output_root : str
        Root folder where results will be saved.

    Returns
    -------
    str
        Path to master summary file.
    """


    # ==== 1. Load Universe ====
    if universe_file.endswith(".csv"):
        stock_list = pd.read_csv(universe_file)[["Symbol", "ISIN Code"]]
    else:
        stock_list = pd.read_excel(universe_file)[["Symbol", "ISIN Code"]]
    # username = os.getenv("TRUEDATA_USERNAME")
    # password = os.getenv("TRUEDATA_PASSWORD")
    
    username = os.getenv("TRUEDATA_USERNAME")
    password = os.getenv("TRUEDATA_PASSWORD")
    # username = 'td105'
    # password = os.getenv("TRUEDATA_PASSWORD")
    # stock_list["Ticker"] = stock_list["Symbol"] + ".NS"
    stock_list["Ticker"] = stock_list["Symbol"] 
    symbol_list = stock_list["Symbol"].tolist()
    universe_name = Path(universe_file).stem
    output_dir = os.path.join(output_root, f"{universe_name}_{top_n}_stocks_results")
    os.makedirs(output_dir, exist_ok=True)

    # ==== 2. Download Data ====
    total_start = pd.to_datetime(start_date)
    total_end = pd.to_datetime(end_date)

    print(f"\n📥 Downloading price data for {len(symbol_list)} symbols...")
    # data = yf.download(symbol_list, start=total_start.strftime('%Y-%m-%d'),
    #                    end=total_end.strftime('%Y-%m-%d'), progress=True)
    # prices_all = data["Close"]
    # prices_all.index = pd.to_datetime(prices_all.index)
    # print("✅ Download complete.")

    data, errors = fetch_truedata_history(username, password, symbol_list, duration='10 Y', bar_size='EOD')
    data = data[['Date', 'Close', 'Ticker']]
    data.drop_duplicates(subset=['Date', 'Ticker'], inplace=True)
    print(data)
    print("Failed tickers:", errors)
    prices = data.pivot(index="Date", columns="Ticker", values="Close")  
    # optional: sort by date
    prices_all = prices.sort_index()



    # ==== 3. Create Rolling Windows ====
    windows = []
    current_start = total_start
    while True:
        current_end = current_start + relativedelta(months=6)
        if current_end > total_end:
            break
        window_prices = prices_all.loc[(prices_all.index >= current_start) & (prices_all.index < current_end)].copy()
        if not window_prices.empty:
            windows.append((current_start, current_end, window_prices))
        current_start += relativedelta(months=1)

    print(f"📊 Created {len(windows)} rolling windows.")

    # ==== 4. Process Each Window ====
    for start, end, prices in windows:
        file_suffix = f"{start.strftime('%Y%m%d')}_{end.strftime('%Y%m%d')}"
        print(f"\n🔍 Processing window: {start.date()} → {end.date()}")

        prices.dropna(axis=1, how='all', inplace=True)
        if prices.empty:
            print("⚠️ All price data missing. Skipping window.")
            continue

        # Monthly momentum
        monthclose = prices.groupby(prices.index.strftime('%Y-%m')).tail(1)
        monthstart = prices.groupby(prices.index.strftime('%Y-%m')).head(1)
        monthstart.index = monthclose.index
        monchange = (monthclose - monthstart) / monthstart
        MOM = (monchange + 1).product() - 1
        mom = MOM * 100

        # Daily returns
        daily_ret = prices.pct_change(fill_method=None)
        positivechange = (daily_ret[daily_ret > 0].count() / daily_ret.count()) * 100
        negativechange = (daily_ret[daily_ret < 0].count() / daily_ret.count()) * 100

        result = pd.concat([positivechange, negativechange, mom], axis=1, join='inner')
        result.columns = ["Positive", "Negative", "Momentum"]
        result = result.reset_index().rename(columns={'index': 'Ticker'})

        # Merge ISIN
        result = pd.merge(result, stock_list[["Ticker", "ISIN Code"]], on="Ticker", how="left")

        # Ranking
        df = result.copy()
        df["Rank_Mom"] = df["Momentum"].rank(method='min', ascending=False)
        print('rank df:', df)
        df['FIP'] = df.apply(lambda row: row['Negative'] - row['Positive'] if row['Momentum'] > 0 else np.nan, axis=1)
        # df['FIP'] = df.apply(lambda row: row['Negative'] - row['Positive'])

        df.dropna(inplace=True)
        df["FIP_rank"] = df["FIP"].rank(method="first", ascending=True)
        df["Combined_Rank"] = df["Rank_Mom"] + df["FIP_rank"]
        if end.strftime('%Y-%m-%d') == '2026-01-01':
            df = df[~(df['Ticker'].isin(['MARUTI', 'PTCIL']))]

        df = df.sort_values(by="Combined_Rank", ascending=True).head(top_n)
        df["Real_Rank"] = range(1, len(df) + 1)
        df["End_Date"] = end.strftime('%Y-%m-%d')


        # Save each window
        output_file = os.path.join(output_dir, f"momentum_{file_suffix}.xlsx")
        df.to_excel(output_file, index=False)
        print(f"✅ Saved results to: {output_file}")

    # ==== 5. Master File ====
    print("\n📂 Creating master summary file...")
    master_data = []
    for file in os.listdir(output_dir):
        if file.startswith("momentum_") and file.endswith(".xlsx"):
            df = pd.read_excel(os.path.join(output_dir, file))
            selected_df = df[["End_Date", "ISIN Code", "Ticker", 'Real_Rank']].copy()
            master_data.append(selected_df)

    if master_data:
        master_df = pd.concat(master_data, ignore_index=True)
        master_file_path = os.path.join(output_dir, "master_momentum_summary.xlsx")
        master_df.to_excel(master_file_path, index=False)
        print(f"✅ Master file saved to: {master_file_path}")
        return master_file_path
    else:
        print("⚠️ No window files found, master not created.")
        return None

# %%
# Momentum/Automating Momentum/Universe/Nifty_500_2025_Apr.csv
# "C:\Users\Admin\Momentum\Automating Momentum\Universe\Nifty_500_2025_Apr.csv"
master_file = run_momentum_strategy(
    universe_file=r"Universe/Nifty_500_2025_Apr.csv",
    start_date="2022-06-01",
    end_date="2026-04-01",
    top_n=20,
    output_root="Stocks"
)
print("Master summary located at:", master_file)
# Out:
# 📥 Downloading price data for 503 symbols...
# (2026-03-30 09:21:04,210) WARNING :: Connected successfully to TrueData Historical Data Service...  (PID:25224 Thread:25096)
# 2026-03-30 09:21:04,210 - WARNING - Connected successfully to TrueData Historical Data Service...
# 2026-03-30 09:21:04,832 - INFO - Fetched data for 360ONE (1621 rows).
# 2026-03-30 09:21:05,494 - INFO - Fetched data for 3MINDIA (2477 rows).
# 2026-03-30 09:21:06,140 - INFO - Fetched data for ABB (2477 rows).
# 2026-03-30 09:21:06,777 - INFO - Fetched data for ACC (2477 rows).
# 2026-03-30 09:21:07,257 - INFO - Fetched data for ACMESOLAR (341 rows).
# 2026-03-30 09:21:07,859 - INFO - Fetched data for AIAENG (2477 rows).
# 2026-03-30 09:21:08,458 - INFO - Fetched data for APLAPOLLO (2477 rows).
# 2026-03-30 09:21:09,079 - INFO - Fetched data for AUBANK (2163 rows).
# 2026-03-30 09:21:09,643 - INFO - Fetched data for AWL (1027 rows).
# 2026-03-30 09:21:10,162 - INFO - Fetched data for AADHARHFC (466 rows).
# 2026-03-30 09:21:10,778 - INFO - Fetched data for AARTIIND (2477 rows).
# 2026-03-30 09:21:11,339 - INFO - Fetched data for AAVAS (1854 rows).
# 2026-03-30 09:21:11,909 - INFO - Fetched data for ABBOTINDIA (2477 rows).
# 2026-03-30 09:21:12,518 - INFO - Fetched data for ACE (2477 rows).
# 2026-03-30 09:21:13,051 - INFO - Fetched data for ADANIENSOL (645 rows).
# 2026-03-30 09:21:13,634 - INFO - Fetched data for ADANIENT (2477 rows).
# 2026-03-30 09:21:14,270 - INFO - Fetched data for ADANIGREEN (1929 rows).
# 2026-03-30 09:21:14,831 - INFO - Fetched data for ADANIPORTS (2477 rows).
# 2026-03-30 09:21:15,368 - INFO - Fetched data for ADANIPOWER (2477 rows).
# 2026-03-30 09:21:15,906 - INFO - Fetched data for ATGL (1834 rows).
# 2026-03-30 09:21:16,450 - INFO - Fetched data for ABCAPITAL (2126 rows).
# 2026-03-30 09:21:17,040 - INFO - Fetched data for ABFRL (2477 rows).
# 2026-03-30 09:21:17,694 - INFO - Fetched data for ABREL (2477 rows).
# 2026-03-30 09:21:18,258 - INFO - Fetched data for ABSLAMC (1109 rows).
# 2026-03-30 09:21:18,808 - INFO - Fetched data for AEGISLOG (2477 rows).
# 2026-03-30 09:21:19,322 - INFO - Fetched data for AFCONS (348 rows).
# 2026-03-30 09:21:19,885 - INFO - Fetched data for AFFLE (1647 rows).
# 2026-03-30 09:21:20,465 - INFO - Fetched data for AJANTPHARM (2477 rows).
# 2026-03-30 09:21:20,956 - INFO - Fetched data for AKUMS (410 rows).
# 2026-03-30 09:21:21,547 - INFO - Fetched data for APLLTD (2477 rows).
# 2026-03-30 09:21:22,074 - INFO - Fetched data for ALIVUS (1153 rows).
# 2026-03-30 09:21:22,633 - INFO - Fetched data for ALKEM (2477 rows).
# 2026-03-30 09:21:23,205 - INFO - Fetched data for ALKYLAMINE (2477 rows).
# 2026-03-30 09:21:23,735 - INFO - Fetched data for ALOKINDS (1516 rows).
# 2026-03-30 09:21:24,253 - INFO - Fetched data for ARE&M (602 rows).
# 2026-03-30 09:21:24,826 - INFO - Fetched data for AMBER (2023 rows).
# 2026-03-30 09:21:25,406 - INFO - Fetched data for AMBUJACEM (2477 rows).
# 2026-03-30 09:21:26,168 - INFO - Fetched data for ANANDRATHI (1066 rows).
# 2026-03-30 09:21:26,750 - INFO - Fetched data for ANANTRAJ (2477 rows).
# 2026-03-30 09:21:27,325 - INFO - Fetched data for ANGELONE (1361 rows).
# 2026-03-30 09:21:27,876 - INFO - Fetched data for APARINDS (2477 rows).
# 2026-03-30 09:21:28,432 - INFO - Fetched data for APOLLOHOSP (2477 rows).
# 2026-03-30 09:21:29,023 - INFO - Fetched data for APOLLOTYRE (2477 rows).
# 2026-03-30 09:21:29,549 - INFO - Fetched data for APTUS (1142 rows).
# 2026-03-30 09:21:30,121 - INFO - Fetched data for ASAHIINDIA (2477 rows).
# 2026-03-30 09:21:30,681 - INFO - Fetched data for ASHOKLEY (2477 rows).
# 2026-03-30 09:21:31,276 - INFO - Fetched data for ASIANPAINT (2477 rows).
# 2026-03-30 09:21:31,807 - INFO - Fetched data for ASTERDM (2005 rows).
# 2026-03-30 09:21:32,402 - INFO - Fetched data for ASTRAZEN (2477 rows).
# 2026-03-30 09:21:32,990 - INFO - Fetched data for ASTRAL (2477 rows).
# 2026-03-30 09:21:33,576 - INFO - Fetched data for ATUL (2477 rows).
# 2026-03-30 09:21:34,174 - INFO - Fetched data for AUROPHARMA (2477 rows).
# 2026-03-30 09:21:34,654 - INFO - Fetched data for AIIL (482 rows).
# 2026-03-30 09:21:35,290 - INFO - Fetched data for DMART (2238 rows).
# 2026-03-30 09:21:35,868 - INFO - Fetched data for AXISBANK (2477 rows).
# 2026-03-30 09:21:36,498 - INFO - Fetched data for BASF (2477 rows).
# 2026-03-30 09:21:37,113 - INFO - Fetched data for BEML (2477 rows).
# 2026-03-30 09:21:37,722 - INFO - Fetched data for BLS (2427 rows).
# 2026-03-30 09:21:38,309 - INFO - Fetched data for BSE (2268 rows).
# 2026-03-30 09:21:38,873 - INFO - Fetched data for BAJAJ-AUTO (2477 rows).
# 2026-03-30 09:21:39,461 - INFO - Fetched data for BAJFINANCE (2477 rows).
# 2026-03-30 09:21:40,017 - INFO - Fetched data for BAJAJFINSV (2477 rows).
# 2026-03-30 09:21:40,551 - INFO - Fetched data for BAJAJHLDNG (2477 rows).
# 2026-03-30 09:21:41,044 - INFO - Fetched data for BAJAJHFL (382 rows).
# 2026-03-30 09:21:41,583 - INFO - Fetched data for BALKRISIND (2477 rows).
# 2026-03-30 09:21:42,158 - INFO - Fetched data for BALRAMCHIN (2477 rows).
# 2026-03-30 09:21:42,753 - INFO - Fetched data for BANDHANBNK (1985 rows).
# 2026-03-30 09:21:43,343 - INFO - Fetched data for BANKBARODA (2477 rows).
# 2026-03-30 09:21:43,897 - INFO - Fetched data for BANKINDIA (2477 rows).
# 2026-03-30 09:21:44,576 - INFO - Fetched data for MAHABANK (2477 rows).
# 2026-03-30 09:21:45,168 - INFO - Fetched data for BATAINDIA (2477 rows).
# 2026-03-30 09:21:45,710 - INFO - Fetched data for BAYERCROP (2477 rows).
# 2026-03-30 09:21:46,275 - INFO - Fetched data for BERGEPAINT (2477 rows).
# 2026-03-30 09:21:46,898 - INFO - Fetched data for BDL (1987 rows).
# 2026-03-30 09:21:47,462 - INFO - Fetched data for BEL (2477 rows).
# 2026-03-30 09:21:48,076 - INFO - Fetched data for BHARATFORG (2477 rows).
# 2026-03-30 09:21:48,671 - INFO - Fetched data for BHEL (2477 rows).
# 2026-03-30 09:21:49,277 - INFO - Fetched data for BPCL (2477 rows).
# 2026-03-30 09:21:49,838 - INFO - Fetched data for BHARTIARTL (2477 rows).
# 2026-03-30 09:21:50,329 - INFO - Fetched data for BHARTIHEXA (488 rows).
# 2026-03-30 09:21:50,874 - INFO - Fetched data for BIKAJI (837 rows).
# 2026-03-30 09:21:51,444 - INFO - Fetched data for BIOCON (2477 rows).
# 2026-03-30 09:21:52,033 - INFO - Fetched data for BSOFT (2477 rows).
# 2026-03-30 09:21:52,589 - INFO - Fetched data for BLUEDART (2477 rows).
# 2026-03-30 09:21:53,137 - INFO - Fetched data for BLUESTARCO (2477 rows).
# 2026-03-30 09:21:53,717 - INFO - Fetched data for BBTC (2477 rows).
# 2026-03-30 09:21:54,306 - INFO - Fetched data for BOSCHLTD (2477 rows).
# 2026-03-30 09:21:54,799 - INFO - Fetched data for FIRSTCRY (405 rows).
# 2026-03-30 09:21:55,349 - INFO - Fetched data for BRIGADE (2477 rows).
# 2026-03-30 09:21:55,955 - INFO - Fetched data for BRITANNIA (2477 rows).
# 2026-03-30 09:21:56,495 - INFO - Fetched data for MAPMYINDIA (1061 rows).
# 2026-03-30 09:21:57,078 - INFO - Fetched data for CCL (2477 rows).
# 2026-03-30 09:21:57,629 - INFO - Fetched data for CESC (2477 rows).
# 2026-03-30 09:21:58,227 - INFO - Fetched data for CGPOWER (2477 rows).
# 2026-03-30 09:21:58,857 - INFO - Fetched data for CRISIL (2477 rows).
# 2026-03-30 09:21:59,418 - INFO - Fetched data for CAMPUS (968 rows).
# 2026-03-30 09:21:59,971 - INFO - Fetched data for CANFINHOME (2477 rows).
# 2026-03-30 09:22:00,527 - INFO - Fetched data for CANBK (2477 rows).
# 2026-03-30 09:22:01,091 - INFO - Fetched data for CAPLIPOINT (2477 rows).
# 2026-03-30 09:22:01,670 - INFO - Fetched data for CGCL (2477 rows).
# 2026-03-30 09:22:02,277 - INFO - Fetched data for CARBORUNIV (2477 rows).
# 2026-03-30 09:22:02,861 - INFO - Fetched data for CASTROLIND (2477 rows).
# 2026-03-30 09:22:03,446 - INFO - Fetched data for CEATLTD (2477 rows).
# 2026-03-30 09:22:04,014 - INFO - Fetched data for CENTRALBK (2477 rows).
# 2026-03-30 09:22:04,571 - INFO - Fetched data for CDSL (2169 rows).
# 2026-03-30 09:22:05,167 - INFO - Fetched data for CENTURYPLY (2477 rows).
# 2026-03-30 09:22:05,756 - INFO - Fetched data for CERA (2477 rows).
# 2026-03-30 09:22:06,317 - INFO - Fetched data for CHALET (1770 rows).
# 2026-03-30 09:22:06,898 - INFO - Fetched data for CHAMBLFERT (2477 rows).
# 2026-03-30 09:22:07,491 - INFO - Fetched data for CHENNPETRO (2477 rows).
# 2026-03-30 09:22:08,065 - INFO - Fetched data for CHOLAHLDNG (2110 rows).
# 2026-03-30 09:22:08,653 - INFO - Fetched data for CHOLAFIN (2477 rows).
# 2026-03-30 09:22:09,263 - INFO - Fetched data for CIPLA (2477 rows).
# 2026-03-30 09:22:09,883 - INFO - Fetched data for CUB (2477 rows).
# 2026-03-30 09:22:10,468 - INFO - Fetched data for CLEAN (1165 rows).
# 2026-03-30 09:22:11,074 - INFO - Fetched data for COALINDIA (2477 rows).
# 2026-03-30 09:22:11,798 - INFO - Fetched data for COCHINSHIP (2139 rows).
# 2026-03-30 09:22:12,844 - INFO - Fetched data for COFORGE (2477 rows).
# 2026-03-30 09:22:13,841 - INFO - Fetched data for COHANCE (1504 rows).
# 2026-03-30 09:22:14,632 - INFO - Fetched data for COLPAL (2477 rows).
# 2026-03-30 09:22:15,151 - INFO - Fetched data for CAMS (1362 rows).
# 2026-03-30 09:22:15,710 - INFO - Fetched data for CONCORDBIO (649 rows).
# 2026-03-30 09:22:16,328 - INFO - Fetched data for CONCOR (2477 rows).
# 2026-03-30 09:22:16,946 - INFO - Fetched data for COROMANDEL (2477 rows).
# 2026-03-30 09:22:17,479 - INFO - Fetched data for CRAFTSMAN (1242 rows).
# 2026-03-30 09:22:18,012 - INFO - Fetched data for CREDITACC (1883 rows).
# 2026-03-30 09:22:18,628 - INFO - Fetched data for CROMPTON (2450 rows).
# 2026-03-30 09:22:19,316 - INFO - Fetched data for CUMMINSIND (2477 rows).
# 2026-03-30 09:22:19,910 - INFO - Fetched data for CYIENT (2477 rows).
# 2026-03-30 09:22:20,492 - INFO - Fetched data for DCMSHRIRAM (2477 rows).
# 2026-03-30 09:22:21,068 - INFO - Fetched data for DLF (2477 rows).
# 2026-03-30 09:22:21,554 - INFO - Fetched data for DOMS (565 rows).
# 2026-03-30 09:22:22,181 - INFO - Fetched data for DABUR (2477 rows).
# 2026-03-30 09:22:22,726 - INFO - Fetched data for DALBHARAT (1782 rows).
# 2026-03-30 09:22:23,283 - INFO - Fetched data for DATAPATTNS (1058 rows).
# 2026-03-30 09:22:23,950 - INFO - Fetched data for DEEPAKFERT (2477 rows).
# 2026-03-30 09:22:24,560 - INFO - Fetched data for DEEPAKNTR (2477 rows).
# 2026-03-30 09:22:25,073 - INFO - Fetched data for DELHIVERY (957 rows).
# 2026-03-30 09:22:25,602 - INFO - Fetched data for DEVYANI (1147 rows).
# 2026-03-30 09:22:26,172 - INFO - Fetched data for DIVISLAB (2477 rows).
# 2026-03-30 09:22:26,789 - INFO - Fetched data for DIXON (2115 rows).
# 2026-03-30 09:22:27,406 - INFO - Fetched data for LALPATHLAB (2477 rows).
# 2026-03-30 09:22:28,031 - INFO - Fetched data for DRREDDY (2477 rows).
# (2026-03-30 09:22:28,501) ERROR :: <class 'AttributeError'> -> 'DataFrame' object has no attribute 'timestamp' (PID:25224 Thread:25096)
# 2026-03-30 09:22:28,501 - ERROR - <class 'AttributeError'> -> 'DataFrame' object has no attribute 'timestamp'
# 2026-03-30 09:22:28,507 - ERROR - Failed to fetch data for DUMMYABFRL: 'NoneType' object does not support item assignment
# (2026-03-30 09:22:28,891) ERROR :: <class 'AttributeError'> -> 'DataFrame' object has no attribute 'timestamp' (PID:25224 Thread:25096)
# 2026-03-30 09:22:28,891 - ERROR - <class 'AttributeError'> -> 'DataFrame' object has no attribute 'timestamp'
# 2026-03-30 09:22:28,896 - ERROR - Failed to fetch data for DUMMYSIEMS: 'NoneType' object does not support item assignment
# (2026-03-30 09:22:29,362) ERROR :: <class 'AttributeError'> -> 'DataFrame' object has no attribute 'timestamp' (PID:25224 Thread:25096)
# 2026-03-30 09:22:29,362 - ERROR - <class 'AttributeError'> -> 'DataFrame' object has no attribute 'timestamp'
# 2026-03-30 09:22:29,366 - ERROR - Failed to fetch data for DUMMYRAYMN: 'NoneType' object does not support item assignment
# 2026-03-30 09:22:29,849 - INFO - Fetched data for EIDPARRY (2477 rows).
# 2026-03-30 09:22:30,445 - INFO - Fetched data for EIHOTEL (2477 rows).
# 2026-03-30 09:22:31,058 - INFO - Fetched data for EICHERMOT (2477 rows).
# 2026-03-30 09:22:31,638 - INFO - Fetched data for ELECON (2477 rows).
# 2026-03-30 09:22:32,231 - INFO - Fetched data for ELGIEQUIP (2477 rows).
# 2026-03-30 09:22:32,849 - INFO - Fetched data for EMAMILTD (2477 rows).
# 2026-03-30 09:22:33,397 - INFO - Fetched data for EMCURE (428 rows).
# 2026-03-30 09:22:34,047 - INFO - Fetched data for ENDURANCE (2343 rows).
# 2026-03-30 09:22:34,624 - INFO - Fetched data for ENGINERSIN (2477 rows).
# 2026-03-30 09:22:35,196 - INFO - Fetched data for ERIS (2170 rows).
# 2026-03-30 09:22:35,822 - INFO - Fetched data for ESCORTS (2477 rows).
# 2026-03-30 09:22:36,364 - INFO - Fetched data for ETERNAL (1162 rows).
# 2026-03-30 09:22:36,951 - INFO - Fetched data for EXIDEIND (2477 rows).
# 2026-03-30 09:22:37,527 - INFO - Fetched data for NYKAA (1089 rows).
# 2026-03-30 09:22:38,108 - INFO - Fetched data for FEDERALBNK (2477 rows).
# 2026-03-30 09:22:38,737 - INFO - Fetched data for FACT (2477 rows).
# 2026-03-30 09:22:39,380 - INFO - Fetched data for FINCABLES (2477 rows).
# 2026-03-30 09:22:39,976 - INFO - Fetched data for FINPIPE (2477 rows).
# 2026-03-30 09:22:40,554 - INFO - Fetched data for FSL (2477 rows).
# 2026-03-30 09:22:41,083 - INFO - Fetched data for FIVESTAR (834 rows).
# 2026-03-30 09:22:41,684 - INFO - Fetched data for FORTIS (2477 rows).
# 2026-03-30 09:22:42,286 - INFO - Fetched data for GAIL (2477 rows).
# 2026-03-30 09:22:42,901 - INFO - Fetched data for GVT&D (2477 rows).
# 2026-03-30 09:22:43,495 - INFO - Fetched data for GMRAIRPORT (2477 rows).
# 2026-03-30 09:22:44,087 - INFO - Fetched data for GRSE (1852 rows).
# 2026-03-30 09:22:44,739 - INFO - Fetched data for GICRE (2090 rows).
# 2026-03-30 09:22:45,325 - INFO - Fetched data for GILLETTE (2477 rows).
# 2026-03-30 09:22:45,880 - INFO - Fetched data for GLAND (1327 rows).
# 2026-03-30 09:22:46,593 - INFO - Fetched data for GLAXO (2477 rows).
# 2026-03-30 09:22:47,230 - INFO - Fetched data for GLENMARK (2477 rows).
# 2026-03-30 09:22:47,736 - INFO - Fetched data for MEDANTA (837 rows).
# 2026-03-30 09:22:48,269 - INFO - Fetched data for GODIGIT (461 rows).
# 2026-03-30 09:22:48,837 - INFO - Fetched data for GPIL (2477 rows).
# 2026-03-30 09:22:49,401 - INFO - Fetched data for GODFRYPHLP (2477 rows).
# 2026-03-30 09:22:49,982 - INFO - Fetched data for GODREJAGRO (2096 rows).
# 2026-03-30 09:22:50,617 - INFO - Fetched data for GODREJCP (2477 rows).
# 2026-03-30 09:22:51,171 - INFO - Fetched data for GODREJIND (2477 rows).
# 2026-03-30 09:22:51,742 - INFO - Fetched data for GODREJPROP (2477 rows).
# 2026-03-30 09:22:52,316 - INFO - Fetched data for GRANULES (2477 rows).
# 2026-03-30 09:22:52,911 - INFO - Fetched data for GRAPHITE (2477 rows).
# 2026-03-30 09:22:53,486 - INFO - Fetched data for GRASIM (2477 rows).
# 2026-03-30 09:22:54,120 - INFO - Fetched data for GRAVITA (2477 rows).
# 2026-03-30 09:22:54,658 - INFO - Fetched data for GESHIP (2477 rows).
# 2026-03-30 09:22:55,210 - INFO - Fetched data for FLUOROCHEM (1604 rows).
# 2026-03-30 09:22:55,840 - INFO - Fetched data for GUJGASLTD (2477 rows).
# 2026-03-30 09:22:56,419 - INFO - Fetched data for GMDCLTD (2477 rows).
# 2026-03-30 09:22:57,002 - INFO - Fetched data for GNFC (2477 rows).
# 2026-03-30 09:22:57,594 - INFO - Fetched data for GPPL (2477 rows).
# 2026-03-30 09:22:58,160 - INFO - Fetched data for GSPL (2477 rows).
# 2026-03-30 09:22:58,779 - INFO - Fetched data for HEG (2477 rows).
# 2026-03-30 09:22:59,386 - INFO - Fetched data for HBLENGINE (2477 rows).
# 2026-03-30 09:22:59,960 - INFO - Fetched data for HCLTECH (2477 rows).
# 2026-03-30 09:23:00,489 - INFO - Fetched data for HDFCAMC (1894 rows).
# 2026-03-30 09:23:01,076 - INFO - Fetched data for HDFCBANK (2477 rows).
# 2026-03-30 09:23:01,631 - INFO - Fetched data for HDFCLIFE (2073 rows).
# 2026-03-30 09:23:02,207 - INFO - Fetched data for HFCL (2477 rows).
# 2026-03-30 09:23:02,732 - INFO - Fetched data for HAPPSTMNDS (1372 rows).
# 2026-03-30 09:23:03,334 - INFO - Fetched data for HAVELLS (2477 rows).
# 2026-03-30 09:23:03,940 - INFO - Fetched data for HEROMOTOCO (2477 rows).
# 2026-03-30 09:23:04,553 - INFO - Fetched data for HSCL (2477 rows).
# 2026-03-30 09:23:05,106 - INFO - Fetched data for HINDALCO (2477 rows).
# 2026-03-30 09:23:05,716 - INFO - Fetched data for HAL (1984 rows).
# 2026-03-30 09:23:06,484 - INFO - Fetched data for HINDCOPPER (2477 rows).
# 2026-03-30 09:23:07,219 - INFO - Fetched data for HINDPETRO (2477 rows).
# 2026-03-30 09:23:07,805 - INFO - Fetched data for HINDUNILVR (2477 rows).
# 2026-03-30 09:23:08,404 - INFO - Fetched data for HINDZINC (2477 rows).
# 2026-03-30 09:23:08,999 - INFO - Fetched data for POWERINDIA (1490 rows).
# 2026-03-30 09:23:09,568 - INFO - Fetched data for HOMEFIRST (1277 rows).
# 2026-03-30 09:23:10,075 - INFO - Fetched data for HONASA (595 rows).
# 2026-03-30 09:23:10,663 - INFO - Fetched data for HONAUT (2477 rows).
# 2026-03-30 09:23:11,288 - INFO - Fetched data for HUDCO (2198 rows).
# 2026-03-30 09:23:11,775 - INFO - Fetched data for HYUNDAI (357 rows).
# 2026-03-30 09:23:12,367 - INFO - Fetched data for ICICIBANK (2477 rows).
# 2026-03-30 09:23:12,937 - INFO - Fetched data for ICICIGI (2108 rows).
# 2026-03-30 09:23:13,572 - INFO - Fetched data for ICICIPRULI (2355 rows).
# 2026-03-30 09:23:14,203 - INFO - Fetched data for IDBI (2477 rows).
# 2026-03-30 09:23:14,777 - INFO - Fetched data for IDFCFIRSTB (2476 rows).
# 2026-03-30 09:23:15,373 - INFO - Fetched data for IFCI (2477 rows).
# 2026-03-30 09:23:15,997 - INFO - Fetched data for IIFL (2477 rows).
# 2026-03-30 09:23:16,506 - INFO - Fetched data for INOXINDIA (564 rows).
# 2026-03-30 09:23:17,167 - INFO - Fetched data for IRB (2477 rows).
# 2026-03-30 09:23:17,744 - INFO - Fetched data for IRCON (1859 rows).
# 2026-03-30 09:23:18,365 - INFO - Fetched data for ITC (2477 rows).
# 2026-03-30 09:23:19,425 - INFO - Fetched data for ITI (2477 rows).
# 2026-03-30 09:23:20,104 - INFO - Fetched data for INDGN (469 rows).
# 2026-03-30 09:23:20,850 - INFO - Fetched data for INDIACEM (2477 rows).
# 2026-03-30 09:23:21,499 - INFO - Fetched data for INDIAMART (1672 rows).
# 2026-03-30 09:23:22,067 - INFO - Fetched data for INDIANB (2477 rows).
# 2026-03-30 09:23:22,655 - INFO - Fetched data for IEX (2092 rows).
# 2026-03-30 09:23:23,233 - INFO - Fetched data for INDHOTEL (2477 rows).
# 2026-03-30 09:23:23,812 - INFO - Fetched data for IOC (2477 rows).
# 2026-03-30 09:23:24,369 - INFO - Fetched data for IOB (2477 rows).
# 2026-03-30 09:23:24,907 - INFO - Fetched data for IRCTC (1606 rows).
# 2026-03-30 09:23:25,427 - INFO - Fetched data for IRFC (1280 rows).
# 2026-03-30 09:23:25,955 - INFO - Fetched data for IREDA (580 rows).
# 2026-03-30 09:23:26,563 - INFO - Fetched data for IGL (2477 rows).
# 2026-03-30 09:23:27,143 - INFO - Fetched data for INDUSTOWER (2477 rows).
# 2026-03-30 09:23:27,715 - INFO - Fetched data for INDUSINDBK (2477 rows).
# 2026-03-30 09:23:28,371 - INFO - Fetched data for NAUKRI (2477 rows).
# 2026-03-30 09:23:28,930 - INFO - Fetched data for INFY (2477 rows).
# 2026-03-30 09:23:29,505 - INFO - Fetched data for INOXWIND (2477 rows).
# 2026-03-30 09:23:30,088 - INFO - Fetched data for INTELLECT (2477 rows).
# 2026-03-30 09:23:30,672 - INFO - Fetched data for INDIGO (2477 rows).
# 2026-03-30 09:23:31,139 - INFO - Fetched data for IGIL (316 rows).
# 2026-03-30 09:23:31,617 - INFO - Fetched data for IKS (317 rows).
# 2026-03-30 09:23:32,177 - INFO - Fetched data for IPCALAB (2477 rows).
# 2026-03-30 09:23:32,747 - INFO - Fetched data for JBCHEPHARM (2477 rows).
# 2026-03-30 09:23:33,350 - INFO - Fetched data for JKCEMENT (2477 rows).
# 2026-03-30 09:23:33,927 - INFO - Fetched data for JBMA (2477 rows).
# 2026-03-30 09:23:34,517 - INFO - Fetched data for JKTYRE (2477 rows).
# 2026-03-30 09:23:35,105 - INFO - Fetched data for JMFINANCIL (2477 rows).
# 2026-03-30 09:23:35,689 - INFO - Fetched data for JSWENERGY (2477 rows).
# 2026-03-30 09:23:36,242 - INFO - Fetched data for JSWHL (2477 rows).
# 2026-03-30 09:23:36,718 - INFO - Fetched data for JSWINFRA (619 rows).
# 2026-03-30 09:23:37,293 - INFO - Fetched data for JSWSTEEL (2477 rows).
# 2026-03-30 09:23:37,851 - INFO - Fetched data for JPPOWER (2477 rows).
# 2026-03-30 09:23:38,443 - INFO - Fetched data for J&KBANK (2477 rows).
# 2026-03-30 09:23:39,017 - INFO - Fetched data for JINDALSAW (2477 rows).
# 2026-03-30 09:23:39,579 - INFO - Fetched data for JSL (2477 rows).
# 2026-03-30 09:23:40,127 - INFO - Fetched data for JINDALSTEL (2477 rows).
# 2026-03-30 09:23:40,608 - INFO - Fetched data for JIOFIN (648 rows).
# 2026-03-30 09:23:41,174 - INFO - Fetched data for JUBLFOOD (2477 rows).
# 2026-03-30 09:23:41,731 - INFO - Fetched data for JUBLINGREA (1246 rows).
# 2026-03-30 09:23:42,298 - INFO - Fetched data for JUBLPHARMA (1271 rows).
# 2026-03-30 09:23:42,877 - INFO - Fetched data for JWL (2477 rows).
# 2026-03-30 09:23:43,514 - INFO - Fetched data for JUSTDIAL (2477 rows).
# 2026-03-30 09:23:45,165 - INFO - Fetched data for JYOTHYLAB (2477 rows).
# 2026-03-30 09:23:45,674 - INFO - Fetched data for JYOTICNC (547 rows).
# 2026-03-30 09:23:46,269 - INFO - Fetched data for KPRMILL (2477 rows).
# 2026-03-30 09:23:46,838 - INFO - Fetched data for KEI (2477 rows).
# 2026-03-30 09:23:47,447 - INFO - Fetched data for KNRCON (2477 rows).
# 2026-03-30 09:23:47,983 - INFO - Fetched data for KPITTECH (1722 rows).
# 2026-03-30 09:23:48,573 - INFO - Fetched data for KAJARIACER (2477 rows).
# 2026-03-30 09:23:49,114 - INFO - Fetched data for KPIL (2477 rows).
# 2026-03-30 09:23:49,699 - INFO - Fetched data for KALYANKJIL (1241 rows).
# 2026-03-30 09:23:50,328 - INFO - Fetched data for KANSAINER (2477 rows).
# 2026-03-30 09:23:50,917 - INFO - Fetched data for KARURVYSYA (2477 rows).
# 2026-03-30 09:23:51,433 - INFO - Fetched data for KAYNES (833 rows).
# 2026-03-30 09:23:51,983 - INFO - Fetched data for KEC (2477 rows).
# 2026-03-30 09:23:52,524 - INFO - Fetched data for KFINTECH (806 rows).
# 2026-03-30 09:23:53,070 - INFO - Fetched data for KIRLOSBROS (2477 rows).
# 2026-03-30 09:23:53,617 - INFO - Fetched data for KIRLOSENG (2477 rows).
# 2026-03-30 09:23:54,194 - INFO - Fetched data for KOTAKBANK (2477 rows).
# 2026-03-30 09:23:54,756 - INFO - Fetched data for KIMS (1180 rows).
# 2026-03-30 09:23:55,383 - INFO - Fetched data for LTF (2477 rows).
# 2026-03-30 09:23:55,980 - INFO - Fetched data for LTTS (2359 rows).
# 2026-03-30 09:23:56,590 - INFO - Fetched data for LICHSGFIN (2477 rows).
# 2026-03-30 09:23:57,089 - INFO - Fetched data for LTFOODS (596 rows).
# 2026-03-30 09:23:57,673 - INFO - Fetched data for LTIM (2382 rows).
# 2026-03-30 09:23:58,247 - INFO - Fetched data for LT (2477 rows).
# 2026-03-30 09:23:58,744 - INFO - Fetched data for LATENTVIEW (1081 rows).
# 2026-03-30 09:23:59,350 - INFO - Fetched data for LAURUSLABS (2301 rows).
# 2026-03-30 09:23:59,887 - INFO - Fetched data for LEMONTREE (1978 rows).
# 2026-03-30 09:24:00,422 - INFO - Fetched data for LICI (962 rows).
# 2026-03-30 09:24:01,007 - INFO - Fetched data for LINDEINDIA (2477 rows).
# 2026-03-30 09:24:01,513 - INFO - Fetched data for LLOYDSME (672 rows).
# 2026-03-30 09:24:02,124 - INFO - Fetched data for LUPIN (2477 rows).
# 2026-03-30 09:24:02,770 - INFO - Fetched data for MMTC (2477 rows).
# 2026-03-30 09:24:03,323 - INFO - Fetched data for MRF (2477 rows).
# 2026-03-30 09:24:03,831 - INFO - Fetched data for LODHA (1228 rows).
# 2026-03-30 09:24:04,429 - INFO - Fetched data for MGL (2415 rows).
# 2026-03-30 09:24:05,011 - INFO - Fetched data for MAHSEAMLES (2477 rows).
# 2026-03-30 09:24:05,582 - INFO - Fetched data for M&MFIN (2477 rows).
# 2026-03-30 09:24:06,151 - INFO - Fetched data for M&M (2477 rows).
# 2026-03-30 09:24:06,736 - INFO - Fetched data for MANAPPURAM (2477 rows).
# 2026-03-30 09:24:07,315 - INFO - Fetched data for MRPL (2477 rows).
# 2026-03-30 09:24:07,821 - INFO - Fetched data for MANKIND (720 rows).
# 2026-03-30 09:24:08,413 - INFO - Fetched data for MARICO (2477 rows).
# 2026-03-30 09:24:09,006 - INFO - Fetched data for MARUTI (2477 rows).
# 2026-03-30 09:24:09,566 - INFO - Fetched data for MASTEK (2477 rows).
# 2026-03-30 09:24:10,134 - INFO - Fetched data for MFSL (2477 rows).
# 2026-03-30 09:24:10,660 - INFO - Fetched data for MAXHEALTH (1391 rows).
# 2026-03-30 09:24:11,192 - INFO - Fetched data for MAZDOCK (1357 rows).
# 2026-03-30 09:24:11,757 - INFO - Fetched data for METROPOLIS (1725 rows).
# 2026-03-30 09:24:12,307 - INFO - Fetched data for MINDACORP (2477 rows).
# 2026-03-30 09:24:12,828 - INFO - Fetched data for MSUMI (994 rows).
# 2026-03-30 09:24:13,391 - INFO - Fetched data for MOTILALOFS (2477 rows).
# 2026-03-30 09:24:13,971 - INFO - Fetched data for MPHASIS (2477 rows).
# 2026-03-30 09:24:14,600 - INFO - Fetched data for MCX (2477 rows).
# 2026-03-30 09:24:15,190 - INFO - Fetched data for MUTHOOTFIN (2477 rows).
# 2026-03-30 09:24:15,730 - INFO - Fetched data for NATCOPHARM (2477 rows).
# 2026-03-30 09:24:16,329 - INFO - Fetched data for NBCC (2477 rows).
# 2026-03-30 09:24:16,928 - INFO - Fetched data for NCC (2477 rows).
# 2026-03-30 09:24:17,521 - INFO - Fetched data for NHPC (2477 rows).
# 2026-03-30 09:24:18,151 - INFO - Fetched data for NLCINDIA (2477 rows).
# 2026-03-30 09:24:18,727 - INFO - Fetched data for NMDC (2477 rows).
# 2026-03-30 09:24:19,246 - INFO - Fetched data for NSLNISP (769 rows).
# 2026-03-30 09:24:19,723 - INFO - Fetched data for NTPCGREEN (333 rows).
# 2026-03-30 09:24:20,353 - INFO - Fetched data for NTPC (2477 rows).
# 2026-03-30 09:24:20,905 - INFO - Fetched data for NH (2477 rows).
# 2026-03-30 09:24:21,515 - INFO - Fetched data for NATIONALUM (2477 rows).
# 2026-03-30 09:24:22,121 - INFO - Fetched data for NAVA (2477 rows).
# 2026-03-30 09:24:22,679 - INFO - Fetched data for NAVINFLUOR (2477 rows).
# 2026-03-30 09:24:23,216 - INFO - Fetched data for NESTLEIND (2477 rows).
# 2026-03-30 09:24:23,738 - INFO - Fetched data for NETWEB (664 rows).
# 2026-03-30 09:24:24,334 - INFO - Fetched data for NETWORK18 (2477 rows).
# 2026-03-30 09:24:24,905 - INFO - Fetched data for NEULANDLAB (2477 rows).
# 2026-03-30 09:24:25,465 - INFO - Fetched data for NEWGEN (2024 rows).
# 2026-03-30 09:24:26,026 - INFO - Fetched data for NAM-INDIA (2081 rows).
# 2026-03-30 09:24:26,523 - INFO - Fetched data for NIVABUPA (340 rows).
# 2026-03-30 09:24:27,174 - INFO - Fetched data for NUVAMA (622 rows).
# 2026-03-30 09:24:27,931 - INFO - Fetched data for OBEROIRLTY (2477 rows).
# 2026-03-30 09:24:28,573 - INFO - Fetched data for ONGC (2477 rows).
# 2026-03-30 09:24:29,192 - INFO - Fetched data for OIL (2477 rows).
# 2026-03-30 09:24:29,669 - INFO - Fetched data for OLAELEC (407 rows).
# 2026-03-30 09:24:30,241 - INFO - Fetched data for OLECTRA (2477 rows).
# 2026-03-30 09:24:30,749 - INFO - Fetched data for PAYTM (1083 rows).
# 2026-03-30 09:24:31,289 - INFO - Fetched data for OFSS (2477 rows).
# 2026-03-30 09:24:31,968 - INFO - Fetched data for POLICYBZR (1086 rows).
# 2026-03-30 09:24:32,456 - INFO - Fetched data for PCBL (1044 rows).
# 2026-03-30 09:24:33,201 - INFO - Fetched data for PGEL (2477 rows).
# 2026-03-30 09:24:33,795 - INFO - Fetched data for PIIND (2477 rows).
# 2026-03-30 09:24:34,360 - INFO - Fetched data for PNBHOUSING (2330 rows).
# 2026-03-30 09:24:34,945 - INFO - Fetched data for PNCINFRA (2477 rows).
# 2026-03-30 09:24:35,447 - INFO - Fetched data for PTCIL (697 rows).
# 2026-03-30 09:24:36,040 - INFO - Fetched data for PVRINOX (2477 rows).
# 2026-03-30 09:24:36,603 - INFO - Fetched data for PAGEIND (2477 rows).
# 2026-03-30 09:24:37,085 - INFO - Fetched data for PATANJALI (921 rows).
# 2026-03-30 09:24:37,630 - INFO - Fetched data for PERSISTENT (2477 rows).
# 2026-03-30 09:24:38,178 - INFO - Fetched data for PETRONET (2477 rows).
# 2026-03-30 09:24:38,691 - INFO - Fetched data for PFIZER (2477 rows).
# 2026-03-30 09:24:39,249 - INFO - Fetched data for PHOENIXLTD (2477 rows).
# 2026-03-30 09:24:39,825 - INFO - Fetched data for PIDILITIND (2477 rows).
# 2026-03-30 09:24:40,492 - INFO - Fetched data for PEL (2349 rows).
# 2026-03-30 09:24:40,981 - INFO - Fetched data for PPLPHARMA (854 rows).
# 2026-03-30 09:24:41,582 - INFO - Fetched data for POLYMED (2477 rows).
# 2026-03-30 09:24:42,123 - INFO - Fetched data for POLYCAB (1724 rows).
# 2026-03-30 09:24:42,986 - INFO - Fetched data for POONAWALLA (2477 rows).
# 2026-03-30 09:24:43,704 - INFO - Fetched data for PFC (2477 rows).
# 2026-03-30 09:24:44,394 - INFO - Fetched data for POWERGRID (2477 rows).
# 2026-03-30 09:24:45,136 - INFO - Fetched data for PRAJIND (2477 rows).
# 2026-03-30 09:24:45,688 - INFO - Fetched data for PREMIERENE (391 rows).
# 2026-03-30 09:24:46,700 - INFO - Fetched data for PRESTIGE (2477 rows).
# 2026-03-30 09:24:49,640 - INFO - Fetched data for PNB (2477 rows).
# 2026-03-30 09:24:50,246 - INFO - Fetched data for RRKABEL (626 rows).
# 2026-03-30 09:24:50,934 - INFO - Fetched data for RBLBANK (2374 rows).
# 2026-03-30 09:24:52,021 - INFO - Fetched data for RECLTD (2477 rows).
# 2026-03-30 09:24:52,552 - INFO - Fetched data for RHIM (1164 rows).
# 2026-03-30 09:24:53,206 - INFO - Fetched data for RITES (1919 rows).
# 2026-03-30 09:24:53,855 - INFO - Fetched data for RADICO (2477 rows).
# 2026-03-30 09:24:54,422 - INFO - Fetched data for RVNL (1727 rows).
# 2026-03-30 09:24:54,952 - INFO - Fetched data for RAILTEL (1260 rows).
# 2026-03-30 09:24:55,639 - INFO - Fetched data for RAINBOW (966 rows).
# 2026-03-30 09:24:56,267 - INFO - Fetched data for RKFORGE (2477 rows).
# 2026-03-30 09:25:07,091 - INFO - Fetched data for RCF (2477 rows).
# 2026-03-30 09:25:08,308 - INFO - Fetched data for RTNINDIA (1236 rows).
# 2026-03-30 09:25:09,311 - INFO - Fetched data for RAYMONDLSL (389 rows).
# 2026-03-30 09:25:10,199 - INFO - Fetched data for RAYMOND (2477 rows).
# 2026-03-30 09:25:10,920 - INFO - Fetched data for REDINGTON (2477 rows).
# 2026-03-30 09:25:11,670 - INFO - Fetched data for RELIANCE (2477 rows).
# 2026-03-30 09:25:12,338 - INFO - Fetched data for RPOWER (2477 rows).
# 2026-03-30 09:25:12,944 - INFO - Fetched data for ROUTE (1371 rows).
# 2026-03-30 09:25:13,480 - INFO - Fetched data for SBFC (651 rows).
# 2026-03-30 09:25:14,072 - INFO - Fetched data for SBICARD (1500 rows).
# 2026-03-30 09:25:14,716 - INFO - Fetched data for SBILIFE (2105 rows).
# 2026-03-30 09:25:15,634 - INFO - Fetched data for SJVN (2477 rows).
# 2026-03-30 09:25:16,347 - INFO - Fetched data for SKFINDIA (2477 rows).
# 2026-03-30 09:25:17,057 - INFO - Fetched data for SRF (2477 rows).
# 2026-03-30 09:25:17,606 - INFO - Fetched data for SAGILITY (342 rows).
# 2026-03-30 09:25:18,105 - INFO - Fetched data for SAILIFE (318 rows).
# 2026-03-30 09:25:18,787 - INFO - Fetched data for SAMMAANCAP (2477 rows).
# 2026-03-30 09:25:19,351 - INFO - Fetched data for MOTHERSON (2477 rows).
# 2026-03-30 09:25:19,900 - INFO - Fetched data for SAPPHIRE (1083 rows).
# 2026-03-30 09:25:20,510 - INFO - Fetched data for SARDAEN (2477 rows).
# 2026-03-30 09:25:21,190 - INFO - Fetched data for SAREGAMA (2477 rows).
# 2026-03-30 09:25:21,877 - INFO - Fetched data for SCHAEFFLER (2477 rows).
# 2026-03-30 09:25:22,570 - INFO - Fetched data for SCHNEIDER (2477 rows).
# 2026-03-30 09:25:23,208 - INFO - Fetched data for SCI (2477 rows).
# 2026-03-30 09:25:24,104 - INFO - Fetched data for SHREECEM (2477 rows).
# 2026-03-30 09:25:24,912 - INFO - Fetched data for RENUKA (2477 rows).
# 2026-03-30 09:25:25,908 - INFO - Fetched data for SHRIRAMFIN (2477 rows).
# 2026-03-30 09:25:26,493 - INFO - Fetched data for SHYAMMETL (1182 rows).
# 2026-03-30 09:25:27,159 - INFO - Fetched data for SIEMENS (2477 rows).
# 2026-03-30 09:25:27,795 - INFO - Fetched data for SIGNATURE (621 rows).
# 2026-03-30 09:25:28,438 - INFO - Fetched data for SOBHA (2477 rows).
# 2026-03-30 09:25:29,178 - INFO - Fetched data for SOLARINDS (2477 rows).
# 2026-03-30 09:25:29,885 - INFO - Fetched data for SONACOMS (1182 rows).
# 2026-03-30 09:25:30,573 - INFO - Fetched data for SONATSOFTW (2477 rows).
# 2026-03-30 09:25:31,196 - INFO - Fetched data for STARHEALTH (1067 rows).
# 2026-03-30 09:25:31,907 - INFO - Fetched data for SBIN (2477 rows).
# 2026-03-30 09:25:32,620 - INFO - Fetched data for SAIL (2477 rows).
# 2026-03-30 09:25:33,254 - INFO - Fetched data for SWSOLAR (1641 rows).
# 2026-03-30 09:25:33,916 - INFO - Fetched data for SUMICHEM (1533 rows).
# 2026-03-30 09:25:34,943 - INFO - Fetched data for SUNPHARMA (2477 rows).
# 2026-03-30 09:25:35,743 - INFO - Fetched data for SUNTV (2477 rows).
# 2026-03-30 09:25:36,502 - INFO - Fetched data for SUNDARMFIN (2477 rows).
# 2026-03-30 09:25:37,226 - INFO - Fetched data for SUNDRMFAST (2477 rows).
# 2026-03-30 09:25:37,811 - INFO - Fetched data for SUPREMEIND (2477 rows).
# 2026-03-30 09:25:38,374 - INFO - Fetched data for SUZLON (2477 rows).
# (2026-03-30 09:25:38,819) ERROR :: <class 'AttributeError'> -> 'DataFrame' object has no attribute 'timestamp' (PID:25224 Thread:25096)
# 2026-03-30 09:25:38,819 - ERROR - <class 'AttributeError'> -> 'DataFrame' object has no attribute 'timestamp'
# 2026-03-30 09:25:38,822 - ERROR - Failed to fetch data for SWANENERGY: 'NoneType' object does not support item assignment
# 2026-03-30 09:25:39,181 - INFO - Fetched data for SWIGGY (341 rows).
# 2026-03-30 09:25:39,771 - INFO - Fetched data for SYNGENE (2477 rows).
# 2026-03-30 09:25:40,249 - INFO - Fetched data for SYRMA (891 rows).
# 2026-03-30 09:25:40,734 - INFO - Fetched data for TBOTEK (467 rows).
# 2026-03-30 09:25:41,337 - INFO - Fetched data for TVSMOTOR (2477 rows).
# 2026-03-30 09:25:41,916 - INFO - Fetched data for TANLA (2477 rows).
# 2026-03-30 09:25:42,567 - INFO - Fetched data for TATACHEM (2477 rows).
# 2026-03-30 09:25:43,121 - INFO - Fetched data for TATACOMM (2477 rows).
# 2026-03-30 09:25:45,425 - INFO - Fetched data for TCS (2477 rows).
# 2026-03-30 09:25:46,083 - INFO - Fetched data for TATACONSUM (2476 rows).
# 2026-03-30 09:25:46,652 - INFO - Fetched data for TATAELXSI (2477 rows).
# 2026-03-30 09:25:47,324 - INFO - Fetched data for TATAINVEST (2477 rows).
# (2026-03-30 09:25:47,800) ERROR :: <class 'AttributeError'> -> 'DataFrame' object has no attribute 'timestamp' (PID:25224 Thread:25096)
# 2026-03-30 09:25:47,800 - ERROR - <class 'AttributeError'> -> 'DataFrame' object has no attribute 'timestamp'
# 2026-03-30 09:25:47,803 - ERROR - Failed to fetch data for TATAMOTORS: 'NoneType' object does not support item assignment
# 2026-03-30 09:25:48,309 - INFO - Fetched data for TATAPOWER (2477 rows).
# 2026-03-30 09:25:48,852 - INFO - Fetched data for TATASTEEL (2477 rows).
# 2026-03-30 09:25:49,397 - INFO - Fetched data for TATATECH (579 rows).
# 2026-03-30 09:25:49,967 - INFO - Fetched data for TTML (2477 rows).
# 2026-03-30 09:25:50,557 - INFO - Fetched data for TECHM (2477 rows).
# 2026-03-30 09:25:51,063 - INFO - Fetched data for TECHNOE (1816 rows).
# 2026-03-30 09:25:51,602 - INFO - Fetched data for TEJASNET (2172 rows).
# 2026-03-30 09:25:52,168 - INFO - Fetched data for NIACL (2077 rows).
# 2026-03-30 09:25:52,750 - INFO - Fetched data for RAMCOCEM (2477 rows).
# 2026-03-30 09:25:53,319 - INFO - Fetched data for THERMAX (2477 rows).
# 2026-03-30 09:25:53,983 - INFO - Fetched data for TIMKEN (2477 rows).
# 2026-03-30 09:25:54,534 - INFO - Fetched data for TITAGARH (2477 rows).
# 2026-03-30 09:25:55,073 - INFO - Fetched data for TITAN (2477 rows).
# 2026-03-30 09:25:55,643 - INFO - Fetched data for TORNTPHARM (2477 rows).
# 2026-03-30 09:25:56,175 - INFO - Fetched data for TORNTPOWER (2477 rows).
# 2026-03-30 09:25:56,795 - INFO - Fetched data for TARIL (2477 rows).
# 2026-03-30 09:25:57,509 - INFO - Fetched data for TRENT (2477 rows).
# 2026-03-30 09:25:58,092 - INFO - Fetched data for TRIDENT (2477 rows).
# 2026-03-30 09:25:58,709 - INFO - Fetched data for TRIVENI (2477 rows).
# 2026-03-30 09:25:59,276 - INFO - Fetched data for TRITURBINE (2477 rows).
# 2026-03-30 09:25:59,843 - INFO - Fetched data for TIINDIA (2084 rows).
# 2026-03-30 09:26:00,470 - INFO - Fetched data for UCOBANK (2477 rows).
# 2026-03-30 09:26:01,073 - INFO - Fetched data for UNOMINDA (2477 rows).
# 2026-03-30 09:26:01,689 - INFO - Fetched data for UPL (2477 rows).
# 2026-03-30 09:26:02,203 - INFO - Fetched data for UTIAMC (1357 rows).
# 2026-03-30 09:26:02,765 - INFO - Fetched data for ULTRACEMCO (2477 rows).
# 2026-03-30 09:26:03,370 - INFO - Fetched data for UNIONBANK (2477 rows).
# 2026-03-30 09:26:03,954 - INFO - Fetched data for UBL (2477 rows).
# 2026-03-30 09:26:04,578 - INFO - Fetched data for UNITDSPR (2477 rows).
# 2026-03-30 09:26:05,197 - INFO - Fetched data for USHAMART (2477 rows).
# 2026-03-30 09:26:05,807 - INFO - Fetched data for VGUARD (2477 rows).
# 2026-03-30 09:26:06,403 - INFO - Fetched data for DBREALTY (2477 rows).
# 2026-03-30 09:26:07,090 - INFO - Fetched data for VTL (2477 rows).
# 2026-03-30 09:26:07,644 - INFO - Fetched data for VBL (2329 rows).
# 2026-03-30 09:26:08,175 - INFO - Fetched data for MANYAVAR (1021 rows).
# 2026-03-30 09:26:08,742 - INFO - Fetched data for VEDL (2477 rows).
# 2026-03-30 09:26:09,326 - INFO - Fetched data for VIJAYA (1128 rows).
# 2026-03-30 09:26:09,834 - INFO - Fetched data for VMM (318 rows).
# 2026-03-30 09:26:10,395 - INFO - Fetched data for IDEA (2476 rows).
# 2026-03-30 09:26:10,956 - INFO - Fetched data for VOLTAS (2477 rows).
# 2026-03-30 09:26:11,429 - INFO - Fetched data for WAAREEENER (353 rows).
# 2026-03-30 09:26:11,998 - INFO - Fetched data for WELCORP (2477 rows).
# 2026-03-30 09:26:12,503 - INFO - Fetched data for WELSPUNLIV (569 rows).
# 2026-03-30 09:26:13,002 - INFO - Fetched data for WESTLIFE (1641 rows).
# 2026-03-30 09:26:13,556 - INFO - Fetched data for WHIRLPOOL (2477 rows).
# 2026-03-30 09:26:14,117 - INFO - Fetched data for WIPRO (2477 rows).
# 2026-03-30 09:26:14,682 - INFO - Fetched data for WOCKPHARMA (2477 rows).
# 2026-03-30 09:26:15,259 - INFO - Fetched data for YESBANK (2477 rows).
# 2026-03-30 09:26:15,791 - INFO - Fetched data for ZFCVINDIA (991 rows).
# 2026-03-30 09:26:16,376 - INFO - Fetched data for ZEEL (2477 rows).
# 2026-03-30 09:26:16,957 - INFO - Fetched data for ZENTEC (2477 rows).
# 2026-03-30 09:26:17,561 - INFO - Fetched data for ZENSARTECH (2477 rows).
