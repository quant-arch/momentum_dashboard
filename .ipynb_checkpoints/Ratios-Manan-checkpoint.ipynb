# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_excel("C:\\Users\\Admin\\Momentum\\Automating Momentum True Data\\Trials\\Nifty_500_2025_Apr_20_stocks_results_GoldSilverDebt_buy&hold_returns.xlsx")
data
# Out:
#             Date      Open      High       Low     Close      volume   oi  \
# 0     2023-04-03    154.00    154.90    152.00    153.80   2347046.0  0.0
# 1     2023-04-03    407.00    410.95    403.05    405.15    112564.0  0.0
# 2     2023-04-03    169.10    170.25    168.10    169.20  16659059.0  0.0
# 3     2023-04-03     75.00     76.45     74.10     75.95   8102076.0  0.0
# 4     2023-04-03  19500.00  19500.85  19200.00  19434.25     29923.0  0.0
# ...          ...       ...       ...       ...       ...         ...  ...
# 14522 2026-01-05    222.90       NaN       NaN    225.54         NaN  NaN
# 14523 2026-01-06    228.16       NaN       NaN    231.65         NaN  NaN
# 14524 2026-01-07    237.60       NaN       NaN    234.36         NaN  NaN
# 14525 2026-01-08    232.70       NaN       NaN    223.53         NaN  NaN
# 14526 2026-01-09    224.20       NaN       NaN    226.32         NaN  NaN
#
#            Ticker   %change  Buy_Hold_Value  Total_Portfolio_Value
# 0       ABCAPITAL  0.001628        3.756106              75.779854
# 1      ANANDRATHI  0.003219        3.762071              75.779854
# 2      BANKBARODA  0.002073        3.757773              75.779854
# 3       BANKINDIA  0.017415        3.815305              75.779854
# 4        BOSCHLTD  0.003322        3.762458              75.779854
# ...           ...       ...             ...                    ...
# 14522  SILVERBEES  0.016541       14.735995                    NaN
# 14523  SILVERBEES  0.027091       15.135202                    NaN
# 14524  SILVERBEES  0.011699       15.312263                    NaN
# 14525  SILVERBEES -0.046211       14.604669                    NaN
# 14526  SILVERBEES  0.012482       14.786958                    NaN
#
# [14527 rows x 11 columns]

# %%
# max_date_tickers = data[(data['Date'] == '2025-12-31')]
# max_date_tickers
max_date_tickers = data[(data['Date'] == data['Date'].max())]
max_date_tickers
# Out:
#             Date     Open     High      Low    Close     volume   oi  \
# 14420 2026-01-09  3139.60  3144.60  3111.20  3130.70    51934.0  0.0
# 14421 2026-01-09   150.40   152.43   149.21   152.33  5857374.0  0.0
# 14422 2026-01-09  4120.10  4193.50  4120.10  4154.20   120752.0  0.0
# 14423 2026-01-09  7582.00  7613.50  7551.00  7570.00   133769.0  0.0
# 14424 2026-01-09   267.20   271.00   263.55   269.25   388515.0  0.0
# 14425 2026-01-09   910.00   918.95   888.85   906.55   610517.0  0.0
# 14426 2026-01-09  5850.00  5891.00  5797.50  5808.00   143394.0  0.0
# 14427 2026-01-09   902.00   908.45   894.00   902.10  1093563.0  0.0
# 14428 2026-01-09   647.90   653.90   638.65   648.45   440561.0  0.0
# 14429 2026-01-09   507.00   515.50   504.05   512.30   318031.0  0.0
# 14430 2026-01-09   803.70   807.00   780.30   787.55   270384.0  0.0
# 14431 2026-01-09  1095.00  1102.50  1085.70  1098.80   431393.0  0.0
# 14432 2026-01-09   306.00   310.00   304.65   307.95   946476.0  0.0
# 14433 2026-01-09   356.40   359.30   350.15   354.75   726215.0  0.0
# 14434 2026-01-09   330.85   344.55   328.85   342.90  6499589.0  0.0
# 14435 2026-01-09   257.00   258.60   253.00   256.05  1118560.0  0.0
# 14436 2026-01-09  3091.20  3091.20  3031.00  3033.00    59563.0  0.0
# 14437 2026-01-09   996.00  1006.40   994.00  1006.00   885834.0  0.0
# 14438 2026-01-09   987.00   993.20   979.80   985.35  1257740.0  0.0
# 14439 2026-01-09   603.00   615.30   602.35   611.45  4400225.0  0.0
# 14468 2026-01-09   113.26      NaN      NaN   112.98        NaN  NaN
# 14497 2026-01-09    62.94      NaN      NaN    62.99        NaN  NaN
# 14526 2026-01-09   224.20      NaN      NaN   226.32        NaN  NaN
#
#            Ticker   %change  Buy_Hold_Value  Total_Portfolio_Value
# 14420  ANANDRATHI -0.003692       10.581379             220.107953
# 14421       CANBK  0.012429       10.344327             220.107953
# 14422  CUMMINSIND  0.008791       10.159561             220.107953
# 14423   EICHERMOT  0.002516       11.157720             220.107953
# 14424        GPIL -0.000557       10.645254             220.107953
# 14425   HBLENGINE -0.004994       10.883288             220.107953
# 14426  HEROMOTOCO -0.007179       11.296974             220.107953
# 14427    HINDALCO -0.002047       11.303762             220.107953
# 14428        IIFL  0.001390       11.173444             220.107953
# 14429      JKTYRE  0.010753       10.720418             220.107953
# 14430         JSL -0.022648        9.871497             220.107953
# 14431  LAURUSLABS -0.001908       13.146141             220.107953
# 14432         LTF  0.002115       13.740296             220.107953
# 14433      M&MFIN -0.000845        9.918337             220.107953
# 14434  NATIONALUM  0.028186       13.712347             220.107953
# 14435       NYKAA -0.002338        9.958498             220.107953
# 14436      RADICO -0.015068        9.673092             220.107953
# 14437        SBIN  0.008016       10.774430             220.107953
# 14438  SHRIRAMFIN -0.007604       10.404955             220.107953
# 14439        VEDL  0.013173       10.642232             220.107953
# 14468    GOLDBEES  0.006145       33.183865                    NaN
# 14497      MOGSEC  0.003665       10.247685                    NaN
# 14526  SILVERBEES  0.012482       14.786958                    NaN

# %%
total_value = max_date_tickers['Buy_Hold_Value'].sum()

# Calculate weights
max_date_tickers['Weight'] = max_date_tickers['Buy_Hold_Value'] / total_value

# Format as percentage (optional)
max_date_tickers['Weight_Percent'] = max_date_tickers['Weight']

max_date_tickers
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_20464\2488948854.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   max_date_tickers['Weight'] = max_date_tickers['Buy_Hold_Value'] / total_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_20464\2488948854.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   max_date_tickers['Weight_Percent'] = max_date_tickers['Weight']
#             Date     Open     High      Low    Close     volume   oi  \
# 14420 2026-01-09  3139.60  3144.60  3111.20  3130.70    51934.0  0.0
# 14421 2026-01-09   150.40   152.43   149.21   152.33  5857374.0  0.0
# 14422 2026-01-09  4120.10  4193.50  4120.10  4154.20   120752.0  0.0
# 14423 2026-01-09  7582.00  7613.50  7551.00  7570.00   133769.0  0.0
# 14424 2026-01-09   267.20   271.00   263.55   269.25   388515.0  0.0
# 14425 2026-01-09   910.00   918.95   888.85   906.55   610517.0  0.0
# 14423        0.040089
# 14424        0.038247
# 14425        0.039103
# 14426        0.040589
# 14427        0.040613
# 14428        0.040145
# 14429        0.038517
# 14430        0.035467
# 14431        0.047233
# 14432        0.049368
# 14433        0.035636
# 14434        0.049267
# 14435        0.035780
# 14436        0.034754
# 14437        0.038711
# 14438        0.037384
# 14439        0.038237
# 14468        0.119226
# 14497        0.036819
# 14526        0.053128

# %%
# Convert to dictionary
weights = dict(zip(max_date_tickers['Ticker'], max_date_tickers['Weight']))

weights
# Out:
# {'ANANDRATHI': 0.03801787077559736,
#  'CANBK': 0.03716616338080143,
#  'CUMMINSIND': 0.036502318247791946,
#  'EICHERMOT': 0.04008860621116982,
#  'GPIL': 0.038247367247248226,
#  'HBLENGINE': 0.03910259938295028,
#  'HEROMOTOCO': 0.040588931191076726,
#  'HINDALCO': 0.040613322350066525,
#  'IIFL': 0.04014510238516204,
#  'JKTYRE': 0.03851742221626549,
#  'JSL': 0.03546733275233086,
#  'LAURUSLABS': 0.0472328118206203,
#  'LTF': 0.0493675516270251,
#  'M&MFIN': 0.03563562388786013,
#  'NATIONALUM': 0.049267133435071504,
#  'NYKAA': 0.03577991648497405,
#  'RADICO': 0.034754482972122414,
#  'SBIN': 0.0387114817020445,
#  'SHRIRAMFIN': 0.037383996476767385,
#  'VEDL': 0.038236509261853756,
#  'GOLDBEES': 0.11922641176200725,
#  'MOGSEC': 0.03681893762462289,
#  'SILVERBEES': 0.05312810680456987}

# %%
tickers = list(max_date_tickers['Ticker'].unique()) + ['NIFTY 500']
# tickers = [
#     "ABCAPITAL",
#     "AIIL",
#     "BOSCHLTD",
#     "DATAPATTNS",
#     "DELHIVERY",
#     "ETERNAL",
#     "GOLDBEES",
#     "GVT&D",
#     "HBLENGINE",
#     "HEROMOTOCO",
#     "HINDCOPPER",
#     "HYUNDAI",
#     "IIFL",
#     "INTELLECT",
#     "LAURUSLABS",
#     "LTF",
#     "MFSL",
#     "NETWEB",
#     "POLYCAB",
#     "SYRMA",
#     "TATAINVEST",
#     "NIFTY 500"
# ]

# tickers

# %%
len(tickers)
# Out:
# 24

# %%
import time
import logging
import pandas as pd
from truedata import TD_hist

def fetch_truedata_history(
    ticker_list: list,
    duration: str = '1 Y',
    bar_size: str = 'EOD',
    sleep_time: float = 0.1
) -> tuple[pd.DataFrame, list]:
    """
    Fetches historical data from TrueData for a list of tickers.

    Parameters
    ----------
    username : str
        TrueData username.
    password : str
        TrueData password.
    ticker_list : list
        List of ticker symbols to fetch data for.
    duration : str, optional
        Duration of data (e.g., '1 Y', '25 Y', etc.). Default is '1 Y'.
    bar_size : str, optional
        Bar size for data ('EOD', 'WEEK', etc.). Default is 'EOD'.
    sleep_time : float, optional
        Delay between API calls to avoid throttling. Default is 0.2 seconds.

    Returns
    -------
    final_df : pd.DataFrame
        Combined DataFrame of all tickers' historical data.
    error_list : list
        List of tickers that failed to fetch.
    """
    logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
    # username =  'tdwsf695'
    # password = 'ocean@695'
    username =  'td105'
    password = 'sharma@105'
    # Initialize connection
    td_hist = TD_hist(username, password)
    df_list = []
    error_list = []
    for ticker in ticker_list:
        try:
            df = td_hist.get_historic_data([ticker], duration=duration, bar_size=bar_size)

            df['Ticker'] = ticker
            df = df.rename(columns={
                'timestamp': 'Date',
                'high': 'High',
                'low': 'Low',
                'close': 'Close',
                'open': 'Open'
            })

            df_list.append(df)
            logging.info(f"Fetched data for {ticker} ({len(df)} rows).")
            time.sleep(sleep_time)

        except Exception as e:
            logging.error(f"Failed to fetch data for {ticker}: {e}")
            error_list.append(ticker)

    final_df = pd.concat(df_list, ignore_index=True) if df_list else pd.DataFrame()
    return final_df, error_list

# %%
 ticker_data = fetch_truedata_history(
        ticker_list = tickers,
        duration = '2 Y',
        bar_size = 'EOD',
        sleep_time= 0.1
    )[0][['Ticker','Date', 'Close']]
ticker_data
# Out:
# (2026-01-09 10:14:45,895) WARNING :: Connected successfully to TrueData Historical Data Service...  (PID:20464 Thread:9788)
# 2026-01-09 10:14:45,895 - WARNING - Connected successfully to TrueData Historical Data Service...
# 2026-01-09 10:14:46,023 - INFO - Fetched data for ANANDRATHI (499 rows).
# 2026-01-09 10:14:46,218 - INFO - Fetched data for CANBK (499 rows).
# 2026-01-09 10:14:46,434 - INFO - Fetched data for CUMMINSIND (499 rows).
# 2026-01-09 10:14:46,639 - INFO - Fetched data for EICHERMOT (499 rows).
# 2026-01-09 10:14:46,838 - INFO - Fetched data for GPIL (499 rows).
# 2026-01-09 10:14:47,048 - INFO - Fetched data for HBLENGINE (499 rows).
# 2026-01-09 10:14:47,247 - INFO - Fetched data for HEROMOTOCO (499 rows).
# 2026-01-09 10:14:47,433 - INFO - Fetched data for HINDALCO (499 rows).
# 2026-01-09 10:14:47,649 - INFO - Fetched data for IIFL (499 rows).
# 2026-01-09 10:14:47,860 - INFO - Fetched data for JKTYRE (499 rows).
# 2026-01-09 10:14:48,063 - INFO - Fetched data for JSL (499 rows).
# 2026-01-09 10:14:48,267 - INFO - Fetched data for LAURUSLABS (499 rows).
# 2026-01-09 10:14:48,504 - INFO - Fetched data for LTF (499 rows).
# 2026-01-09 10:14:48,701 - INFO - Fetched data for M&MFIN (499 rows).
# 2026-01-09 10:14:48,903 - INFO - Fetched data for NATIONALUM (499 rows).
# 2026-01-09 10:14:49,113 - INFO - Fetched data for NYKAA (499 rows).
# 2026-01-09 10:14:49,317 - INFO - Fetched data for RADICO (499 rows).
# 2026-01-09 10:14:49,534 - INFO - Fetched data for SBIN (499 rows).
# 2026-01-09 10:14:49,737 - INFO - Fetched data for SHRIRAMFIN (499 rows).
# 2026-01-09 10:14:49,937 - INFO - Fetched data for VEDL (499 rows).
# 2026-01-09 10:14:50,144 - INFO - Fetched data for GOLDBEES (499 rows).
# 2026-01-09 10:14:50,346 - INFO - Fetched data for MOGSEC (500 rows).
# 2026-01-09 10:14:50,583 - INFO - Fetched data for SILVERBEES (499 rows).
# 2026-01-09 10:14:50,784 - INFO - Fetched data for NIFTY 500 (499 rows).
#            Ticker       Date     Close
# 0      ANANDRATHI 2024-01-09   1391.30
# 1      ANANDRATHI 2024-01-10   1390.60
# 2      ANANDRATHI 2024-01-11   1401.30
# 3      ANANDRATHI 2024-01-12   1407.55
# 4      ANANDRATHI 2024-01-15   1343.75
# ...           ...        ...       ...
# 11972   NIFTY 500 2026-01-05  24058.45
# 11973   NIFTY 500 2026-01-06  24010.50
# 11974   NIFTY 500 2026-01-07  24016.60
# 11975   NIFTY 500 2026-01-08  23680.10
# 11976   NIFTY 500 2026-01-09  23667.65
#
# [11977 rows x 3 columns]

# %%
ticker_data[ticker_data.duplicated(subset=['Ticker', 'Date'])]
# Out:
#        Ticker       Date  Close
# 10489  MOGSEC 2024-01-20  54.22

# %%
ticker_data = ticker_data.drop_duplicates(subset=['Ticker', 'Date'])

# %%
# ticker_data[ticker_data['Ticker'] == 'MOGSEC'].to_excel('MOGSEC.xlsx', index=False)

# %%
ticker_data.pivot(index="Date", columns="Ticker", values="Close").sort_index()
# Out:
# Ticker      ANANDRATHI   CANBK  CUMMINSIND  EICHERMOT  GOLDBEES    GPIL  \
# Date
# 2024-01-09     1391.30   90.10     2025.90    3870.45     53.02  152.60
# 2024-01-10     1390.60   89.75     2046.15    3842.55     52.92  154.50
# 2024-01-11     1401.30   90.90     2035.70    3888.80     52.84  155.80
#  'CANBK': 0.03716616338080143,
#  'CUMMINSIND': 0.036502318247791946,
#  'EICHERMOT': 0.04008860621116982,
#  'GPIL': 0.038247367247248226,
#  'HBLENGINE': 0.03910259938295028,
#  'HEROMOTOCO': 0.040588931191076726,
#  'HINDALCO': 0.040613322350066525,
#  'IIFL': 0.04014510238516204,
#  'JKTYRE': 0.03851742221626549,
#  'JSL': 0.03546733275233086,
#  'LAURUSLABS': 0.0472328118206203,
#  'LTF': 0.0493675516270251,
#  'M&MFIN': 0.03563562388786013,
#  'NATIONALUM': 0.049267133435071504,
#  'NYKAA': 0.03577991648497405,
#  'RADICO': 0.034754482972122414,
#  'SBIN': 0.0387114817020445,
#  'SHRIRAMFIN': 0.037383996476767385,
#  'VEDL': 0.038236509261853756,
#  'GOLDBEES': 0.11922641176200725,
#  'MOGSEC': 0.03681893762462289,
#  'SILVERBEES': 0.05312810680456987}

# %%
import pandas as pd
import numpy as np

def calculate_portfolio_beta_from_df(df, benchmark_name, weights_dict=None):
    """
    df: DataFrame with columns ['Ticker','Date','Close']
    benchmark_name: name used in the 'Ticker' column for your benchmark
    weights_dict: {'ABCAPITAL':0.1, 'BOSCHLTD':0.05, ...}
    """

    df['Date'] = pd.to_datetime(df['Date'])


    # Pivot → Date index, ticker columns
    price_df = df.pivot(index="Date", columns="Ticker", values="Close").sort_index()

    # keep only last 1 year
    price_df = price_df.last("252D")
    # print(price_df)

    # print(price_df)

    # Extract benchmark + stocks separately
    benchmark = price_df[benchmark_name]
    stock_prices = price_df.drop(columns=[benchmark_name])

    # daily returns
    returns = price_df.pct_change().dropna()
    stock_returns = returns.drop(columns=[benchmark_name])
    bench_ret = returns[benchmark_name]

    # weights: equal-weight if not given
    if weights_dict is None:
        n = stock_returns.shape[1]
        weights_dict = {col: 1/n for col in stock_returns.columns}

    weights = pd.Series(weights_dict).reindex(stock_returns.columns).fillna(0)

    # portfolio daily return
    portfolio_ret = (stock_returns * weights).sum(axis=1)

    # beta = Cov(portfolio, benchmark) / Var(benchmark)
    covariance = np.cov(portfolio_ret, bench_ret)[0][1]
    variance = np.var(bench_ret)

    beta = covariance / variance

    return beta, portfolio_ret, bench_ret

# %%
calculate_portfolio_beta_from_df(ticker_data, 'NIFTY 500', weights)[0]
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_20464\2096940647.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_20464\2096940647.py:18: FutureWarning: last is deprecated and will be removed in a future version. Please create a mask and filter using `.loc` instead
#   price_df = price_df.last("252D")
# 0.8959983652091285

# %%
current_beta = pd.DataFrame({'Beta': [calculate_portfolio_beta_from_df(ticker_data, 'NIFTY 500', weights)[0]]})
current_beta.to_excel('momentum_ratios.xlsx', index=False)
current_beta
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_20464\2096940647.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_20464\2096940647.py:18: FutureWarning: last is deprecated and will be removed in a future version. Please create a mask and filter using `.loc` instead
#   price_df = price_df.last("252D")
#        Beta
# 0  0.895998

# %%
weights = dict(sorted(weights.items(), key=lambda x: x[0]))
weights
# Out:
# {'ABCAPITAL': 0.03805270895430915,
#  'AUBANK': 0.040184860213963565,
#  'CUMMINSIND': 0.04138595454402157,
#  'EICHERMOT': 0.039190419491572835,
#  'GOLDBEES': 0.1211659607823858,
#  'HBLENGINE': 0.03616051283024892,
#  'HEROMOTOCO': 0.04355121752398137,
#  'HINDALCO': 0.03949798938680715,
#  'INDIANB': 0.03601745556350235,
#  'LAURUSLABS': 0.04510734212980908,
#  'LTF': 0.05053556022417407,
#  'LTIM': 0.039913337740724156,
#  'M&MFIN': 0.03596149148514988,
#  'MARUTI': 0.04026377481396207,
#  'MCX': 0.039497707106678465,
#  'MOGSEC': 0.03843891128847186,
#  'MUTHOOTFIN': 0.04022080576105464,
#  'NATIONALUM': 0.04168619040022149,
#  'NYKAA': 0.036215670472334135,
#  'PAYTM': 0.039333661869591176,
#  'POLYCAB': 0.0378754600500955,
#  'SILVERBEES': 0.045436251074405284,
#  'SYRMA': 0.034306756292535476}

# %%
len(weights)
# Out:
# 23

# %%
portfolio_data = ticker_data[ticker_data['Ticker']!='NIFTY 500']
portfolio_data
# Out:
#            Ticker       Date   Close
# 0       ABCAPITAL 2023-12-18  165.90
# 1       ABCAPITAL 2023-12-19  164.75
# 2       ABCAPITAL 2023-12-20  156.95
# 3       ABCAPITAL 2023-12-21  159.20
# 4       ABCAPITAL 2023-12-22  159.70
# ...           ...        ...     ...
# 11427  SILVERBEES 2025-12-10  175.29
# 11428  SILVERBEES 2025-12-11  178.85
# 11429  SILVERBEES 2025-12-12  184.13
# 11430  SILVERBEES 2025-12-15  184.87
# 11431  SILVERBEES 2025-12-16  184.69
#
# [11431 rows x 3 columns]

# %%
# import pandas as pd
# import numpy as np

# def calculate_portfolio_std_from_df(df, weights_dict):
#     """
#     df: DataFrame containing ['Ticker','Date','Close']
#     weights_dict: dict of weights {Ticker: weight}
#     """

#     df['Date'] = pd.to_datetime(df['Date'])

#     # Pivot: rows = Date, columns = Ticker
#     price_df = df.pivot(index="Date", columns="Ticker", values="Close").sort_index()

#     # keep only last 1 year
#     price_df = price_df.last("252D")

#     # daily returns
#     returns = price_df.pct_change().dropna()
#     # returns = returns.drop(columns=['NIFTY 500'])
#     returns.to_excel('momentum_returns.xlsx', index=False)

#     # ensure weights align
#     weights = pd.Series(weights_dict).reindex(returns.columns).fillna(0)

#     # covariance matrix of daily returns
#     # cov_matrix = returns.cov()

#     cov_np = np.cov(returns.T, bias=True)
#     cov_matrix = pd.DataFrame(cov_np, index=returns.columns, columns=returns.columns)
#     print(cov_matrix)

#     # # portfolio variance = w.T * Cov * w
#     # portfolio_var_daily = np.dot(weights.T, np.dot(cov_matrix, weights))

#     # # annualize volatility
#     # portfolio_std_annual = np.sqrt(portfolio_var_daily) * np.sqrt(252)
#     # print((portfolio_var_daily))
#     # print(weights)

    
#     print(np.dot(cov_matrix, weights))

#     print(len(np.dot(cov_matrix, weights)))

#     portfolio_std_annual = np.sqrt(np.dot(weights.T, np.dot(cov_matrix, weights)) * 252)


#     return portfolio_std_annual

# %%
# calculate_portfolio_std_from_df(portfolio_data, weights)
