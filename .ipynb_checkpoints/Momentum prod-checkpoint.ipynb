# %%
import numpy as np
import pandas as pd
from datetime import datetime, timedelta
from dateutil.relativedelta import relativedelta
import pytz
import yfinance as yf
import pyodbc
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
import time
import logging
import pandas as pd
from truedata import TD_hist

def fetch_truedata_history(
    ticker_list: list,
    duration: str = '1 Y',
    bar_size: str = 'EOD',
    sleep_time: float = 0.1
) -> tuple[pd.DataFrame, list]:
    """
    Fetches historical data from TrueData for a list of tickers.

    Parameters
    ----------
    username : str
        TrueData username.
    password : str
        TrueData password.
    ticker_list : list
        List of ticker symbols to fetch data for.
    duration : str, optional
        Duration of data (e.g., '1 Y', '25 Y', etc.). Default is '1 Y'.
    bar_size : str, optional
        Bar size for data ('EOD', 'WEEK', etc.). Default is 'EOD'.
    sleep_time : float, optional
        Delay between API calls to avoid throttling. Default is 0.2 seconds.

    Returns
    -------
    final_df : pd.DataFrame
        Combined DataFrame of all tickers' historical data.
    error_list : list
        List of tickers that failed to fetch.
    """
    logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
    username =  'td105'
    password = 'sharma@105'
    # Initialize connection
    td_hist = TD_hist(username, password)
    df_list = []
    error_list = []
    for ticker in ticker_list:
        try:
            df = td_hist.get_historic_data([ticker], duration=duration, bar_size=bar_size)

            df['Ticker'] = ticker
            df = df.rename(columns={
                'timestamp': 'Date',
                'high': 'High',
                'low': 'Low',
                'close': 'Close',
                'open': 'Open'
            })

            df_list.append(df)
            logging.info(f"Fetched data for {ticker} ({len(df)} rows).")
            time.sleep(sleep_time)

        except Exception as e:
            logging.error(f"Failed to fetch data for {ticker}: {e}")
            error_list.append(ticker)

    final_df = pd.concat(df_list, ignore_index=True) if df_list else pd.DataFrame()
    return final_df, error_list

# %%
import numpy as np
import pandas as pd
from dateutil.relativedelta import relativedelta

def process_portfolio(nav_df, ticker_data, initial_value=75, output_file=None):
    """
    Process portfolio allocation and returns final dataframe with portfolio performance.

    Parameters
    ----------
    nav_df : pd.DataFrame
        Dataframe with at least ['Year-Month', 'Ticker'] columns.
    get_individual_stock_data : function
        Function to fetch OHLC data. Must accept (tickers, start_date, end_date) and return DataFrame with ['Date','Ticker','Close'].
    initial_value : float
        Initial portfolio allocation value (default=75).
    debt_ticker : str
        Ticker used as debt/alternative asset (default 'MOGSEC.NS').
    output_file : str or None
        If provided, saves the final dataframe to Excel.

    Returns
    -------
    pd.DataFrame
        Final dataframe with portfolio values.
    """
    df_lis = []
    last_month_value = {}
    year_months = nav_df['Year-Month'].unique()
    for i, year_month in enumerate(year_months):
        print(f"\nProcessing: {year_month}")
        print("Last Month Value:", last_month_value)

        tickers = nav_df[nav_df['Year-Month'] == year_month]['Ticker'].unique()
        year_month_date = pd.to_datetime(f"{year_month}-01")


        prev_month_start = (year_month_date - relativedelta(months=2)).strftime('%Y-%m-%d')
        curr_month_start = year_month_date.strftime('%Y-%m-%d')
        curr_month_end = (year_month_date + pd.offsets.MonthEnd(0)).strftime('%Y-%m-%d')

        # --- Fetch stock data ---
        # stock_data = get_individual_stock_data(tickers, prev_month_start, curr_month_end)
        stock_data = (
            ticker_data[(ticker_data['Date'] >= prev_month_start)
            & (ticker_data['Date'] <= curr_month_end) 
            & (ticker_data['Ticker'].isin(tickers))])
        
        # % change
        stock_data['%change'] = stock_data.groupby('Ticker')['Close'].pct_change()
        # Filter current month
        stock_data_flt = stock_data[
            (stock_data['Date'] >= curr_month_start) & (stock_data['Date'] <= curr_month_end)
        ].copy()

        print(stock_data_flt)

        # --- Portfolio allocation logic ---
        if len(last_month_value) == 0:
            # First month → allocate initial portfolio equally
            allocation_per_stock = initial_value / len(tickers)
            stock_allocations = {t: allocation_per_stock for t in tickers}
        else:
            # Continue portfolio
            stock_allocations = {t: last_month_value[t] for t in tickers if t in last_month_value}

            # Pool value of dropped stocks
            dropped_stocks = [t for t in last_month_value if t not in tickers]
            dropped_value = sum(last_month_value[t] for t in dropped_stocks)

            # New stocks → share the dropped value equally
            new_stocks = [t for t in tickers if t not in last_month_value]
            if new_stocks:
                allocation_per_stock = dropped_value / len(new_stocks)
                for t in new_stocks:
                    stock_allocations[t] = allocation_per_stock

        # Apply allocations into dataframe
        for tkr, init_value in stock_allocations.items():
            tkr_idx = stock_data_flt[stock_data_flt['Ticker'] == tkr].index
            stock_data_flt.loc[tkr_idx, 'Buy_Hold_Value'] = init_value * (
                (1 + stock_data_flt.loc[tkr_idx, '%change'].fillna(0)).cumprod()
            )

        # --- Update last month values ---
        last_month_value = (
            stock_data_flt.groupby('Ticker')['Buy_Hold_Value'].last().to_dict()
        )

        # --- Track total portfolio value ---
        stock_data_flt['Total_Portfolio_Value'] = (
            stock_data_flt.groupby('Date')['Buy_Hold_Value'].transform('sum')
        )

        df_lis.append(stock_data_flt)

    
    final_df = pd.concat(df_lis).reset_index(drop=True)

    if output_file:
        final_df.to_excel(output_file, index=False)

    return final_df

# %%
import os
import pandas as pd

def prepare_and_process_portfolio(input_file, start_date, end_date, output_folder,
                                  process_portfolio,
                                  equity_allocation=75, gold_allocation=25):
    """
    Prepare portfolio dataframe with momentum stocks + GOLDBEES and process performance.

    Parameters
    ----------
    input_file : str
        Path to momentum Excel file (with End_Date, Ticker columns).
    start_date : str (YYYY-MM-DD)
        Start date for filtering.
    end_date : str (YYYY-MM-DD)
        End date for filtering.
    output_folder : str
        Folder to save output file.
    get_individual_stock_data : function
        Function to fetch stock NAV/price data.
    process_pocrtfolio : function
        Function to process equity portion of portfolio.
    process_gold : function
        Function to process gold portion of portfolio.
    equity_allocation : int, optional
        Initial allocation to equities (default=75000).
    gold_allocation : int, optional
        Initial allocation to gold (default=25000).

    Returns
    -------
    final_df : pd.DataFrame
        Combined portfolio dataframe.
    """

    # Load and clean
    nav_df = pd.read_excel(input_file).rename(columns={'End_Date': 'Date'})
    nav_df['Date'] = pd.to_datetime(nav_df['Date'])
    nav_df = (
        nav_df[(nav_df['Date'] >= start_date) & (nav_df['Date'] <= end_date)]
        .reset_index(drop=True)[['Date', 'Ticker']]
    )
    nav_df['Year-Month'] = nav_df['Date'].dt.to_period('M').astype(str)
    stocks = pd.read_excel(input_file)

    # Add GOLDBEES for each unique date
    goldbees_df = pd.DataFrame({
        'Date': nav_df['Date'].unique(),
        'Ticker': 'GOLDBEES'
    })
    goldbees_df['Year-Month'] = pd.to_datetime(goldbees_df['Date']).dt.to_period('M').astype(str)
    # print(goldbees_df)

    # Combine
    concat_df = (
        pd.concat([nav_df, goldbees_df], ignore_index=True)
          .sort_values(['Date', 'Ticker'])
          .reset_index(drop=True)
    )

    # symbol_list = stocks['Ticker'].unique()
    # ticker_data = fetch_truedata_history(
    #     ticker_list = symbol_list,
    #     duration = '5 Y',
    #     bar_size = 'EOD',
    #     sleep_time= 0.1
    # )[0]
    # final_df = process_portfolio(concat_df, ticker_data, equity_allocation)

    
    # Split
    ticker_df = concat_df.query("Ticker != 'GOLDBEES'")
    symbol_list = ticker_df['Ticker'].unique()
    ticker_data_other_stocks = fetch_truedata_history(
        ticker_list = symbol_list,
        duration = '10 Y',
        bar_size = 'EOD',
        sleep_time= 0.1
    )[0]

    
    gold_df = concat_df.query("Ticker == 'GOLDBEES'")
    symbol_list = gold_df['Ticker'].unique()
    ticker_data_gold = fetch_truedata_history(
        ticker_list = symbol_list,
        duration = '10 Y',
        bar_size = 'EOD',
        sleep_time= 0.1
    )[0]
    # print(gold_df)

    # Process
    final_df_other_stocks = process_portfolio(ticker_df, ticker_data_other_stocks, equity_allocation)
    # final_df_gold = process_gold(gold_df, get_individual_stock_data, gold_allocation)
    final_df_gold = process_portfolio(gold_df, ticker_data_gold, gold_allocation)


    # Merge results
    final_df = (
        pd.concat([final_df_other_stocks, final_df_gold], ignore_index=True)
          .sort_values(['Date', 'Ticker'])
          .reset_index(drop=True)
    )


    # --- ensure output folder exists ---
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # --- extract middle folder name from input path ---
    middle_folder = os.path.basename(os.path.dirname(input_file))
    # e.g. for path ".../nifty500_21April2025_results/master_momentum_summary.xlsx"
    # middle_folder = "nifty500_21April2025_results"

    # --- create output filename using middle folder ---
    output_file = os.path.join(output_folder, f"{middle_folder}_gold_buy&hold_returns.xlsx")

    # --- save output ---
    # final_df.to_excel(output_file, index=False)
    print(f"✅ Final output saved to: {output_file}")

    return final_df

# %%
#NSE500

# %%
final_df = prepare_and_process_portfolio(
    input_file="Stocks/Nifty_500_2025_Apr_20_stocks_results/master_momentum_summary.xlsx",
    start_date="2023-04-01",
    end_date="2026-01-01",
    output_folder="Trials",
    process_portfolio=process_portfolio
)

import plotly.express as px

# ✅ Group by Date and calculate total portfolio value
portfolio_summary = (
    final_df.groupby("Date", as_index=False)["Buy_Hold_Value"].sum()
)

# ✅ Plot with Plotly
fig = px.line(
    portfolio_summary,
    x="Date",
    y="Buy_Hold_Value",
    title="Buy_Hold_Value Over Time",
    labels={"Date": "Date", "Buy_Hold_Value": "Buy_Hold_Value"},
    markers=True
)

fig.update_traces(line=dict(width=2))
fig.update_layout(width=1000,   # 🔑 width
                  height=500)    # 🔑 height

fig.show()
# Out:
# (2026-01-09 15:21:54,726) WARNING :: Connected successfully to TrueData Historical Data Service...  (PID:16276 Thread:16724)
# 2026-01-09 15:21:54,726 - WARNING - Connected successfully to TrueData Historical Data Service...
# 2026-01-09 15:21:54,958 - INFO - Fetched data for ABCAPITAL (2073 rows).
# 2026-01-09 15:21:55,215 - INFO - Fetched data for ANANDRATHI (1013 rows).
# 2026-01-09 15:21:55,624 - INFO - Fetched data for BANKBARODA (2478 rows).
# 2026-01-09 15:21:56,022 - INFO - Fetched data for BANKINDIA (2478 rows).
# 2026-01-09 15:21:56,348 - INFO - Fetched data for BOSCHLTD (2478 rows).
# 2026-01-09 15:21:56,623 - INFO - Fetched data for CANBK (2478 rows).
# 2026-01-09 15:21:56,904 - INFO - Fetched data for CUMMINSIND (2478 rows).
# 2026-01-09 15:21:57,194 - INFO - Fetched data for FINCABLES (2478 rows).
# 2026-01-09 15:21:57,488 - INFO - Fetched data for GODFRYPHLP (2478 rows).
# 2026-01-09 15:21:57,749 - INFO - Fetched data for J&KBANK (2478 rows).
# 2026-01-09 15:21:58,014 - INFO - Fetched data for JINDALSAW (2478 rows).
# 2026-01-09 15:21:58,288 - INFO - Fetched data for JSL (2478 rows).
# 2026-01-09 15:21:58,505 - INFO - Fetched data for KAYNES (780 rows).
# 2026-01-09 15:21:58,822 - INFO - Fetched data for KIRLOSENG (2478 rows).
# 2026-01-09 15:21:59,105 - INFO - Fetched data for NCC (2478 rows).
# 2026-01-09 15:21:59,371 - INFO - Fetched data for PFC (2478 rows).
# 2026-01-09 15:21:59,653 - INFO - Fetched data for PNB (2478 rows).
# 2026-01-09 15:21:59,920 - INFO - Fetched data for RKFORGE (2478 rows).
# 2026-01-09 15:22:00,192 - INFO - Fetched data for SHREECEM (2478 rows).
# 2026-01-09 15:22:00,455 - INFO - Fetched data for TITAGARH (2478 rows).
# 2026-01-09 15:22:00,729 - INFO - Fetched data for ANANTRAJ (2478 rows).
# 2026-01-09 15:22:00,994 - INFO - Fetched data for CYIENT (2478 rows).
# 2026-01-09 15:22:01,272 - INFO - Fetched data for GLENMARK (2478 rows).
# 2026-01-09 15:22:01,531 - INFO - Fetched data for HINDPETRO (2478 rows).
# 2026-01-09 15:22:01,790 - INFO - Fetched data for IRCON (1806 rows).
# 2026-01-09 15:22:02,070 - INFO - Fetched data for JBMA (2478 rows).
# 2026-01-09 15:22:02,341 - INFO - Fetched data for JWL (2478 rows).
# 2026-01-09 15:22:02,588 - INFO - Fetched data for KPITTECH (1669 rows).
# 2026-01-09 15:22:02,890 - INFO - Fetched data for LINDEINDIA (2478 rows).
# 2026-01-09 15:22:03,163 - INFO - Fetched data for ABB (2478 rows).
# 2026-01-09 15:22:03,432 - INFO - Fetched data for ACE (2478 rows).
# 2026-01-09 15:22:03,715 - INFO - Fetched data for APARINDS (2478 rows).
# 2026-01-09 15:22:03,986 - INFO - Fetched data for CHENNPETRO (2478 rows).
# 2026-01-09 15:22:04,277 - INFO - Fetched data for CHOLAFIN (2478 rows).
# 2026-01-09 15:22:04,537 - INFO - Fetched data for GRAVITA (2478 rows).
# 2026-01-09 15:22:04,833 - INFO - Fetched data for ITC (2478 rows).
# 2026-01-09 15:22:05,090 - INFO - Fetched data for POLYCAB (1671 rows).
# 2026-01-09 15:22:05,324 - INFO - Fetched data for POWERINDIA (1437 rows).
# 2026-01-09 15:22:05,607 - INFO - Fetched data for RAMCOCEM (2478 rows).
# 2026-01-09 15:22:05,866 - INFO - Fetched data for VBL (2276 rows).
# 2026-01-09 15:22:06,153 - INFO - Fetched data for AUROPHARMA (2478 rows).
# 2026-01-09 15:22:06,424 - INFO - Fetched data for ELECON (2478 rows).
# 2026-01-09 15:22:06,705 - INFO - Fetched data for EXIDEIND (2478 rows).
# 2026-01-09 15:22:06,988 - INFO - Fetched data for LTF (2478 rows).
# 2026-01-09 15:22:07,268 - INFO - Fetched data for MAHSEAMLES (2478 rows).
# 2026-01-09 15:22:07,570 - INFO - Fetched data for RECLTD (2478 rows).
# 2026-01-09 15:22:07,849 - INFO - Fetched data for SIEMENS (2478 rows).
# 2026-01-09 15:22:08,123 - INFO - Fetched data for ZENSARTECH (2478 rows).
# 2026-01-09 15:22:08,333 - INFO - Fetched data for ZFCVINDIA (938 rows).
# 2026-01-09 15:22:08,624 - INFO - Fetched data for ADANIPORTS (2478 rows).
# 2026-01-09 15:22:08,904 - INFO - Fetched data for NEULANDLAB (2478 rows).
# 2026-01-09 15:22:09,181 - INFO - Fetched data for SARDAEN (2478 rows).
# 2026-01-09 15:22:09,466 - INFO - Fetched data for USHAMART (2478 rows).
# 2026-01-09 15:22:09,771 - INFO - Fetched data for ANGELONE (1308 rows).
# 2026-01-09 15:22:10,100 - INFO - Fetched data for BSE (2215 rows).
# 2026-01-09 15:22:10,379 - INFO - Fetched data for HBLENGINE (2478 rows).
# 2026-01-09 15:22:10,625 - INFO - Fetched data for KALYANKJIL (1188 rows).
# 2026-01-09 15:22:10,916 - INFO - Fetched data for LUPIN (2478 rows).
# 2026-01-09 15:22:11,210 - INFO - Fetched data for NATCOPHARM (2478 rows).
# 2026-01-09 15:22:11,479 - INFO - Fetched data for CHOLAHLDNG (2057 rows).
# 2026-01-09 15:22:11,707 - INFO - Fetched data for ETERNAL (1109 rows).
# 2026-01-09 15:22:11,996 - INFO - Fetched data for HUDCO (2145 rows).
# 2026-01-09 15:22:12,271 - INFO - Fetched data for RBLBANK (2321 rows).
# 2026-01-09 15:22:12,539 - INFO - Fetched data for SUZLON (2478 rows).
# 2026-01-09 15:22:12,824 - INFO - Fetched data for TARIL (2478 rows).
# 2026-01-09 15:22:13,091 - INFO - Fetched data for TATAINVEST (2478 rows).
# 2026-01-09 15:22:13,400 - INFO - Fetched data for BSOFT (2478 rows).
# 2026-01-09 15:22:13,723 - INFO - Fetched data for DIXON (2062 rows).
# 2026-01-09 15:22:14,001 - INFO - Fetched data for KIRLOSBROS (2478 rows).
# 2026-01-09 15:22:14,300 - INFO - Fetched data for MRPL (2478 rows).
# 2026-01-09 15:22:14,583 - INFO - Fetched data for SUPREMEIND (2478 rows).
# 2026-01-09 15:22:14,912 - INFO - Fetched data for BHEL (2478 rows).
# 2026-01-09 15:22:15,239 - INFO - Fetched data for GPIL (2478 rows).
# 2026-01-09 15:22:15,557 - INFO - Fetched data for MCX (2478 rows).
# 2026-01-09 15:22:15,863 - INFO - Fetched data for NLCINDIA (2478 rows).
# 2026-01-09 15:22:16,200 - INFO - Fetched data for PRESTIGE (2478 rows).
# 2026-01-09 15:22:16,405 - INFO - Fetched data for SIGNATURE (568 rows).
# 2026-01-09 15:22:16,700 - INFO - Fetched data for SJVN (2478 rows).
# 2026-01-09 15:22:16,980 - INFO - Fetched data for DBREALTY (2478 rows).
# 2026-01-09 15:22:17,235 - INFO - Fetched data for GVT&D (2478 rows).
# 2026-01-09 15:22:17,473 - INFO - Fetched data for IREDA (527 rows).
# 2026-01-09 15:22:17,785 - INFO - Fetched data for NBCC (2478 rows).
# 2026-01-09 15:22:18,024 - INFO - Fetched data for RAILTEL (1207 rows).
# 2026-01-09 15:22:18,344 - INFO - Fetched data for TRENT (2478 rows).
# 2026-01-09 15:22:18,621 - INFO - Fetched data for GMDCLTD (2478 rows).
# 2026-01-09 15:22:18,904 - INFO - Fetched data for BAJAJ-AUTO (2478 rows).
# 2026-01-09 15:22:19,171 - INFO - Fetched data for BPCL (2478 rows).
# 2026-01-09 15:22:19,453 - INFO - Fetched data for DLF (2478 rows).
# 2026-01-09 15:22:19,883 - INFO - Fetched data for INOXWIND (2478 rows).
# 2026-01-09 15:22:20,157 - INFO - Fetched data for IOC (2478 rows).
# 2026-01-09 15:22:20,450 - INFO - Fetched data for NIACL (2024 rows).
# 2026-01-09 15:22:20,729 - INFO - Fetched data for OIL (2478 rows).
# 2026-01-09 15:22:20,996 - INFO - Fetched data for BDL (1934 rows).
# 2026-01-09 15:22:21,282 - INFO - Fetched data for EIHOTEL (2478 rows).
# 2026-01-09 15:22:21,580 - INFO - Fetched data for ZYDUSLIFE (2478 rows).
# 2026-01-09 15:22:21,853 - INFO - Fetched data for BEL (2478 rows).
# 2026-01-09 15:22:22,113 - INFO - Fetched data for COCHINSHIP (2086 rows).
# 2026-01-09 15:22:22,383 - INFO - Fetched data for HAL (1931 rows).
# 2026-01-09 15:22:22,905 - INFO - Fetched data for MOTILALOFS (2478 rows).
# 2026-01-09 15:22:23,190 - INFO - Fetched data for NHPC (2478 rows).
# 2026-01-09 15:22:23,539 - INFO - Fetched data for SAIL (2478 rows).
# 2026-01-09 15:22:23,854 - INFO - Fetched data for VOLTAS (2478 rows).
# 2026-01-09 15:22:24,168 - INFO - Fetched data for NATIONALUM (2478 rows).
# 2026-01-09 15:22:24,480 - INFO - Fetched data for RVNL (1674 rows).
# 2026-01-09 15:22:24,778 - INFO - Fetched data for TECHNOE (1763 rows).
# 2026-01-09 15:22:25,071 - INFO - Fetched data for THERMAX (2478 rows).
# 2026-01-09 15:22:25,348 - INFO - Fetched data for VEDL (2478 rows).
# 2026-01-09 15:22:25,629 - INFO - Fetched data for BLUESTARCO (2478 rows).
# 2026-01-09 15:22:25,896 - INFO - Fetched data for GODREJPROP (2478 rows).
# 2026-01-09 15:22:26,189 - INFO - Fetched data for INDUSTOWER (2478 rows).
# 2026-01-09 15:22:26,465 - INFO - Fetched data for JSWENERGY (2478 rows).
# 2026-01-09 15:22:26,739 - INFO - Fetched data for MOTHERSON (2478 rows).
# 2026-01-09 15:22:27,011 - INFO - Fetched data for SCHNEIDER (2478 rows).
# 2026-01-09 15:22:27,284 - INFO - Fetched data for BASF (2478 rows).
# 2026-01-09 15:22:27,479 - INFO - Fetched data for DOMS (512 rows).
# 2026-01-09 15:22:27,746 - INFO - Fetched data for M&M (2478 rows).
# 2026-01-09 15:22:28,063 - INFO - Fetched data for AJANTPHARM (2478 rows).
# 2026-01-09 15:22:28,344 - INFO - Fetched data for COLPAL (2478 rows).
# 2026-01-09 15:22:28,646 - INFO - Fetched data for COROMANDEL (2478 rows).
# 2026-01-09 15:22:28,935 - INFO - Fetched data for DEEPAKFERT (2478 rows).
# 2026-01-09 15:22:29,219 - INFO - Fetched data for EMAMILTD (2478 rows).
# 2026-01-09 15:22:29,602 - INFO - Fetched data for ERIS (2117 rows).
# 2026-01-09 15:22:29,823 - INFO - Fetched data for LTFOODS (543 rows).
# 2026-01-09 15:22:30,099 - INFO - Fetched data for NAVA (2478 rows).
# 2026-01-09 15:22:30,374 - INFO - Fetched data for DIVISLAB (2478 rows).
# 2026-01-09 15:22:30,673 - INFO - Fetched data for HSCL (2478 rows).
# 2026-01-09 15:22:30,895 - INFO - Fetched data for PCBL (991 rows).
# 2026-01-09 15:22:31,183 - INFO - Fetched data for PGEL (2478 rows).
# 2026-01-09 15:22:31,398 - INFO - Fetched data for PPLPHARMA (801 rows).
# 2026-01-09 15:22:31,686 - INFO - Fetched data for COFORGE (2478 rows).
# 2026-01-09 15:22:31,934 - INFO - Fetched data for COHANCE (1451 rows).
# 2026-01-09 15:22:32,219 - INFO - Fetched data for JMFINANCIL (2478 rows).
# 2026-01-09 15:22:32,489 - INFO - Fetched data for PERSISTENT (2478 rows).
# 2026-01-09 15:22:32,788 - INFO - Fetched data for WOCKPHARMA (2478 rows).
# 2026-01-09 15:22:32,999 - INFO - Fetched data for KIMS (1127 rows).
# 2026-01-09 15:22:33,256 - INFO - Fetched data for OFSS (2478 rows).
# 2026-01-09 15:22:33,678 - INFO - Fetched data for PEL (2403 rows).
# 2026-01-09 15:22:33,963 - INFO - Fetched data for FORTIS (2478 rows).
# 2026-01-09 15:22:34,266 - INFO - Fetched data for IPCALAB (2478 rows).
# 2026-01-09 15:22:34,490 - INFO - Fetched data for KFINTECH (753 rows).
# 2026-01-09 15:22:34,738 - INFO - Fetched data for LAURUSLABS (2248 rows).
# 2026-01-09 15:22:34,976 - INFO - Fetched data for PAYTM (1030 rows).
# 2026-01-09 15:22:35,174 - INFO - Fetched data for SAGILITY (289 rows).
# 2026-01-09 15:22:35,496 - INFO - Fetched data for WELCORP (2478 rows).
# 2026-01-09 15:22:35,799 - INFO - Fetched data for ZENTEC (2478 rows).
# 2026-01-09 15:22:36,010 - INFO - Fetched data for AIIL (429 rows).
# 2026-01-09 15:22:36,270 - INFO - Fetched data for ASTERDM (1952 rows).
# 2026-01-09 15:22:36,469 - INFO - Fetched data for CONCORDBIO (596 rows).
# 2026-01-09 15:22:36,807 - INFO - Fetched data for ECLERX (2478 rows).
# 2026-01-09 15:22:37,086 - INFO - Fetched data for INDHOTEL (2478 rows).
# 2026-01-09 15:22:37,452 - INFO - Fetched data for JSWHL (2478 rows).
# 2026-01-09 15:22:37,686 - INFO - Fetched data for LLOYDSME (619 rows).
# 2026-01-09 15:22:38,027 - INFO - Fetched data for MUTHOOTFIN (2478 rows).
# 2026-01-09 15:22:38,759 - INFO - Fetched data for BAJFINANCE (2478 rows).
# 2026-01-09 15:22:39,015 - INFO - Fetched data for FLUOROCHEM (1551 rows).
# 2026-01-09 15:22:39,335 - INFO - Fetched data for HDFCBANK (2478 rows).
# 2026-01-09 15:22:39,623 - INFO - Fetched data for NAVINFLUOR (2478 rows).
# 2026-01-09 15:22:39,863 - INFO - Fetched data for SBICARD (1447 rows).
# 2026-01-09 15:22:40,274 - INFO - Fetched data for SRF (2478 rows).
# 2026-01-09 15:22:40,553 - INFO - Fetched data for AAVAS (1801 rows).
# 2026-01-09 15:22:40,838 - INFO - Fetched data for AMBER (1970 rows).
# 2026-01-09 15:22:41,125 - INFO - Fetched data for KOTAKBANK (2478 rows).
# 2026-01-09 15:22:41,385 - INFO - Fetched data for MAZDOCK (1304 rows).

# %%
final_df

# %%
old_df = final_df[~((final_df['Date']>'2025-11-30') & (final_df['Ticker']=='GOLDBEES'))]
old_df

# %%
np.sort(old_df['Ticker'].unique())

# %%
df = fetch_truedata_history(
    ticker_list = ['GOLDBEES', 'SILVERBEES', 'MOGSEC'],
    duration = '5 Y',
    bar_size = 'EOD',
    sleep_time= 0.1
)[0]
df = df[["Date","Ticker", "Open", "Close"]]
df['%change'] = df['Close'].pct_change()
df = df[df['Date'] >= '2025-12-01']
# df.to_excel('C:\\Users\\Admin\\Momentum\\Automating Momentum True Data\\Trials\\nse200_Nifty_200_2025_Aug_nse200_nse200_nse200_nse200_nse200_returns.xlsx', index=False)
df

# %%
ticker_weights = {'GOLDBEES':0.6, 'SILVERBEES':0.2, 'MOGSEC':0.2}
factor = 51.2140199725867

ticker_value = {ticker: weight * factor for ticker, weight in ticker_weights.items()}
ticker_value

# %%
df['BaseValue'] = df['Ticker'].map(ticker_value)
# Assign values
df['Value'] = df['Ticker'].map(ticker_value)
# Convert %change to numeric (if needed)
df['%change'] = pd.to_numeric(df['%change'])
# Sort (important for cumprod)
df = df.sort_values(['Ticker', 'Date'])

# Daily growth factor
df['ret_factor'] = 1 + df['%change']

# Cumulative factor per ticker
df['cum_factor'] = df.groupby('Ticker')['ret_factor'].cumprod()

# FINAL DAILY VALUE
df['Value_On_Date'] = df['BaseValue'] * df['cum_factor']

df = df[['Date', 'Ticker', 'Open', 'Close', 'Value_On_Date', '%change']].rename(columns={'Value_On_Date':'Buy_Hold_Value'})
df

# %%
# df

# %%
conc_df = pd.concat([old_df, df])
conc_df

# %%
import plotly.express as px

# ✅ Group by Date and calculate total portfolio value
portfolio_summary = (
    conc_df.groupby("Date", as_index=False)["Buy_Hold_Value"].sum()
)
# ✅ Plot with Plotly
fig = px.line(
    portfolio_summary,
    x="Date",
    y="Buy_Hold_Value",
    title="Buy_Hold_Value Over Time",
    labels={"Date": "Date", "Buy_Hold_Value": "Buy_Hold_Value"},
    markers=True
)

fig.update_traces(line=dict(width=2))
fig.update_layout(width=1000,   # 🔑 width
                  height=500)    # 🔑 height
fig.show()

# %%
# Momentum/Automating Momentum True Data/Trials/Nifty_500_2025_Apr_20_stocks_results_GoldSilverDebt_buy&hold_returns.xlsx

# %%
 conc_df.to_excel('C://Users//Admin//Momentum//Automating Momentum True Data//Trials//Nifty_500_2025_Apr_20_stocks_results_GoldSilverDebt_buy&hold_returns.xlsx', index=False)

# %%
conc_df

# %%
conc_df['Asset Type'] = np.where(
    conc_df['Ticker'] == 'GOLDBEES', 'Gold',
    np.where(
        conc_df['Ticker'] == 'SILVERBEES', 'Silver',
        np.where(
            conc_df['Ticker'] == 'MOGSEC', 'Debt',
            'Equities'
        )
    )
)

conc_df

# %%
# ----------------------xxxxxxxxxxxxxxxxxxxxx-----------------------------------

# %%
max_df = conc_df[conc_df['Date'] == conc_df['Date'].max()]
max_df

# %%
max_df = max_df[['Date', 'Ticker', 'Open', 'Close', '%change', 'Buy_Hold_Value', 'Asset Type']]
max_df

# %%
max_df['%change'] = max_df['Close'] / max_df['Open'] - 1
max_df

# %%
max_df['Weight'] = max_df['Buy_Hold_Value'] / sum(max_df['Buy_Hold_Value'])
max_df

# %%
max_df['Total'] = sum(max_df['Buy_Hold_Value'])
max_df

# %%
nse = fetch_truedata_history(
    ticker_list = ['Nifty 500'],
    duration = '5 Y',
    bar_size = 'EOD',
    sleep_time= 0.1
)[0]
nse = nse[["Date", "Close"]].rename(columns={'Close':'Buy_Hold_Value'})
nse['%change'] = nse['Buy_Hold_Value'].pct_change()
nse = nse[nse['Date'] >= '2023-04-01']
nse.to_excel('Trials\\nse500_Nifty_500_2025_Apr_nse500_nse500_nse500_nse500_nse500_returns.xlsx', index=False)
nse
