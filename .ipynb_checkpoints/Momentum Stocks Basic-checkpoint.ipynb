# %%
import time
import logging
import pandas as pd
from truedata import TD_hist

def fetch_truedata_history(
    username: str,
    password: str,
    ticker_list: list,
    duration: str = '1 Y',
    bar_size: str = 'EOD',
    sleep_time: float = 0.1
) -> tuple[pd.DataFrame, list]:
    """
    Fetches historical data from TrueData for a list of tickers.

    Parameters
    ----------
    username : str
        TrueData username.
    password : str
        TrueData password.
    ticker_list : list
        List of ticker symbols to fetch data for.
    duration : str, optional
        Duration of data (e.g., '1 Y', '25 Y', etc.). Default is '1 Y'.
    bar_size : str, optional
        Bar size for data ('EOD', 'WEEK', etc.). Default is 'EOD'.
    sleep_time : float, optional
        Delay between API calls to avoid throttling. Default is 0.2 seconds.

    Returns
    -------
    final_df : pd.DataFrame
        Combined DataFrame of all tickers' historical data.
    error_list : list
        List of tickers that failed to fetch.
    """
    logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

    # Initialize connection
    td_hist = TD_hist(username, password)

    df_list = []
    error_list = []

    for ticker in ticker_list:
        try:
            df = td_hist.get_historic_data([ticker], duration=duration, bar_size=bar_size)

            df['Ticker'] = ticker
            df = df.rename(columns={
                'timestamp': 'Date',
                'high': 'High',
                'low': 'Low',
                'close': 'Close',
                'open': 'Open'
            })

            df_list.append(df)
            logging.info(f"Fetched data for {ticker} ({len(df)} rows).")
            time.sleep(sleep_time)

        except Exception as e:
            logging.error(f"Failed to fetch data for {ticker}: {e}")
            error_list.append(ticker)

    final_df = pd.concat(df_list, ignore_index=True) if df_list else pd.DataFrame()
    return final_df, error_list

# %%
import numpy as np
import pandas as pd
from datetime import datetime
from dateutil.relativedelta import relativedelta
import yfinance as yf
from pathlib import Path

import os

def run_momentum_strategy(universe_file: str,
                          start_date: str,
                          end_date: str,
                          top_n: int,
                          output_root: str = "Momentum_Results") -> str:
    """
    Run rolling-window momentum strategy on given stock universe.

    Parameters
    ----------
    universe_file : str
        Path to universe file (.csv or .xlsx) with columns ["Symbol", "ISIN Code"].
    start_date : str
        Start date for backtest (YYYY-MM-DD).
    end_date : str
        End date for backtest (YYYY-MM-DD).
    top_n : int
        Number of top ranked stocks to select each window.
    output_root : str
        Root folder where results will be saved.

    Returns
    -------
    str
        Path to master summary file.
    """


    # ==== 1. Load Universe ====
    if universe_file.endswith(".csv"):
        stock_list = pd.read_csv(universe_file)[["Symbol", "ISIN Code"]]
    else:
        stock_list = pd.read_excel(universe_file)[["Symbol", "ISIN Code"]]
    # username = 'tdwsf695'
    # password = 'ocean@695'
    
    username = 'td105'
    password = 'sharma@105'
    # stock_list["Ticker"] = stock_list["Symbol"] + ".NS"
    stock_list["Ticker"] = stock_list["Symbol"] 
    symbol_list = stock_list["Symbol"].tolist()
    universe_name = Path(universe_file).stem
    output_dir = os.path.join(output_root, f"{universe_name}_{top_n}_stocks_results")
    os.makedirs(output_dir, exist_ok=True)

    # ==== 2. Download Data ====
    total_start = pd.to_datetime(start_date)
    total_end = pd.to_datetime(end_date)

    print(f"\n📥 Downloading price data for {len(symbol_list)} symbols...")
    # data = yf.download(symbol_list, start=total_start.strftime('%Y-%m-%d'),
    #                    end=total_end.strftime('%Y-%m-%d'), progress=True)
    # prices_all = data["Close"]
    # prices_all.index = pd.to_datetime(prices_all.index)
    # print("✅ Download complete.")

    data, errors = fetch_truedata_history(username, password, symbol_list, duration='10 Y', bar_size='EOD')
    data = data[['Date', 'Close', 'Ticker']]
    data.drop_duplicates(subset=['Date', 'Ticker'], inplace=True)
    print(data)
    print("Failed tickers:", errors)
    prices = data.pivot(index="Date", columns="Ticker", values="Close")  
    # optional: sort by date
    prices_all = prices.sort_index()



    # ==== 3. Create Rolling Windows ====
    windows = []
    current_start = total_start
    while True:
        current_end = current_start + relativedelta(months=6)
        if current_end > total_end:
            break
        window_prices = prices_all.loc[(prices_all.index >= current_start) & (prices_all.index < current_end)].copy()
        if not window_prices.empty:
            windows.append((current_start, current_end, window_prices))
        current_start += relativedelta(months=1)

    print(f"📊 Created {len(windows)} rolling windows.")

    # ==== 4. Process Each Window ====
    for start, end, prices in windows:
        file_suffix = f"{start.strftime('%Y%m%d')}_{end.strftime('%Y%m%d')}"
        print(f"\n🔍 Processing window: {start.date()} → {end.date()}")

        prices.dropna(axis=1, how='all', inplace=True)
        if prices.empty:
            print("⚠️ All price data missing. Skipping window.")
            continue

        # Monthly momentum
        monthclose = prices.groupby(prices.index.strftime('%Y-%m')).tail(1)
        monthstart = prices.groupby(prices.index.strftime('%Y-%m')).head(1)
        monthstart.index = monthclose.index
        monchange = (monthclose - monthstart) / monthstart
        MOM = (monchange + 1).product() - 1
        mom = MOM * 100

        # Daily returns
        daily_ret = prices.pct_change(fill_method=None)
        positivechange = (daily_ret[daily_ret > 0].count() / daily_ret.count()) * 100
        negativechange = (daily_ret[daily_ret < 0].count() / daily_ret.count()) * 100

        result = pd.concat([positivechange, negativechange, mom], axis=1, join='inner')
        result.columns = ["Positive", "Negative", "Momentum"]
        result = result.reset_index().rename(columns={'index': 'Ticker'})

        # Merge ISIN
        result = pd.merge(result, stock_list[["Ticker", "ISIN Code"]], on="Ticker", how="left")

        # Ranking
        df = result.copy()
        df["Rank_Mom"] = df["Momentum"].rank(method='min', ascending=False)
        print('rank df:', df)
        df['FIP'] = df.apply(lambda row: row['Negative'] - row['Positive'] if row['Momentum'] > 0 else np.nan, axis=1)
        # df['FIP'] = df.apply(lambda row: row['Negative'] - row['Positive'])

        df.dropna(inplace=True)
        df["FIP_rank"] = df["FIP"].rank(method="first", ascending=True)
        df["Combined_Rank"] = df["Rank_Mom"] + df["FIP_rank"]
        if end.strftime('%Y-%m-%d') == '2026-01-01':
            df = df[~(df['Ticker'].isin(['MARUTI', 'PTCIL']))]

        df = df.sort_values(by="Combined_Rank", ascending=True).head(top_n)
        df["Real_Rank"] = range(1, len(df) + 1)
        df["End_Date"] = end.strftime('%Y-%m-%d')


        # Save each window
        output_file = os.path.join(output_dir, f"momentum_{file_suffix}.xlsx")
        df.to_excel(output_file, index=False)
        print(f"✅ Saved results to: {output_file}")

    # ==== 5. Master File ====
    print("\n📂 Creating master summary file...")
    master_data = []
    for file in os.listdir(output_dir):
        if file.startswith("momentum_") and file.endswith(".xlsx"):
            df = pd.read_excel(os.path.join(output_dir, file))
            selected_df = df[["End_Date", "ISIN Code", "Ticker", 'Real_Rank']].copy()
            master_data.append(selected_df)

    if master_data:
        master_df = pd.concat(master_data, ignore_index=True)
        master_file_path = os.path.join(output_dir, "master_momentum_summary.xlsx")
        master_df.to_excel(master_file_path, index=False)
        print(f"✅ Master file saved to: {master_file_path}")
        return master_file_path
    else:
        print("⚠️ No window files found, master not created.")
        return None

# %%
# Momentum/Automating Momentum/Universe/Nifty_500_2025_Apr.csv
# "C:\Users\Admin\Momentum\Automating Momentum\Universe\Nifty_500_2025_Apr.csv"
master_file = run_momentum_strategy(
    universe_file=r"Universe/Nifty_500_2025_Apr.csv",
    start_date="2022-06-01",
    end_date="2026-01-01",
    top_n=20,
    output_root="Stocks"
)
print("Master summary located at:", master_file)
# Out:
# 📥 Downloading price data for 503 symbols...
# (2026-01-09 13:49:44,195) WARNING :: Connected successfully to TrueData Historical Data Service...  (PID:28928 Thread:28324)
# 2026-01-09 13:49:44,195 - WARNING - Connected successfully to TrueData Historical Data Service...
# 2026-01-09 13:49:44,492 - INFO - Fetched data for 360ONE (1568 rows).
# 2026-01-09 13:49:44,909 - INFO - Fetched data for 3MINDIA (2478 rows).
# 2026-01-09 13:49:45,282 - INFO - Fetched data for ABB (2478 rows).
# 2026-01-09 13:49:45,681 - INFO - Fetched data for ACC (2478 rows).
# 2026-01-09 13:49:45,936 - INFO - Fetched data for ACMESOLAR (288 rows).
# 2026-01-09 13:49:46,302 - INFO - Fetched data for AIAENG (2478 rows).
# 2026-01-09 13:49:46,687 - INFO - Fetched data for APLAPOLLO (2478 rows).
# 2026-01-09 13:49:47,036 - INFO - Fetched data for AUBANK (2110 rows).
# 2026-01-09 13:49:47,349 - INFO - Fetched data for AWL (974 rows).
# 2026-01-09 13:49:47,616 - INFO - Fetched data for AADHARHFC (413 rows).
# 2026-01-09 13:49:47,997 - INFO - Fetched data for AARTIIND (2478 rows).
# 2026-01-09 13:49:48,348 - INFO - Fetched data for AAVAS (1801 rows).
# 2026-01-09 13:49:48,715 - INFO - Fetched data for ABBOTINDIA (2478 rows).
# 2026-01-09 13:49:49,095 - INFO - Fetched data for ACE (2478 rows).
# 2026-01-09 13:49:49,358 - INFO - Fetched data for ADANIENSOL (592 rows).
# 2026-01-09 13:49:49,746 - INFO - Fetched data for ADANIENT (2478 rows).
# 2026-01-09 13:49:50,103 - INFO - Fetched data for ADANIGREEN (1876 rows).
# 2026-01-09 13:49:50,475 - INFO - Fetched data for ADANIPORTS (2478 rows).
# 2026-01-09 13:49:50,858 - INFO - Fetched data for ADANIPOWER (2478 rows).
# 2026-01-09 13:49:51,209 - INFO - Fetched data for ATGL (1781 rows).
# 2026-01-09 13:49:51,565 - INFO - Fetched data for ABCAPITAL (2073 rows).
# 2026-01-09 13:49:51,954 - INFO - Fetched data for ABFRL (2478 rows).
# 2026-01-09 13:49:52,318 - INFO - Fetched data for ABREL (2478 rows).
# 2026-01-09 13:49:52,648 - INFO - Fetched data for ABSLAMC (1056 rows).
# 2026-01-09 13:49:53,011 - INFO - Fetched data for AEGISLOG (2478 rows).
# 2026-01-09 13:49:53,274 - INFO - Fetched data for AFCONS (295 rows).
# 2026-01-09 13:49:53,613 - INFO - Fetched data for AFFLE (1594 rows).
# 2026-01-09 13:49:53,991 - INFO - Fetched data for AJANTPHARM (2478 rows).
# 2026-01-09 13:49:54,242 - INFO - Fetched data for AKUMS (357 rows).
# 2026-01-09 13:49:54,620 - INFO - Fetched data for APLLTD (2478 rows).
# 2026-01-09 13:49:54,922 - INFO - Fetched data for ALIVUS (1100 rows).
# 2026-01-09 13:49:55,299 - INFO - Fetched data for ALKEM (2478 rows).
# 2026-01-09 13:49:55,665 - INFO - Fetched data for ALKYLAMINE (2478 rows).
# 2026-01-09 13:49:56,006 - INFO - Fetched data for ALOKINDS (1463 rows).
# 2026-01-09 13:49:56,288 - INFO - Fetched data for ARE&M (549 rows).
# 2026-01-09 13:49:56,630 - INFO - Fetched data for AMBER (1970 rows).
# 2026-01-09 13:49:57,038 - INFO - Fetched data for AMBUJACEM (2478 rows).
# 2026-01-09 13:49:57,345 - INFO - Fetched data for ANANDRATHI (1013 rows).
# 2026-01-09 13:49:57,699 - INFO - Fetched data for ANANTRAJ (2478 rows).
# 2026-01-09 13:49:58,021 - INFO - Fetched data for ANGELONE (1308 rows).
# 2026-01-09 13:49:58,397 - INFO - Fetched data for APARINDS (2478 rows).
# 2026-01-09 13:49:58,789 - INFO - Fetched data for APOLLOHOSP (2478 rows).
# 2026-01-09 13:49:59,161 - INFO - Fetched data for APOLLOTYRE (2478 rows).
# 2026-01-09 13:49:59,475 - INFO - Fetched data for APTUS (1089 rows).
# 2026-01-09 13:49:59,865 - INFO - Fetched data for ASAHIINDIA (2478 rows).
# 2026-01-09 13:50:00,221 - INFO - Fetched data for ASHOKLEY (2478 rows).
# 2026-01-09 13:50:00,596 - INFO - Fetched data for ASIANPAINT (2478 rows).
# 2026-01-09 13:50:00,971 - INFO - Fetched data for ASTERDM (1952 rows).
# 2026-01-09 13:50:01,348 - INFO - Fetched data for ASTRAZEN (2478 rows).
# 2026-01-09 13:50:01,710 - INFO - Fetched data for ASTRAL (2478 rows).
# 2026-01-09 13:50:02,096 - INFO - Fetched data for ATUL (2478 rows).
# 2026-01-09 13:50:02,475 - INFO - Fetched data for AUROPHARMA (2478 rows).
# 2026-01-09 13:50:02,736 - INFO - Fetched data for AIIL (429 rows).
# 2026-01-09 13:50:03,105 - INFO - Fetched data for DMART (2185 rows).
# 2026-01-09 13:50:03,507 - INFO - Fetched data for AXISBANK (2478 rows).
# 2026-01-09 13:50:03,898 - INFO - Fetched data for BASF (2478 rows).
# 2026-01-09 13:50:04,286 - INFO - Fetched data for BEML (2478 rows).
# 2026-01-09 13:50:04,647 - INFO - Fetched data for BLS (2374 rows).
# 2026-01-09 13:50:05,031 - INFO - Fetched data for BSE (2215 rows).
# 2026-01-09 13:50:05,416 - INFO - Fetched data for BAJAJ-AUTO (2478 rows).
# 2026-01-09 13:50:05,776 - INFO - Fetched data for BAJFINANCE (2478 rows).
# 2026-01-09 13:50:06,151 - INFO - Fetched data for BAJAJFINSV (2478 rows).
# 2026-01-09 13:50:06,519 - INFO - Fetched data for BAJAJHLDNG (2478 rows).
# 2026-01-09 13:50:06,783 - INFO - Fetched data for BAJAJHFL (329 rows).
# 2026-01-09 13:50:07,158 - INFO - Fetched data for BALKRISIND (2478 rows).
# 2026-01-09 13:50:07,547 - INFO - Fetched data for BALRAMCHIN (2478 rows).
# 2026-01-09 13:50:07,899 - INFO - Fetched data for BANDHANBNK (1932 rows).
# 2026-01-09 13:50:08,268 - INFO - Fetched data for BANKBARODA (2478 rows).
# 2026-01-09 13:50:08,628 - INFO - Fetched data for BANKINDIA (2478 rows).
# 2026-01-09 13:50:09,010 - INFO - Fetched data for MAHABANK (2478 rows).
# 2026-01-09 13:50:09,371 - INFO - Fetched data for BATAINDIA (2478 rows).
# 2026-01-09 13:50:09,736 - INFO - Fetched data for BAYERCROP (2478 rows).
# 2026-01-09 13:50:10,119 - INFO - Fetched data for BERGEPAINT (2478 rows).
# 2026-01-09 13:50:10,512 - INFO - Fetched data for BDL (1934 rows).
# 2026-01-09 13:50:10,877 - INFO - Fetched data for BEL (2478 rows).
# 2026-01-09 13:50:11,252 - INFO - Fetched data for BHARATFORG (2478 rows).
# 2026-01-09 13:50:11,628 - INFO - Fetched data for BHEL (2478 rows).
# 2026-01-09 13:50:11,997 - INFO - Fetched data for BPCL (2478 rows).
# 2026-01-09 13:50:12,368 - INFO - Fetched data for BHARTIARTL (2478 rows).
# 2026-01-09 13:50:12,633 - INFO - Fetched data for BHARTIHEXA (435 rows).
# 2026-01-09 13:50:12,938 - INFO - Fetched data for BIKAJI (784 rows).
# 2026-01-09 13:50:13,316 - INFO - Fetched data for BIOCON (2478 rows).
# 2026-01-09 13:50:13,678 - INFO - Fetched data for BSOFT (2478 rows).
# 2026-01-09 13:50:14,074 - INFO - Fetched data for BLUEDART (2478 rows).
# 2026-01-09 13:50:14,446 - INFO - Fetched data for BLUESTARCO (2478 rows).
# 2026-01-09 13:50:14,818 - INFO - Fetched data for BBTC (2478 rows).
# 2026-01-09 13:50:15,192 - INFO - Fetched data for BOSCHLTD (2478 rows).
# 2026-01-09 13:50:15,466 - INFO - Fetched data for FIRSTCRY (352 rows).
# 2026-01-09 13:50:15,834 - INFO - Fetched data for BRIGADE (2478 rows).
# 2026-01-09 13:50:16,233 - INFO - Fetched data for BRITANNIA (2478 rows).
# 2026-01-09 13:50:16,539 - INFO - Fetched data for MAPMYINDIA (1008 rows).
# 2026-01-09 13:50:16,926 - INFO - Fetched data for CCL (2478 rows).
# 2026-01-09 13:50:17,301 - INFO - Fetched data for CESC (2478 rows).
# 2026-01-09 13:50:17,662 - INFO - Fetched data for CGPOWER (2478 rows).
# 2026-01-09 13:50:18,045 - INFO - Fetched data for CRISIL (2478 rows).
# 2026-01-09 13:50:18,354 - INFO - Fetched data for CAMPUS (915 rows).
# 2026-01-09 13:50:18,727 - INFO - Fetched data for CANFINHOME (2478 rows).
# 2026-01-09 13:50:19,080 - INFO - Fetched data for CANBK (2478 rows).
# 2026-01-09 13:50:19,458 - INFO - Fetched data for CAPLIPOINT (2478 rows).
# 2026-01-09 13:50:19,826 - INFO - Fetched data for CGCL (2478 rows).
# 2026-01-09 13:50:20,193 - INFO - Fetched data for CARBORUNIV (2478 rows).
# 2026-01-09 13:50:20,547 - INFO - Fetched data for CASTROLIND (2478 rows).
# 2026-01-09 13:50:20,922 - INFO - Fetched data for CEATLTD (2478 rows).
# 2026-01-09 13:50:21,297 - INFO - Fetched data for CENTRALBK (2478 rows).
# 2026-01-09 13:50:21,645 - INFO - Fetched data for CDSL (2116 rows).
# 2026-01-09 13:50:22,031 - INFO - Fetched data for CENTURYPLY (2478 rows).
# 2026-01-09 13:50:22,418 - INFO - Fetched data for CERA (2478 rows).
# 2026-01-09 13:50:22,749 - INFO - Fetched data for CHALET (1717 rows).
# 2026-01-09 13:50:23,170 - INFO - Fetched data for CHAMBLFERT (2478 rows).
# 2026-01-09 13:50:23,549 - INFO - Fetched data for CHENNPETRO (2478 rows).
# 2026-01-09 13:50:23,901 - INFO - Fetched data for CHOLAHLDNG (2057 rows).
# 2026-01-09 13:50:24,272 - INFO - Fetched data for CHOLAFIN (2478 rows).
# 2026-01-09 13:50:24,662 - INFO - Fetched data for CIPLA (2478 rows).
# 2026-01-09 13:50:25,031 - INFO - Fetched data for CUB (2478 rows).
# 2026-01-09 13:50:25,339 - INFO - Fetched data for CLEAN (1112 rows).
# 2026-01-09 13:50:25,714 - INFO - Fetched data for COALINDIA (2478 rows).
# 2026-01-09 13:50:26,076 - INFO - Fetched data for COCHINSHIP (2086 rows).
# 2026-01-09 13:50:26,456 - INFO - Fetched data for COFORGE (2478 rows).
# 2026-01-09 13:50:26,773 - INFO - Fetched data for COHANCE (1451 rows).
# 2026-01-09 13:50:27,148 - INFO - Fetched data for COLPAL (2478 rows).
# 2026-01-09 13:50:27,488 - INFO - Fetched data for CAMS (1309 rows).
# 2026-01-09 13:50:27,759 - INFO - Fetched data for CONCORDBIO (596 rows).
# 2026-01-09 13:50:28,144 - INFO - Fetched data for CONCOR (2478 rows).
# 2026-01-09 13:50:28,777 - INFO - Fetched data for COROMANDEL (2478 rows).
# 2026-01-09 13:50:29,098 - INFO - Fetched data for CRAFTSMAN (1189 rows).
# 2026-01-09 13:50:29,461 - INFO - Fetched data for CREDITACC (1830 rows).
# 2026-01-09 13:50:29,831 - INFO - Fetched data for CROMPTON (2397 rows).
# 2026-01-09 13:50:30,194 - INFO - Fetched data for CUMMINSIND (2478 rows).
# 2026-01-09 13:50:30,547 - INFO - Fetched data for CYIENT (2478 rows).
# 2026-01-09 13:50:30,933 - INFO - Fetched data for DCMSHRIRAM (2478 rows).
# 2026-01-09 13:50:31,312 - INFO - Fetched data for DLF (2478 rows).
# 2026-01-09 13:50:31,583 - INFO - Fetched data for DOMS (512 rows).
# 2026-01-09 13:50:31,984 - INFO - Fetched data for DABUR (2478 rows).
# 2026-01-09 13:50:32,338 - INFO - Fetched data for DALBHARAT (1729 rows).
# 2026-01-09 13:50:32,646 - INFO - Fetched data for DATAPATTNS (1005 rows).
# 2026-01-09 13:50:33,018 - INFO - Fetched data for DEEPAKFERT (2478 rows).
# 2026-01-09 13:50:33,403 - INFO - Fetched data for DEEPAKNTR (2478 rows).
# 2026-01-09 13:50:33,698 - INFO - Fetched data for DELHIVERY (904 rows).
# 2026-01-09 13:50:34,033 - INFO - Fetched data for DEVYANI (1094 rows).
# 2026-01-09 13:50:34,418 - INFO - Fetched data for DIVISLAB (2478 rows).
# 2026-01-09 13:50:34,779 - INFO - Fetched data for DIXON (2062 rows).
# 2026-01-09 13:50:35,153 - INFO - Fetched data for LALPATHLAB (2478 rows).
# 2026-01-09 13:50:35,547 - INFO - Fetched data for DRREDDY (2478 rows).
# (2026-01-09 13:50:35,785) ERROR :: <class 'AttributeError'> -> 'DataFrame' object has no attribute 'timestamp' (PID:28928 Thread:28324)
# 2026-01-09 13:50:35,785 - ERROR - <class 'AttributeError'> -> 'DataFrame' object has no attribute 'timestamp'
# 2026-01-09 13:50:35,802 - ERROR - Failed to fetch data for DUMMYABFRL: 'NoneType' object does not support item assignment
# (2026-01-09 13:50:35,947) ERROR :: <class 'AttributeError'> -> 'DataFrame' object has no attribute 'timestamp' (PID:28928 Thread:28324)
# 2026-01-09 13:50:35,947 - ERROR - <class 'AttributeError'> -> 'DataFrame' object has no attribute 'timestamp'
# 2026-01-09 13:50:35,947 - ERROR - Failed to fetch data for DUMMYSIEMS: 'NoneType' object does not support item assignment
# (2026-01-09 13:50:36,105) ERROR :: <class 'AttributeError'> -> 'DataFrame' object has no attribute 'timestamp' (PID:28928 Thread:28324)
# 2026-01-09 13:50:36,105 - ERROR - <class 'AttributeError'> -> 'DataFrame' object has no attribute 'timestamp'
# 2026-01-09 13:50:36,105 - ERROR - Failed to fetch data for DUMMYRAYMN: 'NoneType' object does not support item assignment
# 2026-01-09 13:50:36,413 - INFO - Fetched data for EIDPARRY (2478 rows).
# 2026-01-09 13:50:36,779 - INFO - Fetched data for EIHOTEL (2478 rows).
# 2026-01-09 13:50:37,150 - INFO - Fetched data for EICHERMOT (2478 rows).
# 2026-01-09 13:50:37,521 - INFO - Fetched data for ELECON (2478 rows).
# 2026-01-09 13:50:37,885 - INFO - Fetched data for ELGIEQUIP (2478 rows).
# 2026-01-09 13:50:38,255 - INFO - Fetched data for EMAMILTD (2478 rows).
# 2026-01-09 13:50:38,519 - INFO - Fetched data for EMCURE (375 rows).
# 2026-01-09 13:50:38,910 - INFO - Fetched data for ENDURANCE (2290 rows).
# 2026-01-09 13:50:39,267 - INFO - Fetched data for ENGINERSIN (2478 rows).
# 2026-01-09 13:50:39,635 - INFO - Fetched data for ERIS (2117 rows).
# 2026-01-09 13:50:40,017 - INFO - Fetched data for ESCORTS (2478 rows).
# 2026-01-09 13:50:40,324 - INFO - Fetched data for ETERNAL (1109 rows).
# 2026-01-09 13:50:40,702 - INFO - Fetched data for EXIDEIND (2478 rows).
# 2026-01-09 13:50:41,025 - INFO - Fetched data for NYKAA (1036 rows).
# 2026-01-09 13:50:41,399 - INFO - Fetched data for FEDERALBNK (2478 rows).
# 2026-01-09 13:50:41,765 - INFO - Fetched data for FACT (2478 rows).
# 2026-01-09 13:50:42,132 - INFO - Fetched data for FINCABLES (2478 rows).
# 2026-01-09 13:50:42,489 - INFO - Fetched data for FINPIPE (2478 rows).
# 2026-01-09 13:50:42,869 - INFO - Fetched data for FSL (2478 rows).
# 2026-01-09 13:50:43,171 - INFO - Fetched data for FIVESTAR (781 rows).
# 2026-01-09 13:50:43,553 - INFO - Fetched data for FORTIS (2478 rows).
# 2026-01-09 13:50:43,938 - INFO - Fetched data for GAIL (2478 rows).
# 2026-01-09 13:50:44,328 - INFO - Fetched data for GVT&D (2478 rows).
# 2026-01-09 13:50:44,697 - INFO - Fetched data for GMRAIRPORT (2478 rows).
# 2026-01-09 13:50:45,050 - INFO - Fetched data for GRSE (1799 rows).
# 2026-01-09 13:50:45,418 - INFO - Fetched data for GICRE (2037 rows).
# 2026-01-09 13:50:45,794 - INFO - Fetched data for GILLETTE (2478 rows).
# 2026-01-09 13:50:46,115 - INFO - Fetched data for GLAND (1274 rows).
# 2026-01-09 13:50:46,483 - INFO - Fetched data for GLAXO (2478 rows).
# 2026-01-09 13:50:46,852 - INFO - Fetched data for GLENMARK (2478 rows).
# 2026-01-09 13:50:47,172 - INFO - Fetched data for MEDANTA (784 rows).
# 2026-01-09 13:50:47,439 - INFO - Fetched data for GODIGIT (408 rows).
# 2026-01-09 13:50:47,831 - INFO - Fetched data for GPIL (2478 rows).
# 2026-01-09 13:50:48,207 - INFO - Fetched data for GODFRYPHLP (2478 rows).
# 2026-01-09 13:50:48,575 - INFO - Fetched data for GODREJAGRO (2043 rows).
# 2026-01-09 13:50:48,969 - INFO - Fetched data for GODREJCP (2478 rows).
# 2026-01-09 13:50:49,360 - INFO - Fetched data for GODREJIND (2478 rows).
# 2026-01-09 13:50:49,733 - INFO - Fetched data for GODREJPROP (2478 rows).
# 2026-01-09 13:50:50,102 - INFO - Fetched data for GRANULES (2478 rows).
# 2026-01-09 13:50:50,482 - INFO - Fetched data for GRAPHITE (2478 rows).
# 2026-01-09 13:50:50,883 - INFO - Fetched data for GRASIM (2478 rows).
# 2026-01-09 13:50:51,251 - INFO - Fetched data for GRAVITA (2478 rows).
# 2026-01-09 13:50:51,627 - INFO - Fetched data for GESHIP (2478 rows).
# 2026-01-09 13:50:52,000 - INFO - Fetched data for FLUOROCHEM (1551 rows).
# 2026-01-09 13:50:52,377 - INFO - Fetched data for GUJGASLTD (2478 rows).
# 2026-01-09 13:50:52,760 - INFO - Fetched data for GMDCLTD (2478 rows).
# 2026-01-09 13:50:53,139 - INFO - Fetched data for GNFC (2478 rows).
# 2026-01-09 13:50:53,512 - INFO - Fetched data for GPPL (2478 rows).
# 2026-01-09 13:50:53,884 - INFO - Fetched data for GSPL (2478 rows).
# 2026-01-09 13:50:54,330 - INFO - Fetched data for HEG (2478 rows).
# 2026-01-09 13:50:54,725 - INFO - Fetched data for HBLENGINE (2478 rows).
# 2026-01-09 13:50:55,118 - INFO - Fetched data for HCLTECH (2478 rows).
# 2026-01-09 13:50:55,479 - INFO - Fetched data for HDFCAMC (1841 rows).
# 2026-01-09 13:50:55,856 - INFO - Fetched data for HDFCBANK (2478 rows).
# 2026-01-09 13:50:56,210 - INFO - Fetched data for HDFCLIFE (2020 rows).
# 2026-01-09 13:50:56,595 - INFO - Fetched data for HFCL (2478 rows).
# 2026-01-09 13:50:56,917 - INFO - Fetched data for HAPPSTMNDS (1319 rows).
# 2026-01-09 13:50:57,314 - INFO - Fetched data for HAVELLS (2478 rows).
# 2026-01-09 13:50:57,695 - INFO - Fetched data for HEROMOTOCO (2478 rows).
# 2026-01-09 13:50:58,073 - INFO - Fetched data for HSCL (2478 rows).
# 2026-01-09 13:50:58,474 - INFO - Fetched data for HINDALCO (2478 rows).
# 2026-01-09 13:50:58,835 - INFO - Fetched data for HAL (1931 rows).
# 2026-01-09 13:50:59,213 - INFO - Fetched data for HINDCOPPER (2478 rows).
# 2026-01-09 13:50:59,582 - INFO - Fetched data for HINDPETRO (2478 rows).
# 2026-01-09 13:50:59,992 - INFO - Fetched data for HINDUNILVR (2478 rows).
# 2026-01-09 13:51:00,378 - INFO - Fetched data for HINDZINC (2478 rows).
# 2026-01-09 13:51:00,729 - INFO - Fetched data for POWERINDIA (1437 rows).
# 2026-01-09 13:51:01,064 - INFO - Fetched data for HOMEFIRST (1224 rows).
# 2026-01-09 13:51:01,345 - INFO - Fetched data for HONASA (542 rows).
# 2026-01-09 13:51:01,724 - INFO - Fetched data for HONAUT (2478 rows).
# 2026-01-09 13:51:02,092 - INFO - Fetched data for HUDCO (2145 rows).
# 2026-01-09 13:51:02,391 - INFO - Fetched data for HYUNDAI (304 rows).
# 2026-01-09 13:51:02,785 - INFO - Fetched data for ICICIBANK (2478 rows).
# 2026-01-09 13:51:03,146 - INFO - Fetched data for ICICIGI (2055 rows).
# 2026-01-09 13:51:03,551 - INFO - Fetched data for ICICIPRULI (2302 rows).
# 2026-01-09 13:51:03,932 - INFO - Fetched data for IDBI (2478 rows).
# 2026-01-09 13:51:04,323 - INFO - Fetched data for IDFCFIRSTB (2477 rows).
# 2026-01-09 13:51:04,695 - INFO - Fetched data for IFCI (2478 rows).
# 2026-01-09 13:51:05,333 - INFO - Fetched data for IIFL (2478 rows).
# 2026-01-09 13:51:05,611 - INFO - Fetched data for INOXINDIA (511 rows).
# 2026-01-09 13:51:05,995 - INFO - Fetched data for IRB (2478 rows).
# 2026-01-09 13:51:06,316 - INFO - Fetched data for IRCON (1806 rows).
# 2026-01-09 13:51:06,692 - INFO - Fetched data for ITC (2478 rows).
# 2026-01-09 13:51:07,083 - INFO - Fetched data for ITI (2478 rows).
# 2026-01-09 13:51:07,354 - INFO - Fetched data for INDGN (416 rows).
# 2026-01-09 13:51:07,735 - INFO - Fetched data for INDIACEM (2478 rows).
# 2026-01-09 13:51:08,100 - INFO - Fetched data for INDIAMART (1619 rows).
# 2026-01-09 13:51:08,473 - INFO - Fetched data for INDIANB (2478 rows).
# 2026-01-09 13:51:08,851 - INFO - Fetched data for IEX (2039 rows).
# 2026-01-09 13:51:09,235 - INFO - Fetched data for INDHOTEL (2478 rows).
# 2026-01-09 13:51:09,601 - INFO - Fetched data for IOC (2478 rows).
# 2026-01-09 13:51:09,984 - INFO - Fetched data for IOB (2478 rows).
# 2026-01-09 13:51:10,303 - INFO - Fetched data for IRCTC (1553 rows).
# 2026-01-09 13:51:10,617 - INFO - Fetched data for IRFC (1227 rows).
# 2026-01-09 13:51:10,896 - INFO - Fetched data for IREDA (527 rows).
# 2026-01-09 13:51:11,268 - INFO - Fetched data for IGL (2478 rows).
# 2026-01-09 13:51:11,675 - INFO - Fetched data for INDUSTOWER (2478 rows).
# 2026-01-09 13:51:12,138 - INFO - Fetched data for INDUSINDBK (2478 rows).
# 2026-01-09 13:51:12,521 - INFO - Fetched data for NAUKRI (2478 rows).
# 2026-01-09 13:51:12,909 - INFO - Fetched data for INFY (2478 rows).
# 2026-01-09 13:51:13,269 - INFO - Fetched data for INOXWIND (2478 rows).
# 2026-01-09 13:51:13,662 - INFO - Fetched data for INTELLECT (2478 rows).
# 2026-01-09 13:51:14,049 - INFO - Fetched data for INDIGO (2478 rows).
# 2026-01-09 13:51:14,325 - INFO - Fetched data for IGIL (263 rows).
# 2026-01-09 13:51:14,579 - INFO - Fetched data for IKS (264 rows).
# 2026-01-09 13:51:15,014 - INFO - Fetched data for IPCALAB (2478 rows).
# 2026-01-09 13:51:15,480 - INFO - Fetched data for JBCHEPHARM (2478 rows).
# 2026-01-09 13:51:15,854 - INFO - Fetched data for JKCEMENT (2478 rows).
# 2026-01-09 13:51:16,237 - INFO - Fetched data for JBMA (2478 rows).
# 2026-01-09 13:51:16,643 - INFO - Fetched data for JKTYRE (2478 rows).
# 2026-01-09 13:51:17,040 - INFO - Fetched data for JMFINANCIL (2478 rows).
# 2026-01-09 13:51:17,475 - INFO - Fetched data for JSWENERGY (2478 rows).
# 2026-01-09 13:51:17,941 - INFO - Fetched data for JSWHL (2478 rows).
# 2026-01-09 13:51:18,330 - INFO - Fetched data for JSWINFRA (566 rows).
# 2026-01-09 13:51:18,773 - INFO - Fetched data for JSWSTEEL (2478 rows).
# 2026-01-09 13:51:19,142 - INFO - Fetched data for JPPOWER (2478 rows).
# 2026-01-09 13:51:19,541 - INFO - Fetched data for J&KBANK (2478 rows).
# 2026-01-09 13:51:19,926 - INFO - Fetched data for JINDALSAW (2478 rows).
# 2026-01-09 13:51:20,325 - INFO - Fetched data for JSL (2478 rows).
# 2026-01-09 13:51:20,712 - INFO - Fetched data for JINDALSTEL (2478 rows).
# 2026-01-09 13:51:21,059 - INFO - Fetched data for JIOFIN (595 rows).
# 2026-01-09 13:51:21,456 - INFO - Fetched data for JUBLFOOD (2478 rows).
# 2026-01-09 13:51:21,790 - INFO - Fetched data for JUBLINGREA (1193 rows).
# 2026-01-09 13:51:22,101 - INFO - Fetched data for JUBLPHARMA (1218 rows).
# 2026-01-09 13:51:22,523 - INFO - Fetched data for JWL (2478 rows).
# 2026-01-09 13:51:22,891 - INFO - Fetched data for JUSTDIAL (2478 rows).
# 2026-01-09 13:51:23,274 - INFO - Fetched data for JYOTHYLAB (2478 rows).
# 2026-01-09 13:51:23,558 - INFO - Fetched data for JYOTICNC (494 rows).
# 2026-01-09 13:51:23,941 - INFO - Fetched data for KPRMILL (2478 rows).
# 2026-01-09 13:51:24,303 - INFO - Fetched data for KEI (2478 rows).
# 2026-01-09 13:51:24,680 - INFO - Fetched data for KNRCON (2478 rows).
# 2026-01-09 13:51:25,109 - INFO - Fetched data for KPITTECH (1669 rows).
# 2026-01-09 13:51:25,565 - INFO - Fetched data for KAJARIACER (2478 rows).
# 2026-01-09 13:51:25,934 - INFO - Fetched data for KPIL (2478 rows).
# 2026-01-09 13:51:26,232 - INFO - Fetched data for KALYANKJIL (1188 rows).
# 2026-01-09 13:51:26,631 - INFO - Fetched data for KANSAINER (2478 rows).
# 2026-01-09 13:51:27,002 - INFO - Fetched data for KARURVYSYA (2478 rows).
# 2026-01-09 13:51:27,309 - INFO - Fetched data for KAYNES (780 rows).
# 2026-01-09 13:51:27,696 - INFO - Fetched data for KEC (2478 rows).
# 2026-01-09 13:51:28,017 - INFO - Fetched data for KFINTECH (753 rows).
# 2026-01-09 13:51:28,404 - INFO - Fetched data for KIRLOSBROS (2478 rows).
# 2026-01-09 13:51:28,807 - INFO - Fetched data for KIRLOSENG (2478 rows).
# 2026-01-09 13:51:29,194 - INFO - Fetched data for KOTAKBANK (2478 rows).
# 2026-01-09 13:51:29,516 - INFO - Fetched data for KIMS (1127 rows).
# 2026-01-09 13:51:29,896 - INFO - Fetched data for LTF (2478 rows).
# 2026-01-09 13:51:30,253 - INFO - Fetched data for LTTS (2306 rows).
# 2026-01-09 13:51:30,630 - INFO - Fetched data for LICHSGFIN (2478 rows).
# 2026-01-09 13:51:30,888 - INFO - Fetched data for LTFOODS (543 rows).
# 2026-01-09 13:51:31,267 - INFO - Fetched data for LTIM (2349 rows).
# 2026-01-09 13:51:31,643 - INFO - Fetched data for LT (2478 rows).
# 2026-01-09 13:51:31,965 - INFO - Fetched data for LATENTVIEW (1028 rows).
# 2026-01-09 13:51:32,317 - INFO - Fetched data for LAURUSLABS (2248 rows).
# 2026-01-09 13:51:32,692 - INFO - Fetched data for LEMONTREE (1925 rows).
# 2026-01-09 13:51:33,002 - INFO - Fetched data for LICI (909 rows).
# 2026-01-09 13:51:33,398 - INFO - Fetched data for LINDEINDIA (2478 rows).
# 2026-01-09 13:51:33,773 - INFO - Fetched data for LLOYDSME (619 rows).
# 2026-01-09 13:51:34,184 - INFO - Fetched data for LUPIN (2478 rows).
# 2026-01-09 13:51:34,551 - INFO - Fetched data for MMTC (2478 rows).
# 2026-01-09 13:51:34,966 - INFO - Fetched data for MRF (2478 rows).
# 2026-01-09 13:51:35,286 - INFO - Fetched data for LODHA (1175 rows).
# 2026-01-09 13:51:35,710 - INFO - Fetched data for MGL (2362 rows).
# 2026-01-09 13:51:36,126 - INFO - Fetched data for MAHSEAMLES (2478 rows).
# 2026-01-09 13:51:36,500 - INFO - Fetched data for M&MFIN (2478 rows).
# 2026-01-09 13:51:36,872 - INFO - Fetched data for M&M (2478 rows).
# 2026-01-09 13:51:37,241 - INFO - Fetched data for MANAPPURAM (2478 rows).
# 2026-01-09 13:51:37,617 - INFO - Fetched data for MRPL (2478 rows).
# 2026-01-09 13:51:37,918 - INFO - Fetched data for MANKIND (667 rows).
# 2026-01-09 13:51:38,315 - INFO - Fetched data for MARICO (2478 rows).
# 2026-01-09 13:51:38,693 - INFO - Fetched data for MARUTI (2478 rows).
# 2026-01-09 13:51:39,053 - INFO - Fetched data for MASTEK (2478 rows).
# 2026-01-09 13:51:39,434 - INFO - Fetched data for MFSL (2478 rows).
# 2026-01-09 13:51:39,803 - INFO - Fetched data for MAXHEALTH (1338 rows).
# 2026-01-09 13:51:40,159 - INFO - Fetched data for MAZDOCK (1304 rows).
# 2026-01-09 13:51:40,485 - INFO - Fetched data for METROPOLIS (1672 rows).
# 2026-01-09 13:51:40,874 - INFO - Fetched data for MINDACORP (2478 rows).
# 2026-01-09 13:51:41,171 - INFO - Fetched data for MSUMI (941 rows).
# 2026-01-09 13:51:41,554 - INFO - Fetched data for MOTILALOFS (2478 rows).
# 2026-01-09 13:51:41,913 - INFO - Fetched data for MPHASIS (2478 rows).
# 2026-01-09 13:51:42,308 - INFO - Fetched data for MCX (2478 rows).
# 2026-01-09 13:51:42,714 - INFO - Fetched data for MUTHOOTFIN (2478 rows).
# 2026-01-09 13:51:43,099 - INFO - Fetched data for NATCOPHARM (2478 rows).
# 2026-01-09 13:51:43,473 - INFO - Fetched data for NBCC (2478 rows).
# 2026-01-09 13:51:43,850 - INFO - Fetched data for NCC (2478 rows).
# 2026-01-09 13:51:44,251 - INFO - Fetched data for NHPC (2478 rows).
# 2026-01-09 13:51:44,609 - INFO - Fetched data for NLCINDIA (2478 rows).
# 2026-01-09 13:51:44,980 - INFO - Fetched data for NMDC (2478 rows).
# 2026-01-09 13:51:45,271 - INFO - Fetched data for NSLNISP (716 rows).
# 2026-01-09 13:51:45,548 - INFO - Fetched data for NTPCGREEN (280 rows).
# 2026-01-09 13:51:45,927 - INFO - Fetched data for NTPC (2478 rows).
# 2026-01-09 13:51:46,296 - INFO - Fetched data for NH (2478 rows).
# 2026-01-09 13:51:46,677 - INFO - Fetched data for NATIONALUM (2478 rows).
# 2026-01-09 13:51:47,036 - INFO - Fetched data for NAVA (2478 rows).
# 2026-01-09 13:51:47,409 - INFO - Fetched data for NAVINFLUOR (2478 rows).
# 2026-01-09 13:51:47,791 - INFO - Fetched data for NESTLEIND (2478 rows).
# 2026-01-09 13:51:48,087 - INFO - Fetched data for NETWEB (611 rows).
# 2026-01-09 13:51:48,461 - INFO - Fetched data for NETWORK18 (2478 rows).
# 2026-01-09 13:51:48,829 - INFO - Fetched data for NEULANDLAB (2478 rows).
# 2026-01-09 13:51:49,198 - INFO - Fetched data for NEWGEN (1971 rows).
# 2026-01-09 13:51:49,551 - INFO - Fetched data for NAM-INDIA (2028 rows).
# 2026-01-09 13:51:49,823 - INFO - Fetched data for NIVABUPA (287 rows).
# 2026-01-09 13:51:50,106 - INFO - Fetched data for NUVAMA (569 rows).
# 2026-01-09 13:51:50,532 - INFO - Fetched data for OBEROIRLTY (2478 rows).
# 2026-01-09 13:51:50,909 - INFO - Fetched data for ONGC (2478 rows).
# 2026-01-09 13:51:51,297 - INFO - Fetched data for OIL (2478 rows).
# 2026-01-09 13:51:51,569 - INFO - Fetched data for OLAELEC (354 rows).
# 2026-01-09 13:51:51,949 - INFO - Fetched data for OLECTRA (2478 rows).
# 2026-01-09 13:51:52,262 - INFO - Fetched data for PAYTM (1030 rows).
# 2026-01-09 13:51:52,641 - INFO - Fetched data for OFSS (2478 rows).
# 2026-01-09 13:51:52,950 - INFO - Fetched data for POLICYBZR (1033 rows).
# 2026-01-09 13:51:53,262 - INFO - Fetched data for PCBL (991 rows).
# 2026-01-09 13:51:53,635 - INFO - Fetched data for PGEL (2478 rows).
# 2026-01-09 13:51:54,010 - INFO - Fetched data for PIIND (2478 rows).
# 2026-01-09 13:51:54,367 - INFO - Fetched data for PNBHOUSING (2277 rows).
# 2026-01-09 13:51:54,745 - INFO - Fetched data for PNCINFRA (2478 rows).
# 2026-01-09 13:51:55,053 - INFO - Fetched data for PTCIL (644 rows).
# 2026-01-09 13:51:55,449 - INFO - Fetched data for PVRINOX (2478 rows).
# 2026-01-09 13:51:55,825 - INFO - Fetched data for PAGEIND (2478 rows).
# 2026-01-09 13:51:56,135 - INFO - Fetched data for PATANJALI (868 rows).
# 2026-01-09 13:51:56,526 - INFO - Fetched data for PERSISTENT (2478 rows).
# 2026-01-09 13:51:56,912 - INFO - Fetched data for PETRONET (2478 rows).
# 2026-01-09 13:51:57,330 - INFO - Fetched data for PFIZER (2478 rows).
# 2026-01-09 13:51:57,718 - INFO - Fetched data for PHOENIXLTD (2478 rows).
# 2026-01-09 13:51:58,079 - INFO - Fetched data for PIDILITIND (2478 rows).
# 2026-01-09 13:51:58,504 - INFO - Fetched data for PEL (2403 rows).
# 2026-01-09 13:51:58,823 - INFO - Fetched data for PPLPHARMA (801 rows).
# 2026-01-09 13:51:59,193 - INFO - Fetched data for POLYMED (2478 rows).
# 2026-01-09 13:51:59,536 - INFO - Fetched data for POLYCAB (1671 rows).
# 2026-01-09 13:51:59,920 - INFO - Fetched data for POONAWALLA (2478 rows).
# 2026-01-09 13:52:00,300 - INFO - Fetched data for PFC (2478 rows).
# 2026-01-09 13:52:00,679 - INFO - Fetched data for POWERGRID (2478 rows).
# 2026-01-09 13:52:01,058 - INFO - Fetched data for PRAJIND (2478 rows).
# 2026-01-09 13:52:01,332 - INFO - Fetched data for PREMIERENE (338 rows).
# 2026-01-09 13:52:01,690 - INFO - Fetched data for PRESTIGE (2478 rows).
# 2026-01-09 13:52:02,059 - INFO - Fetched data for PNB (2478 rows).
# 2026-01-09 13:52:02,339 - INFO - Fetched data for RRKABEL (573 rows).
# 2026-01-09 13:52:02,776 - INFO - Fetched data for RBLBANK (2321 rows).
# 2026-01-09 13:52:03,153 - INFO - Fetched data for RECLTD (2478 rows).
# 2026-01-09 13:52:03,473 - INFO - Fetched data for RHIM (1111 rows).
# 2026-01-09 13:52:03,817 - INFO - Fetched data for RITES (1866 rows).
# 2026-01-09 13:52:04,202 - INFO - Fetched data for RADICO (2478 rows).
# 2026-01-09 13:52:04,532 - INFO - Fetched data for RVNL (1674 rows).
# 2026-01-09 13:52:04,959 - INFO - Fetched data for RAILTEL (1207 rows).
# 2026-01-09 13:52:05,294 - INFO - Fetched data for RAINBOW (913 rows).
# 2026-01-09 13:52:05,711 - INFO - Fetched data for RKFORGE (2478 rows).
# 2026-01-09 13:52:06,115 - INFO - Fetched data for RCF (2478 rows).
# 2026-01-09 13:52:06,435 - INFO - Fetched data for RTNINDIA (1183 rows).
# 2026-01-09 13:52:06,770 - INFO - Fetched data for RAYMONDLSL (336 rows).
# 2026-01-09 13:52:07,131 - INFO - Fetched data for RAYMOND (2478 rows).
# 2026-01-09 13:52:07,515 - INFO - Fetched data for REDINGTON (2478 rows).
# 2026-01-09 13:52:07,931 - INFO - Fetched data for RELIANCE (2478 rows).
# 2026-01-09 13:52:08,349 - INFO - Fetched data for RPOWER (2478 rows).
# 2026-01-09 13:52:08,678 - INFO - Fetched data for ROUTE (1318 rows).
# 2026-01-09 13:52:08,964 - INFO - Fetched data for SBFC (598 rows).
# 2026-01-09 13:52:09,333 - INFO - Fetched data for SBICARD (1447 rows).
# 2026-01-09 13:52:09,697 - INFO - Fetched data for SBILIFE (2052 rows).
# 2026-01-09 13:52:10,071 - INFO - Fetched data for SJVN (2478 rows).
# 2026-01-09 13:52:10,467 - INFO - Fetched data for SKFINDIA (2478 rows).
# 2026-01-09 13:52:10,866 - INFO - Fetched data for SRF (2478 rows).
# 2026-01-09 13:52:11,132 - INFO - Fetched data for SAGILITY (289 rows).
# 2026-01-09 13:52:11,423 - INFO - Fetched data for SAILIFE (265 rows).
# 2026-01-09 13:52:11,800 - INFO - Fetched data for SAMMAANCAP (2478 rows).
# 2026-01-09 13:52:12,181 - INFO - Fetched data for MOTHERSON (2478 rows).
# 2026-01-09 13:52:12,492 - INFO - Fetched data for SAPPHIRE (1030 rows).
# 2026-01-09 13:52:12,864 - INFO - Fetched data for SARDAEN (2478 rows).
# 2026-01-09 13:52:13,244 - INFO - Fetched data for SAREGAMA (2478 rows).
# 2026-01-09 13:52:13,656 - INFO - Fetched data for SCHAEFFLER (2478 rows).
# 2026-01-09 13:52:14,047 - INFO - Fetched data for SCHNEIDER (2478 rows).
# 2026-01-09 13:52:14,432 - INFO - Fetched data for SCI (2478 rows).
# 2026-01-09 13:52:14,807 - INFO - Fetched data for SHREECEM (2478 rows).
# 2026-01-09 13:52:15,177 - INFO - Fetched data for RENUKA (2478 rows).
# 2026-01-09 13:52:15,558 - INFO - Fetched data for SHRIRAMFIN (2478 rows).
# 2026-01-09 13:52:15,890 - INFO - Fetched data for SHYAMMETL (1129 rows).
# 2026-01-09 13:52:16,267 - INFO - Fetched data for SIEMENS (2478 rows).
# 2026-01-09 13:52:16,536 - INFO - Fetched data for SIGNATURE (568 rows).
# 2026-01-09 13:52:16,911 - INFO - Fetched data for SOBHA (2478 rows).
# 2026-01-09 13:52:17,313 - INFO - Fetched data for SOLARINDS (2478 rows).
# 2026-01-09 13:52:17,619 - INFO - Fetched data for SONACOMS (1129 rows).
# 2026-01-09 13:52:17,985 - INFO - Fetched data for SONATSOFTW (2478 rows).
# 2026-01-09 13:52:18,305 - INFO - Fetched data for STARHEALTH (1014 rows).
# 2026-01-09 13:52:18,676 - INFO - Fetched data for SBIN (2478 rows).
# 2026-01-09 13:52:19,080 - INFO - Fetched data for SAIL (2478 rows).
# 2026-01-09 13:52:19,419 - INFO - Fetched data for SWSOLAR (1588 rows).
# 2026-01-09 13:52:19,807 - INFO - Fetched data for SUMICHEM (1480 rows).
# 2026-01-09 13:52:20,185 - INFO - Fetched data for SUNPHARMA (2478 rows).
# 2026-01-09 13:52:20,568 - INFO - Fetched data for SUNTV (2478 rows).
# 2026-01-09 13:52:20,984 - INFO - Fetched data for SUNDARMFIN (2478 rows).
# 2026-01-09 13:52:21,362 - INFO - Fetched data for SUNDRMFAST (2478 rows).
# 2026-01-09 13:52:21,760 - INFO - Fetched data for SUPREMEIND (2478 rows).
# 2026-01-09 13:52:22,128 - INFO - Fetched data for SUZLON (2478 rows).
# (2026-01-09 13:52:22,394) ERROR :: <class 'AttributeError'> -> 'DataFrame' object has no attribute 'timestamp' (PID:28928 Thread:28324)
# 2026-01-09 13:52:22,394 - ERROR - <class 'AttributeError'> -> 'DataFrame' object has no attribute 'timestamp'
# 2026-01-09 13:52:22,399 - ERROR - Failed to fetch data for SWANENERGY: 'NoneType' object does not support item assignment
# 2026-01-09 13:52:22,567 - INFO - Fetched data for SWIGGY (288 rows).
# 2026-01-09 13:52:22,946 - INFO - Fetched data for SYNGENE (2478 rows).
# 2026-01-09 13:52:23,273 - INFO - Fetched data for SYRMA (838 rows).
# 2026-01-09 13:52:23,562 - INFO - Fetched data for TBOTEK (414 rows).
# 2026-01-09 13:52:23,947 - INFO - Fetched data for TVSMOTOR (2478 rows).
# 2026-01-09 13:52:24,346 - INFO - Fetched data for TANLA (2478 rows).
# 2026-01-09 13:52:24,733 - INFO - Fetched data for TATACHEM (2478 rows).
# 2026-01-09 13:52:25,105 - INFO - Fetched data for TATACOMM (2478 rows).
# 2026-01-09 13:52:25,488 - INFO - Fetched data for TCS (2478 rows).
# 2026-01-09 13:52:25,864 - INFO - Fetched data for TATACONSUM (2477 rows).
# 2026-01-09 13:52:26,248 - INFO - Fetched data for TATAELXSI (2478 rows).
# 2026-01-09 13:52:26,649 - INFO - Fetched data for TATAINVEST (2478 rows).
# (2026-01-09 13:52:26,902) ERROR :: <class 'AttributeError'> -> 'DataFrame' object has no attribute 'timestamp' (PID:28928 Thread:28324)
# 2026-01-09 13:52:26,902 - ERROR - <class 'AttributeError'> -> 'DataFrame' object has no attribute 'timestamp'
# 2026-01-09 13:52:26,902 - ERROR - Failed to fetch data for TATAMOTORS: 'NoneType' object does not support item assignment
# 2026-01-09 13:52:27,190 - INFO - Fetched data for TATAPOWER (2478 rows).
# 2026-01-09 13:52:27,574 - INFO - Fetched data for TATASTEEL (2478 rows).
# 2026-01-09 13:52:27,854 - INFO - Fetched data for TATATECH (526 rows).
# 2026-01-09 13:52:28,330 - INFO - Fetched data for TTML (2478 rows).
# 2026-01-09 13:52:28,885 - INFO - Fetched data for TECHM (2478 rows).
# 2026-01-09 13:52:29,368 - INFO - Fetched data for TECHNOE (1763 rows).
# 2026-01-09 13:52:29,975 - INFO - Fetched data for TEJASNET (2119 rows).
# 2026-01-09 13:52:30,582 - INFO - Fetched data for NIACL (2024 rows).
# 2026-01-09 13:52:31,213 - INFO - Fetched data for RAMCOCEM (2478 rows).
# 2026-01-09 13:52:31,825 - INFO - Fetched data for THERMAX (2478 rows).
# 2026-01-09 13:52:32,236 - INFO - Fetched data for TIMKEN (2478 rows).
# 2026-01-09 13:52:32,626 - INFO - Fetched data for TITAGARH (2478 rows).
# 2026-01-09 13:52:33,027 - INFO - Fetched data for TITAN (2478 rows).
# 2026-01-09 13:52:33,402 - INFO - Fetched data for TORNTPHARM (2478 rows).
# 2026-01-09 13:52:33,818 - INFO - Fetched data for TORNTPOWER (2478 rows).
# 2026-01-09 13:52:34,197 - INFO - Fetched data for TARIL (2478 rows).
# 2026-01-09 13:52:34,605 - INFO - Fetched data for TRENT (2478 rows).
# 2026-01-09 13:52:34,991 - INFO - Fetched data for TRIDENT (2478 rows).
# 2026-01-09 13:52:35,362 - INFO - Fetched data for TRIVENI (2478 rows).
# 2026-01-09 13:52:35,737 - INFO - Fetched data for TRITURBINE (2478 rows).
# 2026-01-09 13:52:36,098 - INFO - Fetched data for TIINDIA (2031 rows).
# 2026-01-09 13:52:36,468 - INFO - Fetched data for UCOBANK (2478 rows).
# 2026-01-09 13:52:36,845 - INFO - Fetched data for UNOMINDA (2478 rows).
# 2026-01-09 13:52:37,230 - INFO - Fetched data for UPL (2478 rows).
# 2026-01-09 13:52:37,534 - INFO - Fetched data for UTIAMC (1304 rows).
# 2026-01-09 13:52:37,925 - INFO - Fetched data for ULTRACEMCO (2478 rows).
# 2026-01-09 13:52:38,304 - INFO - Fetched data for UNIONBANK (2478 rows).
# 2026-01-09 13:52:38,667 - INFO - Fetched data for UBL (2478 rows).
# 2026-01-09 13:52:39,066 - INFO - Fetched data for UNITDSPR (2478 rows).
# 2026-01-09 13:52:39,431 - INFO - Fetched data for USHAMART (2478 rows).
# 2026-01-09 13:52:39,811 - INFO - Fetched data for VGUARD (2478 rows).
# 2026-01-09 13:52:40,185 - INFO - Fetched data for DBREALTY (2478 rows).
# 2026-01-09 13:52:40,550 - INFO - Fetched data for VTL (2478 rows).
# 2026-01-09 13:52:40,913 - INFO - Fetched data for VBL (2276 rows).
# 2026-01-09 13:52:41,226 - INFO - Fetched data for MANYAVAR (968 rows).
# 2026-01-09 13:52:41,601 - INFO - Fetched data for VEDL (2478 rows).
# 2026-01-09 13:52:41,945 - INFO - Fetched data for VIJAYA (1075 rows).
# 2026-01-09 13:52:42,213 - INFO - Fetched data for VMM (265 rows).
# 2026-01-09 13:52:42,582 - INFO - Fetched data for IDEA (2477 rows).
# 2026-01-09 13:52:42,974 - INFO - Fetched data for VOLTAS (2478 rows).
# 2026-01-09 13:52:43,242 - INFO - Fetched data for WAAREEENER (300 rows).
# 2026-01-09 13:52:43,617 - INFO - Fetched data for WELCORP (2478 rows).
# 2026-01-09 13:52:43,960 - INFO - Fetched data for WELSPUNLIV (516 rows).
# 2026-01-09 13:52:44,291 - INFO - Fetched data for WESTLIFE (1588 rows).
# 2026-01-09 13:52:44,667 - INFO - Fetched data for WHIRLPOOL (2478 rows).
# 2026-01-09 13:52:45,077 - INFO - Fetched data for WIPRO (2478 rows).
# 2026-01-09 13:52:45,455 - INFO - Fetched data for WOCKPHARMA (2478 rows).
# 2026-01-09 13:52:45,826 - INFO - Fetched data for YESBANK (2478 rows).
# 2026-01-09 13:52:46,138 - INFO - Fetched data for ZFCVINDIA (938 rows).
# 2026-01-09 13:52:46,518 - INFO - Fetched data for ZEEL (2478 rows).
# 2026-01-09 13:52:46,893 - INFO - Fetched data for ZENTEC (2478 rows).
# 2026-01-09 13:52:47,263 - INFO - Fetched data for ZENSARTECH (2478 rows).
# 2026-01-09 13:52:47,632 - INFO - Fetched data for ZYDUSLIFE (2478 rows).
# 2026-01-09 13:52:48,012 - INFO - Fetched data for ECLERX (2478 rows).
#               Date    Close  Ticker
# 0       2019-09-19   317.65  360ONE
# 1       2019-09-20   333.50  360ONE
# 2       2019-09-23   350.15  360ONE
# 3       2019-09-24   367.65  360ONE
# 4       2019-09-25   351.25  360ONE
# ...            ...      ...     ...
# 1026604 2026-01-05  4775.00  ECLERX
# 1026605 2026-01-06  4802.60  ECLERX
# 1026606 2026-01-07  4772.10  ECLERX
# 1026607 2026-01-08  4751.40  ECLERX
# 1026608 2026-01-09  4674.00  ECLERX
#
# [1026609 rows x 3 columns]
# Failed tickers: ['DUMMYABFRL', 'DUMMYSIEMS', 'DUMMYRAYMN', 'SWANENERGY', 'TATAMOTORS']
# 📊 Created 38 rolling windows.
#
# 🔍 Processing window: 2022-06-01 → 2022-12-01
# rank df:          Ticker   Positive   Negative   Momentum     ISIN Code  Rank_Mom
# 0        360ONE  50
01
# rank df:          Ticker   Positive   Negative   Momentum     ISIN Code  Rank_Mom
# 0        360ONE  50.793651  48.412698  10.744098  INE466L01038     214.0
# 1       3MINDIA  46.031746  50.793651  -2.510671  INE470A01017     370.0
# 2     AADHARHFC  48.412698  51.587302   8.578626  INE883F01010     233.0
# 3      AARTIIND  46.031746  53.174603 -10.645467  INE769A01020     449.0
# 4         AAVAS  49.206349  50.000000  -4.053111  INE216P01012     393.0
# ..          ...        ...        ...        ...           ...       ...
# 493        ZEEL  48.412698  51.587302   1.236891  INE256A01028     324.0
# 494  ZENSARTECH  50.000000  50.000000  10.775863  INE520A01027     213.0
# 495      ZENTEC  47.619048  52.380952 -10.578337  INE251B01027     447.0
# 496   ZFCVINDIA  45.238095  54.761905   1.357350  INE342J01019     321.0
# 497   ZYDUSLIFE  57.142857  42.063492   9.119493  INE010B01027     228.0
#
# [498 rows x 6 columns]
# ✅ Saved results to: Stocks\Nifty_500_2025_Apr_20_stocks_results\momentum_20250501_20251101.xlsx
#
# 🔍 Processing window: 2025-06-01 → 2025-12-01
# rank df:          Ticker   Positive   Negative   Momentum     ISIN Code  Rank_Mom
# 0        360ONE  50.000000  49.193548  13.739234  INE466L01038      89.0
# 1       3MINDIA  45.161290  51.612903  12.450115  INE470A01017     103.0
# 2     AADHARHFC  47.580645  52.419355   8.707667  INE883F01010     132.0
# 3      AARTIIND  44.354839  55.645161 -20.084746  INE769A01020     442.0
# 4         AAVAS  45.967742  54.032258  -9.971141  INE216P01012     349.0
# ..          ...        ...        ...        ...           ...       ...
# 493        ZEEL  45.161290  54.838710 -16.858056  INE256A01028     413.0
# 494  ZENSARTECH  50.806452  49.193548  -5.378424  INE520A01027     280.0
# 495      ZENTEC  45.161290  54.838710 -42.204338  INE251B01027     496.0
# 496   ZFCVINDIA  45.161290  54.838710  -3.784702  INE342J01019     262.0
# 497   ZYDUSLIFE  54.032258  45.161290  -0.173185  INE010B01027     223.0
#
# [498 rows x 6 columns]
# ✅ Saved results to: Stocks\Nifty_500_2025_Apr_20_stocks_results\momentum_20250601_20251201.xlsx
#
# 🔍 Processing window: 2025-07-01 → 2026-01-01
# rank df:          Ticker  Positive  Negative   Momentum     ISIN Code  Rank_Mom
# 0        360ONE      49.6      49.6  -2.866975  INE466L01038     207.0
# 1       3MINDIA      44.0      53.6  16.582891  INE470A01017      62.0
# 2     AADHARHFC      48.8      51.2   5.737193  INE883F01010     127.0
# 3      AARTIIND      40.8      59.2 -22.902144  INE769A01020     430.0
# 4         AAVAS      42.4      57.6 -25.131470  INE216P01012     446.0
# ..          ...       ...       ...        ...           ...       ...
# 493        ZEEL      40.8      59.2 -34.642836  INE256A01028     485.0
# 494  ZENSARTECH      50.4      49.6 -12.539661  INE520A01027     325.0
# 495      ZENTEC      44.8      55.2 -39.429447  INE251B01027     491.0
# 496   ZFCVINDIA      43.2      56.8  -3.035616  INE342J01019     212.0
# 497   ZYDUSLIFE      50.4      49.6  -8.628699  INE010B01027     283.0
#
# [498 rows x 6 columns]
# ✅ Saved results to: Stocks\Nifty_500_2025_Apr_20_stocks_results\momentum_20250701_20260101.xlsx
#
# 📂 Creating master summary file...
# ✅ Master file saved to: Stocks\Nifty_500_2025_Apr_20_stocks_results\master_momentum_summary.xlsx
# Master summary located at: Stocks\Nifty_500_2025_Apr_20_stocks_results\master_momentum_summary.xlsx

# %%
----------------xxxxxxxxxxxxxxx---------------------------------------
